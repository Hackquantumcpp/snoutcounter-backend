# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
congress = pd.read_csv('congress_approval_polls_display_table.csv')
scotus = pd.read_csv('scotus_approval_polls_display_table.csv')

# %%
congress
# Out:
#      Unnamed: 0                                           Pollster  \
# 0             0  <a href="https://www.claritycampaigns.com/clar...
# 1             1  <a href="https://cdn.prod.website-files.com/65...
# 2             2  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 3             3  <a href="https://harvardharrispoll.com/wp-cont...
# 4             4  <a href="https://static1.squarespace.com/stati...
# ..          ...                                                ...
# 153         153  <a href="https://static.foxnews.com/foxnews.co...
# 154         154  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 155         155  <a href="https://static1.squarespace.com/stati...
# 156         156  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 157         157  <a href="https://www.monmouth.edu/polling-inst...
#
#      Start Date    End Date   Sample        Weight  Approve  Disapprove   Net
# 0    2025-09-04  2025-09-11  1001 RV  3.799917e-01     37.0        52.0 -15.0
# ...

# %%
scotus
# Out:
#      Unnamed: 0                                           Pollster  \
# 0             0  <a href="https://napolitannews.org/posts/scotu...
# 1             1  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 2             2  <a href="https://napolitannews.org/posts/scotu...
# 3             3  <a href="https://htv-prod-media.s3.amazonaws.c...
# 4             4  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# ..          ...                                                ...
# 150         150  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 151         151  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 152         152  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 153         153  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 154         154  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
#
#      Start Date    End Date   Sample        Weight  Approve  Disapprove   Net
# 0    2025-09-16  2025-09-17  1000 RV  5.313158e-01     41.0        50.0  -9.0
# ...

# %%
congress['Category'] = congress['Pollster'].map(lambda x: 'Congress')
congress
# Out:
#      Unnamed: 0                                           Pollster  \
# 0             0  <a href="https://www.claritycampaigns.com/clar...
# 1             1  <a href="https://cdn.prod.website-files.com/65...
# 2             2  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 3             3  <a href="https://harvardharrispoll.com/wp-cont...
# 4             4  <a href="https://static1.squarespace.com/stati...
# ..          ...                                                ...
# 153         153  <a href="https://static.foxnews.com/foxnews.co...
# 154         154  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 155         155  <a href="https://static1.squarespace.com/stati...
# 156         156  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 157         157  <a href="https://www.monmouth.edu/polling-inst...
#
#      Start Date    End Date   Sample        Weight  Approve  Disapprove   Net  \
# 0    2025-09-04  2025-09-11  1001 RV  3.799917e-01     37.0        52.0 -15.0
# ...

# %%
scotus['Category'] = scotus['Pollster'].map(lambda x: 'Supreme Court')
scotus
# Out:
#      Unnamed: 0                                           Pollster  \
# 0             0  <a href="https://napolitannews.org/posts/scotu...
# 1             1  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 2             2  <a href="https://napolitannews.org/posts/scotu...
# 3             3  <a href="https://htv-prod-media.s3.amazonaws.c...
# 4             4  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# ..          ...                                                ...
# 150         150  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 151         151  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 152         152  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 153         153  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 154         154  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
#
#      Start Date    End Date   Sample        Weight  Approve  Disapprove   Net  \
# 0    2025-09-16  2025-09-17  1000 RV  5.313158e-01     41.0        50.0  -9.0
# ...

# %%
congress_scotus = pd.concat([congress, scotus], axis=0)
congress_scotus
# Out:
#      Unnamed: 0                                           Pollster  \
# 0             0  <a href="https://www.claritycampaigns.com/clar...
# 1             1  <a href="https://cdn.prod.website-files.com/65...
# 2             2  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 3             3  <a href="https://harvardharrispoll.com/wp-cont...
# 4             4  <a href="https://static1.squarespace.com/stati...
# ..          ...                                                ...
# 150         150  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 151         151  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 152         152  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 153         153  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
# 154         154  <a href="https://d3nkl3psvxxpe9.cloudfront.net...
#
#      Start Date    End Date   Sample        Weight  Approve  Disapprove   Net  \
# 0    2025-09-04  2025-09-11  1001 RV  3.799917e-01     37.0        52.0 -15.0
# ...

# %%
congress_scotus.to_csv('congress_scotus_polls_display_table.csv')
