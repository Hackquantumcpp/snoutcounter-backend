# %%
# %run ./president-approval.ipynb
# %run ./president-issue-approval.ipynb
# %run ./scotus-approval.ipynb
# %run ./congress-approval.ipynb
# %run ./generic-ballot.ipynb
# %run ./congress-scotus-table-combined.ipynb
# Out:
# <div>                            <div id="1f1d8ef2-ebbf-4271-a9a7-e99335351a8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f1d8ef2-ebbf-4271-a9a7-e99335351a8b")) {                    Plotly.newPlot(                        "1f1d8ef2-ebbf-4271-a9a7-e99335351a8b",                        [{"legendgroup":"Approve","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Approve","orientation":"v","showlegend":true,"x":["2025-01-23T00:00:00","2025-01-24T00:00:00","2025-01-25T00:00:00","2025-01-26T00:00:00","2025-01-27T00:00:00","2025-01-28T00:00:00","2025-01-29T00:00:00","2025-01-30T00:00:00","2025-01-31T00:00:00","2025-02-01T00:00:00","2025-02-02T00:00:00","2025-02-03T00:00:00","2025-02-04T00:00:00","2025-02-05T
# ...

# %%
import pandas as pd
import gspread
from gspread_dataframe import set_with_dataframe
from google.oauth2.service_account import Credentials

from keys import GOOG_API_KEY

# %%
# Define the scope
scopes = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive"
]

# Authenticate with the service account
credentials = Credentials.from_service_account_file(
    GOOG_API_KEY,
    scopes=scopes
)

# Authorize gspread
client = gspread.authorize(credentials)

# %%
spreadsheet = client.open("snoutcounter-data")
worksheet = spreadsheet.worksheet("approval-stats")  # or use .sheet1
worksheet.clear()

approval_stats = pd.read_csv('approval_stats.csv')
set_with_dataframe(worksheet, approval_stats)

# %%
# spreadsheet = client.open("snoutcounter-data")
worksheet = spreadsheet.worksheet("polls_display_table")  # or use .sheet1
worksheet.clear()

approval_stats = pd.read_csv('polls_display_table.csv')
set_with_dataframe(worksheet, approval_stats)

# %%
for issue in ['econ', 'imm', 'infl', 'trade', 'fp']:
    # spreadsheet = client.open("snoutcounter-data")
    worksheet = spreadsheet.worksheet(f"approval_stats_{issue}")  # or use .sheet1
    worksheet.clear()

    approval_stats = pd.read_csv(f'approval_stats_{issue}.csv')
    set_with_dataframe(worksheet, approval_stats)

# %%
# spreadsheet = client.open("snoutcounter-data")
worksheet = spreadsheet.worksheet("polls_display_issues")  # or use .sheet1
worksheet.clear()

approval_stats = pd.read_csv('polls_display_issues.csv')
set_with_dataframe(worksheet, approval_stats)

# %%
for inst in ['congress', 'scotus']:
    # spreadsheet = client.open("snoutcounter-data")
    worksheet = spreadsheet.worksheet(f"{inst}_approval_stats")  # or use .sheet1
    worksheet.clear()

    approval_stats = pd.read_csv(f'{inst}_approval_stats.csv')
    set_with_dataframe(worksheet, approval_stats)

# %%
# spreadsheet = client.open("snoutcounter-data")
worksheet = spreadsheet.worksheet("generic_ballot_stats")  # or use .sheet1
worksheet.clear()

approval_stats = pd.read_csv('generic_ballot_stats.csv')
set_with_dataframe(worksheet, approval_stats)

# %%
for inst in ['congress_scotus', 'generic_ballot']:
    # spreadsheet = client.open("snoutcounter-data")
    worksheet = spreadsheet.worksheet(f"{inst}_polls_display_table")  # or use .sheet1
    worksheet.clear()

    approval_stats = pd.read_csv(f'{inst}_polls_display_table.csv')
    set_with_dataframe(worksheet, approval_stats)

# %%
# spreadsheet = client.open("snoutcounter-data")
worksheet = spreadsheet.worksheet("net_approval_issues")  # or use .sheet1
worksheet.clear()

approval_stats = pd.read_csv('net_approval_issues.csv')
set_with_dataframe(worksheet, approval_stats)

# %%
# spreadsheet = client.open("snoutcounter-data")
worksheet = spreadsheet.worksheet("net_approval")  # or use .sheet1
worksheet.clear()

approval_stats = pd.read_csv('net_approval.csv')
set_with_dataframe(worksheet, approval_stats)

# %%
worksheet = spreadsheet.worksheet("indiv_pollster_avgs")
worksheet.clear()

approval_stats = pd.read_csv('indiv_pollster_avgs.csv')
set_with_dataframe(worksheet, approval_stats)
