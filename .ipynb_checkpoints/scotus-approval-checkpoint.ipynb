# %%
import numpy as np
import pandas as pd
import scipy
from scipy.optimize import minimize
import plotly.express as px
import plotly.graph_objects as go
import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://docs.google.com/spreadsheets/d/1_y0_LJmSY6sNx8qd51T70n0oa_ugN50AVFKuJmXO1-s/export?format=csv&gid=1343375723'

# %%
approval = pd.read_csv(url)
approval
# Out:
#      poll_id  pollster_id              pollster  sponsor_ids  \
# 0      89601        568.0                YouGov        352.0
# 1      89601        568.0                YouGov        352.0
# 2      89579        568.0                YouGov        352.0
# 3      89579        568.0                YouGov        352.0
# 4      89573        460.0             SurveyUSA          NaN
# ..       ...          ...                   ...          ...
# 577    89901          NaN                YouGov          NaN
# 578    89947          NaN  UMass Amherst/YouGov          NaN
# 579    89956          NaN          RMG Research          NaN
# 580    89957          NaN                YouGov          NaN
# 581    89957          NaN                YouGov          NaN
#
#                    sponsors            methodology  state start_date end_date  \
# 0                 Economist  Online Matched Sample    NaN    2/23/25  2/25/25
# 1                 Economist  Online Matched Sample    NaN    2/23/25  2/25/25
# 2                 Economist  Online Matched Sample    NaN    2/16/25  2/18/25
# 3                 Economist  Online Matched Sample    NaN    2/16/25  2/18/25
# 4                       NaN    Online Opt-In Panel    NaN    2/13/25  2/16/25
# ..                      ...                    ...    ...        ...      ...
# 577               Economist  Online Matched Sample    NaN     4/5/25   4/8/25
# 578                 WCVB-TV  Online Matched Sample    NaN     4/4/25   4/9/25
# 579  Napolitan News Service    Online Opt-In Panel    NaN     4/9/25  4/10/25
# 580               Economist  Online Matched Sample    NaN    4/13/25  4/15/25
# 581               Economist  Online Matched Sample    NaN    4/13/25  4/15/25
#
#      sponsor_candidate_id  ...  notes  \
# 0                     NaN  ...    NaN
# 1                     NaN  ...    NaN
# 2                     NaN  ...    NaN
# 3                     NaN  ...    NaN
# 4                     NaN  ...    NaN
# ..                    ...  ...    ...
# 577                   NaN  ...    NaN
# 578                   NaN  ...    NaN
# 579                   NaN  ...    NaN
# 580                   NaN  ...    NaN
# 581                   NaN  ...    NaN
#
#                                            url_article  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 577                                                NaN
# 578  https://www.umass.edu/political-science/about/...
# 579  https://napolitannews.org/posts/supreme-court-...
# 580                                                NaN
# 581                                                NaN
#
#                                            url_topline  \
# 0    https://d3nkl3psvxxpe9.cloudfront.net/document...
# 1                                                  NaN
# 2    https://d3nkl3psvxxpe9.cloudfront.net/document...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 577  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 578                                                NaN
# 579                                                NaN
# 580  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 581  https://d3nkl3psvxxpe9.cloudfront.net/document...
#
#                                           url_crosstab source  internal  \
# 0    https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 1    https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 2    https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 3    https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 4    https://www.surveyusa.com/client/PollReport.as...    NaN       NaN
# ..                                                 ...    ...       ...
# 577  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 578                                                NaN    NaN       NaN
# 579                                                NaN    NaN       NaN
# 580  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 581  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
#
#     partisan   yes    no alternate_answers
# 0        NaN  37.0  43.0              20.0
# 1        NaN  40.0  45.0              14.0
# 2        NaN  40.0  42.0              18.0
# 3        NaN  43.0  45.0              12.0
# 4        NaN  46.0  40.0              13.0
# ..       ...   ...   ...               ...
# 577      NaN  37.0  51.0              12.0
# 578      NaN  38.0  48.0              14.0
# 579      NaN  50.0  42.0               8.0
# 580      NaN  38.0  45.0              18.0
# 581      NaN  42.0  47.0              11.0
#
# [582 rows x 29 columns]

# %%
morris_to_silver_dict = {
    'HarrisX/Harris Poll':'Harris Insights & Analytics',
    'Clarity': 'Clarity Campaign Labs',
    'Beacon/Shaw': 'Beacon Research/Shaw & Co. Research',
    'Monmouth': 'Monmouth University',
    'HarrisX': 'Harris Insights & Analytics',
    'UMass Amherst/YouGov': 'YouGov',
    'Emerson': 'Emerson College',
    'Marquette Law School': 'Marquette University Law School',
    'NewsNation/Decision Desk HQ': 'NewsNation',
    'CNN/SSRS': 'SSRS',
    'Suffolk': 'Suffolk University',
    'Harris Poll': 'Harris Insights & Analytics',
    'Fabrizio/Impact': 'Fabrizio Lee & Associates/Impact Research',
    'Winston': 'The Winston Group',
    'Hart/POS': 'Hart Research Associates/Public Opinion Strategies',
    'Quinnipiac': 'Quinnipiac University',
    'Siena/NYT': 'The New York Times/Siena College',
    'Noble Predictive Insights': 'OH Predictive Insights'
}

# %%
approval['pollster'] = approval['pollster'].replace(morris_to_silver_dict)
approval = approval.rename({'yes':'approve', 'no':'disapprove', 'population':'population_empty'}, axis='columns')
approval = approval.rename({'population_full':'population'}, axis='columns')
approval.head(7)
# Out:
#    poll_id  pollster_id   pollster  sponsor_ids   sponsors  \
# 0    89601        568.0     YouGov        352.0  Economist
# 1    89601        568.0     YouGov        352.0  Economist
# 2    89579        568.0     YouGov        352.0  Economist
# 3    89579        568.0     YouGov        352.0  Economist
# 4    89573        460.0  SurveyUSA          NaN        NaN
# 5    89558        568.0     YouGov        352.0  Economist
# 6    89558        568.0     YouGov        352.0  Economist
#
#              methodology  state start_date end_date  sponsor_candidate_id  \
# 0  Online Matched Sample    NaN    2/23/25  2/25/25                   NaN
# 1  Online Matched Sample    NaN    2/23/25  2/25/25                   NaN
# 2  Online Matched Sample    NaN    2/16/25  2/18/25                   NaN
# 3  Online Matched Sample    NaN    2/16/25  2/18/25                   NaN
# 4    Online Opt-In Panel    NaN    2/13/25  2/16/25                   NaN
# 5  Online Matched Sample    NaN     2/9/25  2/11/25                   NaN
# 6  Online Matched Sample    NaN     2/9/25  2/11/25                   NaN
#
#    ...  notes  url_article                                        url_topline  \
# 0  ...    NaN          NaN  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 1  ...    NaN          NaN                                                NaN
# 2  ...    NaN          NaN  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 3  ...    NaN          NaN                                                NaN
# 4  ...    NaN          NaN                                                NaN
# 5  ...    NaN          NaN  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 6  ...    NaN          NaN                                                NaN
#
#                                         url_crosstab source  internal  \
# 0  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 1  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 2  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 3  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 4  https://www.surveyusa.com/client/PollReport.as...    NaN       NaN
# 5  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
# 6  https://d3nkl3psvxxpe9.cloudfront.net/document...    NaN       NaN
#
#   partisan  approve disapprove alternate_answers
# 0      NaN     37.0       43.0              20.0
# 1      NaN     40.0       45.0              14.0
# 2      NaN     40.0       42.0              18.0
# 3      NaN     43.0       45.0              12.0
# 4      NaN     46.0       40.0              13.0
# 5      NaN     38.0       45.0              17.0
# 6      NaN     41.0       49.0              10.0
#
# [7 rows x 29 columns]

# %%
approval.shape
# Out:
# (582, 29)

# %%
approval = approval[approval['partisan'].isna()][pd.to_datetime(approval['end_date']) >= pd.to_datetime('2023-12-01')]
approval.shape
# Out:
# (179, 29)

# %%
ratings = pd.read_csv('pollster_ratings_silver.csv')
ratings
# Out:
#                              Pollster    Grade  Predictive Plus-Minus  \
# 0                          AtlasIntel    A+@@1              -0.957740
# 1     Marquette University Law School   A/B@@4              -0.920261
# 2                 The Washington Post    A+@@1              -0.902281
# 3             Research & Polling Inc.     A@@2              -0.871136
# 4    The New York Times/Siena College     A@@2              -0.763947
# ..                                ...      ...                    ...
# 530          Nielson Brothers Polling  C/D@@12               1.946864
# 531                     Ascend Action  C/D@@12               2.282717
# 532       Jayhawk Consulting Services  C/D@@12               2.353968
# 533        Fort Hays State University  C/D@@12               2.489170
# 534                The Dartmouth Poll  C/D@@12               3.988291
#
#       Mean-reverted bias  Number of polls cat
# 0     D+0.16@@0.16334188               91  D+
# 1     D+0.32@@0.31545374               17  D+
# 2     D+0.90@@0.89811021               98  D+
# 3    R+0.55@@-0.54944503               44  R+
# 4      D+1.41@@1.4121077              116  D+
# ..                   ...              ...  ..
# 530    D+3.05@@3.0515239               11  D+
# 531    D+3.35@@3.3485439                6  D+
# 532    D+2.27@@2.2674108                2  D+
# 533   R+1.10@@-1.0960908                6  R+
# 534    D+4.40@@4.4045453                4  D+
#
# [535 rows x 6 columns]

# %%
banned_pollsters = ratings[ratings['Grade'].str.contains('F')]['Pollster'].values
banned_pollsters
# Out:
# array(['Strategic Vision LLC', 'Pharos Research Group', 'Research 2000',
#        'Big Data Poll', 'Overtime Politics', 'Rethink Priorities',
#        'Blumenthal Research Daily', 'CSP Polling', 'KG Polling',
#        'OurProgress (The Progress Campaign)', 'TCJ Research'],
#       dtype=object)

# %%
approval = approval[~approval['pollster'].isin(banned_pollsters)]
approval.shape
# Out:
# (179, 29)

# %%
approval = pd.merge(left=approval, right=ratings[['Pollster', 'Predictive Plus-Minus']], left_on='pollster',
                   right_on='Pollster', how='inner')
approval.shape
# Out:
# (179, 31)

# %%
approval['Pollster'].value_counts()
# Out:
# Pollster
# YouGov                                 149
# Marquette University Law School         16
# Quinnipiac University                    4
# RMG Research                             3
# Gallup                                   2
# High Point University                    2
# SurveyUSA                                1
# Emerson College                          1
# Beacon Research/Shaw & Co. Research      1
# Name: count, dtype: int64

# %%
approval = approval[(~approval['sample_size'].isna())]
approval.shape
# Out:
# (179, 31)

# %%
auxiliary = pd.read_csv('auxiliary_pollster_rating_stats.csv')
auxiliary
# Out:
#                               Pollster  Correct calls       Outside MoE  \
# 0                           AtlasIntel       0.840659   8.8%@@91.208791
# 1                  The Washington Post       0.693878   6.1%@@93.877551
# 2              Research & Polling Inc.       0.886364  9.1%@@90.9090906
# 3     The New York Times/Siena College       0.737069  18.1%@@81.896552
# 4                               Cygnal       0.939655  13.8%@@86.206897
# ..                                 ...            ...               ...
# 93                    Digital Research       0.904762  38.1%@@61.904761
# 94  Mitchell Research & Communications       0.695122    39%@@60.975611
# 95                Merriman River Group       0.840000    60%@@39.999998
# 96             McLaughlin & Associates       0.689655  34.5%@@65.517241
# 97                        TCJ Research       0.590909  49.2%@@50.757575
#
#            House effect             ADPA  Herding penalty  herd_cat p_cat
# 0    R+2.00@@-1.9990723   3.7@@3.6687982         0.096047         2    R+
# 1     D+1.02@@1.0173736   3.6@@3.5756676         0.221841         3    D+
# 2    D+0.63@@0.63289553    4.6@@4.642076         0.286276         3    D+
# 3    D+0.79@@0.79133403   3.2@@3.2483816         0.280332         3    D+
# 4   R+0.60@@-0.59704119   3.5@@3.4644768         0.521310         4    R+
# ..                  ...              ...              ...       ...   ...
# 93   R+2.44@@-2.4431372  11.4@@11.413808         0.000000         1    R+
# 94  R+0.45@@-0.44617203   4.4@@4.4410443         0.229193         3    R+
# 95   R+3.23@@-3.2347174  10.3@@10.260222         0.000000         1    R+
# 96   R+4.94@@-4.9392128     6.2@@6.17804         0.000000         1    R+
# 97   R+3.42@@-3.4232018   4.4@@4.3859954         0.000000         1    R+
#
# [98 rows x 8 columns]

# %%
house_eff = auxiliary['House effect'].str.extract(r'(\w)\+(\d\.\d\d)@@*.')
house_eff[1] = house_eff[1].astype(float)
house_eff
# Out:
#     0     1
# 0   R  2.00
# 1   D  1.02
# 2   D  0.63
# 3   D  0.79
# 4   R  0.60
# .. ..   ...
# 93  R  2.44
# 94  R  0.45
# 95  R  3.23
# 96  R  4.94
# 97  R  3.42
#
# [98 rows x 2 columns]

# %%
# R --> -1, D --> 1
house_eff[0] = house_eff[0].replace({'R':-1, 'D':1})
house_eff['house_effect'] = house_eff[0] * house_eff[1]
house_eff
# Out:
#     0     1  house_effect
# 0  -1  2.00         -2.00
# 1   1  1.02          1.02
# 2   1  0.63          0.63
# 3   1  0.79          0.79
# 4  -1  0.60         -0.60
# .. ..   ...           ...
# 93 -1  2.44         -2.44
# 94 -1  0.45         -0.45
# 95 -1  3.23         -3.23
# 96 -1  4.94         -4.94
# 97 -1  3.42         -3.42
#
# [98 rows x 3 columns]

# %%
auxiliary['house_effect'] = house_eff['house_effect']
auxiliary = auxiliary.set_index(['Pollster'])
auxiliary
# Out:
#                                     Correct calls       Outside MoE  \
# Pollster
# AtlasIntel                               0.840659   8.8%@@91.208791
# The Washington Post                      0.693878   6.1%@@93.877551
# Research & Polling Inc.                  0.886364  9.1%@@90.9090906
# The New York Times/Siena College         0.737069  18.1%@@81.896552
# Cygnal                                   0.939655  13.8%@@86.206897
# ...                                           ...               ...
# Digital Research                         0.904762  38.1%@@61.904761
# Mitchell Research & Communications       0.695122    39%@@60.975611
# Merriman River Group                     0.840000    60%@@39.999998
# McLaughlin & Associates                  0.689655  34.5%@@65.517241
# TCJ Research                             0.590909  49.2%@@50.757575
#
#                                            House effect             ADPA  \
# Pollster
# AtlasIntel                           R+2.00@@-1.9990723   3.7@@3.6687982
# The Washington Post                   D+1.02@@1.0173736   3.6@@3.5756676
# Research & Polling Inc.              D+0.63@@0.63289553    4.6@@4.642076
# The New York Times/Siena College     D+0.79@@0.79133403   3.2@@3.2483816
# Cygnal                              R+0.60@@-0.59704119   3.5@@3.4644768
# ...                                                 ...              ...
# Digital Research                     R+2.44@@-2.4431372  11.4@@11.413808
# Mitchell Research & Communications  R+0.45@@-0.44617203   4.4@@4.4410443
# Merriman River Group                 R+3.23@@-3.2347174  10.3@@10.260222
# McLaughlin & Associates              R+4.94@@-4.9392128     6.2@@6.17804
# TCJ Research                         R+3.42@@-3.4232018   4.4@@4.3859954
#
#                                     Herding penalty  herd_cat p_cat  \
# Pollster
# AtlasIntel                                 0.096047         2    R+
# The Washington Post                        0.221841         3    D+
# Research & Polling Inc.                    0.286276         3    D+
# The New York Times/Siena College           0.280332         3    D+
# Cygnal                                     0.521310         4    R+
# ...                                             ...       ...   ...
# Digital Research                           0.000000         1    R+
# Mitchell Research & Communications         0.229193         3    R+
# Merriman River Group                       0.000000         1    R+
# McLaughlin & Associates                    0.000000         1    R+
# TCJ Research                               0.000000         1    R+
#
#                                     house_effect
# Pollster
# AtlasIntel                                 -2.00
# The Washington Post                         1.02
# Research & Polling Inc.                     0.63
# The New York Times/Siena College            0.79
# Cygnal                                     -0.60
# ...                                          ...
# Digital Research                           -2.44
# Mitchell Research & Communications         -0.45
# Merriman River Group                       -3.23
# McLaughlin & Associates                    -4.94
# TCJ Research                               -3.42
#
# [98 rows x 8 columns]

# %%
def apply_house_eff(data, pollster):
    df = data[data['pollster']==pollster]
    try:
        df['approve_adj'] = df['approve'] + (auxiliary.loc[pollster, 'house_effect'] / 2)
        df['disapprove_adj'] = df['disapprove'] - (auxiliary.loc[pollster, 'house_effect'] / 2)
    except KeyError:
        df['approve_adj'] = df['approve']
        df['disapprove_adj'] = df['disapprove']
    return df

# %%
pollsters = approval['pollster'].value_counts().index.values
df_adjs = []
for p in pollsters:
    df = apply_house_eff(approval, p)
    df_adjs.append(df)

approval_adj = pd.concat(df_adjs, axis=0)
approval_adj
# Out:
#     poll_id  pollster_id                             pollster  sponsor_ids  \
# 0     89601        568.0                               YouGov        352.0
# 1     89601        568.0                               YouGov        352.0
# 2     89579        568.0                               YouGov        352.0
# 3     89579        568.0                               YouGov        352.0
# 5     89558        568.0                               YouGov        352.0
# ..      ...          ...                                  ...          ...
# 93    87149        217.0                High Point University          NaN
# 94    87149        217.0                High Point University          NaN
# 4     89573        460.0                            SurveyUSA          NaN
# 72    87898       1102.0                      Emerson College          NaN
# 78    87393       1597.0  Beacon Research/Shaw & Co. Research        149.0
#
#      sponsors             methodology  state start_date end_date  \
# 0   Economist   Online Matched Sample    NaN    2/23/25  2/25/25
# 1   Economist   Online Matched Sample    NaN    2/23/25  2/25/25
# 2   Economist   Online Matched Sample    NaN    2/16/25  2/18/25
# 3   Economist   Online Matched Sample    NaN    2/16/25  2/18/25
# 5   Economist   Online Matched Sample    NaN     2/9/25  2/11/25
# ..        ...                     ...    ...        ...      ...
# 93        NaN     Online Opt-In Panel    NaN    5/22/24  5/29/24
# 94        NaN     Online Opt-In Panel    NaN    5/22/24  5/29/24
# 4         NaN     Online Opt-In Panel    NaN    2/13/25  2/16/25
# 72        NaN     Online Opt-In Panel    NaN    7/25/24  7/28/24
# 78   FOX News  Live Phone/Text-to-Web    NaN     7/7/24  7/10/24
#
#     sponsor_candidate_id  ...  source  internal  partisan  approve disapprove  \
# 0                    NaN  ...     NaN       NaN       NaN     37.0       43.0
# 1                    NaN  ...     NaN       NaN       NaN     40.0       45.0
# 2                    NaN  ...     NaN       NaN       NaN     40.0       42.0
# 3                    NaN  ...     NaN       NaN       NaN     43.0       45.0
# 5                    NaN  ...     NaN       NaN       NaN     38.0       45.0
# ..                   ...  ...     ...       ...       ...      ...        ...
# 93                   NaN  ...     NaN       NaN       NaN     36.0       48.0
# 94                   NaN  ...     NaN       NaN       NaN     38.0       49.0
# 4                    NaN  ...     NaN       NaN       NaN     46.0       40.0
# 72                   NaN  ...     NaN       NaN       NaN     33.7       42.5
# 78                   NaN  ...     NaN     False       NaN     38.0       60.0
#
#     alternate_answers                             Pollster  \
# 0                20.0                               YouGov
# 1                14.0                               YouGov
# 2                18.0                               YouGov
# 3                12.0                               YouGov
# 5                17.0                               YouGov
# ..                ...                                  ...
# 93               17.0                High Point University
# 94               13.0                High Point University
# 4                13.0                            SurveyUSA
# 72               23.8                      Emerson College
# 78                3.0  Beacon Research/Shaw & Co. Research
#
#     Predictive Plus-Minus approve_adj disapprove_adj
# 0                0.047635      37.250         42.750
# 1                0.047635      40.250         44.750
# 2                0.047635      40.250         41.750
# 3                0.047635      43.250         44.750
# 5                0.047635      38.250         44.750
# ..                    ...         ...            ...
# 93               0.411680      36.000         48.000
# 94               0.411680      38.000         49.000
# 4               -0.732433      45.765         40.235
# 72              -0.569153      33.030         43.170
# 78              -0.635562      38.420         59.580
#
# [179 rows x 33 columns]

# %%
approval = approval_adj.copy()
approval.shape
# Out:
# (179, 33)

# %%
def pipeline(data: pd.DataFrame):
    dup = data[data.duplicated(subset='poll_id')]
    ndup = data[~data.duplicated(subset='poll_id')]
    #try:
    dup_a = dup[dup['population'].isin(['a'])]
#     except ValueError:
#         print(dup['population'].isin(['a']))
    df = pd.concat([dup_a, ndup], axis=0)
    
    dup = df[df.duplicated(subset='poll_id')]
    ndup = df[~df.duplicated(subset='poll_id')]
    dup_lv = dup[dup['population'].isin(['rv'])]
    df = pd.concat([dup_lv, ndup], axis=0)
    
    df['start_date'] = pd.to_datetime(df['start_date'])
    df['end_date'] = pd.to_datetime(df['end_date'])
    
    return df

# %%
approval = approval.rename({'Predictive Plus-Minus':'pred_plus_minus'}, axis=1)

# %%
# banned_pollsters_aux = ['Rasmussen Reports', 'co/efficient', 'TIPP Insights', 'Civiqs', 'Trafalgar Group', 'OnMessage Inc.']
banned_pollsters_aux = pd.read_csv('banned_pollsters_aux.csv')['banned_pollsters'].values
banned_pollsters_aux
# Out:
# array(['Rasmussen Reports', 'co/efficient', 'TIPP Insights', 'Civiqs',
#        'Trafalgar Group', 'OnMessage Inc.', 'McLaughlin & Associates',
#        'North Star Opinion Research'], dtype=object)

# %%
approval = approval[~approval['pollster'].isin(banned_pollsters_aux)]
approval.head()
# Out:
#    poll_id  pollster_id pollster  sponsor_ids   sponsors  \
# 0    89601        568.0   YouGov        352.0  Economist
# 1    89601        568.0   YouGov        352.0  Economist
# 2    89579        568.0   YouGov        352.0  Economist
# 3    89579        568.0   YouGov        352.0  Economist
# 5    89558        568.0   YouGov        352.0  Economist
#
#              methodology  state start_date end_date  sponsor_candidate_id  \
# 0  Online Matched Sample    NaN    2/23/25  2/25/25                   NaN
# 1  Online Matched Sample    NaN    2/23/25  2/25/25                   NaN
# 2  Online Matched Sample    NaN    2/16/25  2/18/25                   NaN
# 3  Online Matched Sample    NaN    2/16/25  2/18/25                   NaN
# 5  Online Matched Sample    NaN     2/9/25  2/11/25                   NaN
#
#    ...  source  internal  partisan  approve disapprove  alternate_answers  \
# 0  ...     NaN       NaN       NaN     37.0       43.0               20.0
# 1  ...     NaN       NaN       NaN     40.0       45.0               14.0
# 2  ...     NaN       NaN       NaN     40.0       42.0               18.0
# 3  ...     NaN       NaN       NaN     43.0       45.0               12.0
# 5  ...     NaN       NaN       NaN     38.0       45.0               17.0
#
#   Pollster  pred_plus_minus approve_adj disapprove_adj
# 0   YouGov         0.047635       37.25          42.75
# 1   YouGov         0.047635       40.25          44.75
# 2   YouGov         0.047635       40.25          41.75
# 3   YouGov         0.047635       43.25          44.75
# 5   YouGov         0.047635       38.25          44.75
#
# [5 rows x 33 columns]

# %%
approval['net'] = approval['approve'] - approval['disapprove']
approval.head(1)
# Out:
#    poll_id  pollster_id pollster  sponsor_ids   sponsors  \
# 0    89601        568.0   YouGov        352.0  Economist
#
#              methodology  state start_date end_date  sponsor_candidate_id  \
# 0  Online Matched Sample    NaN    2/23/25  2/25/25                   NaN
#
#    ...  internal  partisan  approve  disapprove alternate_answers  Pollster  \
# 0  ...       NaN       NaN     37.0        43.0              20.0    YouGov
#
#   pred_plus_minus  approve_adj disapprove_adj  net
# 0        0.047635        37.25          42.75 -6.0
#
# [1 rows x 34 columns]

# %%
approval['url'] = approval['url_crosstab'].fillna(approval['url_topline']).fillna(approval['url_article'].fillna(''))

# %%
approval_polls = approval[['pollster', 'start_date', 'end_date', 'sample_size', 'population', 'approve', 'disapprove', 'approve_adj', 'disapprove_adj', 'net', 'pred_plus_minus', 'poll_id',
                          'sponsors', 'url']]
approval_polls
# Out:
#                                pollster start_date end_date  sample_size  \
# 0                                YouGov    2/23/25  2/25/25         1604
# 1                                YouGov    2/23/25  2/25/25         1444
# 2                                YouGov    2/16/25  2/18/25         1603
# 3                                YouGov    2/16/25  2/18/25         1451
# 5                                YouGov     2/9/25  2/11/25         1595
# ..                                  ...        ...      ...          ...
# 93                High Point University    5/22/24  5/29/24         1000
# 94                High Point University    5/22/24  5/29/24          850
# 4                             SurveyUSA    2/13/25  2/16/25         2000
# 72                      Emerson College    7/25/24  7/28/24         1000
# 78  Beacon Research/Shaw & Co. Research     7/7/24  7/10/24         1210
#
#    population  approve  disapprove  approve_adj  disapprove_adj   net  \
# 0           a     37.0        43.0       37.250          42.750  -6.0
# 1          rv     40.0        45.0       40.250          44.750  -5.0
# 2           a     40.0        42.0       40.250          41.750  -2.0
# 3          rv     43.0        45.0       43.250          44.750  -2.0
# 5           a     38.0        45.0       38.250          44.750  -7.0
# ..        ...      ...         ...          ...             ...   ...
# 93          a     36.0        48.0       36.000          48.000 -12.0
# 94         rv     38.0        49.0       38.000          49.000 -11.0
# 4           a     46.0        40.0       45.765          40.235   6.0
# 72         rv     33.7        42.5       33.030          43.170  -8.8
# 78         rv     38.0        60.0       38.420          59.580 -22.0
#
#     pred_plus_minus  poll_id   sponsors  \
# 0          0.047635    89601  Economist
# 1          0.047635    89601  Economist
# 2          0.047635    89579  Economist
# 3          0.047635    89579  Economist
# 5          0.047635    89558  Economist
# ..              ...      ...        ...
# 93         0.411680    87149        NaN
# 94         0.411680    87149        NaN
# 4         -0.732433    89573        NaN
# 72        -0.569153    87898        NaN
# 78        -0.635562    87393   FOX News
#
#                                                   url
# 0   https://d3nkl3psvxxpe9.cloudfront.net/document...
# 1   https://d3nkl3psvxxpe9.cloudfront.net/document...
# 2   https://d3nkl3psvxxpe9.cloudfront.net/document...
# 3   https://d3nkl3psvxxpe9.cloudfront.net/document...
# 5   https://d3nkl3psvxxpe9.cloudfront.net/document...
# ..                                                ...
# 93  https://www.highpoint.edu/src/files/2023/08/10...
# 94  https://www.highpoint.edu/src/files/2023/08/10...
# 4   https://www.surveyusa.com/client/PollReport.as...
# 72  https://docs.google.com/spreadsheets/d/1GfcxTh...
# 78  https://static.foxnews.com/foxnews.com/content...
#
# [179 rows x 14 columns]

# %%
def avgs_pipeline(data: pd.DataFrame, date: datetime.date):
    state_pivot = pipeline(data)
    # state_pivot['end_date'] = pd.to_datetime(state_pivot['end_date'])
    # state_pivot['pred_plus_minus'] = state_pivot['pred_plus_minus'].map(lambda x: -x)
    state_pivot = state_pivot[state_pivot['end_date'] <= pd.to_datetime(date)]
    # state_pivot['population'] = state_pivot['population'].astype(str).map(lambda x: x.strip())
    
    total_num_polls = state_pivot.shape[0]

    # Sample size weights
    total_sample_size = np.sum(state_pivot['sample_size'])
    state_pivot['sample_size_weights'] = (state_pivot['sample_size'].map(lambda x: np.sqrt(min(x, 3000))) / np.sqrt(np.median(state_pivot['sample_size'].map(lambda x: min(x, 2000)))))
    # print(np.median(state_pivot['sample_size'].map(lambda x: min(x, 5000))))
    state_pivot['sample_size_weights'] /= np.sum(state_pivot['sample_size_weights'])
    
    # Time weights
    # Variation of the equation used here: https://polls.votehub.us/
    latest_date = pd.Timestamp(date)
    delta = state_pivot['end_date'].apply(lambda x: (latest_date - x).days)# (latest_date - state_pivot['end_date']).apply(lambda x: x.days)
    linear_weights = delta.map(lambda x: (1 - x/(50)) if x < 50 else 0)
    exp_weights = 0.1**(delta/(40))
    state_pivot['time_weights'] =  0 * linear_weights + 1 * exp_weights
    # state_pivot['time_weights'] /= np.sum(state_pivot['time_weights'])
    
    # Quality weights
    rel_quality = state_pivot['pred_plus_minus']
    def quality_weight(rel_qual):
        if rel_qual > 0.5: # Utilizing predictive plus-minus from Silver Bulletin's ratings
            return 0.2
        # return np.sqrt(-rel_qual+1)+0.05
        return np.exp(-rel_qual/1.3)
    state_pivot['quality_weights'] = rel_quality.map(quality_weight)
    # state_pivot['quality_weights'] /= np.sum(state_pivot['quality_weights'])
    
    # Population weights
    def population_weight(population):
        if population == 'rv':
            return 0.8
        elif population == 'lv':
            return 0.6
        return 1
    state_pivot['population_weights'] = state_pivot['population'].map(population_weight)
    # state_pivot['population_weights'] /= np.sum(state_pivot['population_weights'])

    # Gather the weights together
    state_pivot['total_weights'] = state_pivot['sample_size_weights'] * state_pivot['time_weights'] * state_pivot['quality_weights'] * state_pivot['population_weights']
    state_pivot['total_weights'] /= np.sum(state_pivot['total_weights']) # Normalization step
    
    return state_pivot

# %%
avgs_pipeline(approval_polls, datetime.datetime.today())
# Out:
#                                 pollster start_date   end_date  sample_size  \
# 121                Quinnipiac University 2024-03-21 2024-03-25         1407
# 122                Quinnipiac University 2024-03-21 2024-03-25         1569
# 0                                 YouGov 2025-02-23 2025-02-25         1604
# 2                                 YouGov 2025-02-16 2025-02-18         1603
# 5                                 YouGov 2025-02-09 2025-02-11         1595
# ..                                   ...        ...        ...          ...
# 75                                Gallup 2024-07-01 2024-07-21         1010
# 93                 High Point University 2024-05-22 2024-05-29         1000
# 4                              SurveyUSA 2025-02-13 2025-02-16         2000
# 72                       Emerson College 2024-07-25 2024-07-28         1000
# 78   Beacon Research/Shaw & Co. Research 2024-07-07 2024-07-10         1210
#
#     population  approve  disapprove  approve_adj  disapprove_adj   net  \
# 121         rv     34.0        58.0       34.265          57.735 -24.0
# 122          a     32.0        58.0       32.265          57.735 -26.0
# 0            a     37.0        43.0       37.250          42.750  -6.0
# 2            a     40.0        42.0       40.250          41.750  -2.0
# 5            a     38.0        45.0       38.250          44.750  -7.0
# ..         ...      ...         ...          ...             ...   ...
# 75           a     43.0        52.0       42.155          52.845  -9.0
# 93           a     36.0        48.0       36.000          48.000 -12.0
# 4            a     46.0        40.0       45.765          40.235   6.0
# 72          rv     33.7        42.5       33.030          43.170  -8.8
# 78          rv     38.0        60.0       38.420          59.580 -22.0
#
#      pred_plus_minus  poll_id   sponsors  \
# 121        -0.290484    86559        NaN
# 122        -0.290484    86559        NaN
# 0           0.047635    89601  Economist
# 2           0.047635    89579  Economist
# 5           0.047635    89558  Economist
# ..               ...      ...        ...
# 75         -0.096810    87535        NaN
# 93          0.411680    87149        NaN
# 4          -0.732433    89573        NaN
# 72         -0.569153    87898        NaN
# 78         -0.635562    87393   FOX News
#
#                                                    url  sample_size_weights  \
# 121    https://poll.qu.edu/poll-release?releaseid=3894             0.010452
# 122  https://poll.qu.edu/images/polling/us/us032720...             0.011037
# 0    https://d3nkl3psvxxpe9.cloudfront.net/document...             0.011159
# 2    https://d3nkl3psvxxpe9.cloudfront.net/document...             0.011156
# 5    https://d3nkl3psvxxpe9.cloudfront.net/document...             0.011128
# ..                                                 ...                  ...
# 75   https://news.gallup.com/poll/647834/approval-s...             0.008855
# 93   https://www.highpoint.edu/src/files/2023/08/10...             0.008811
# 4    https://www.surveyusa.com/client/PollReport.as...             0.012461
# 72   https://docs.google.com/spreadsheets/d/1GfcxTh...             0.008811
# 78   https://static.foxnews.com/foxnews.com/content...             0.009692
#
#      time_weights  quality_weights  population_weights  total_weights
# 121  1.778279e-10         1.250382                 0.8   4.645349e-11
# 122  1.778279e-10         1.250382                 1.0   6.131868e-11
# 0    4.731513e-02         0.964021                 1.0   1.271825e-02
# 2    3.162278e-02         0.964021                 1.0   8.497512e-03
# 5    2.113489e-02         0.964021                 1.0   5.665071e-03
# ..            ...              ...                 ...            ...
# 75   1.584893e-07         1.077313                 1.0   3.777817e-08
# 93   7.498942e-09         0.728566                 1.0   1.202839e-09
# 4    2.818383e-02         1.756652                 1.0   1.541485e-02
# 72   2.371374e-07         1.549311                 0.8   6.470936e-08
# 78   8.413951e-08         1.630512                 0.8   2.657940e-08
#
# [93 rows x 19 columns]

# %%
def approval_over_time(data: pd.DataFrame):
    date_range = pd.date_range(start=datetime.date(2024, 4, 1), end=datetime.datetime.today(), freq='d', inclusive='both')
    yes_averages = []
    no_averages = []
    yes_stdevs = []
    no_stdevs = []
    for date in date_range:
        pipelined_df = avgs_pipeline(data, date)
        yes_avg = np.sum(pipelined_df['approve_adj'] * pipelined_df['total_weights'])
        no_avg = np.sum(pipelined_df['disapprove_adj'] * pipelined_df['total_weights'])
        yes_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['approve_adj'] - yes_avg)**2))
        no_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['disapprove_adj'] - no_avg)**2))
        yes_averages.append(yes_avg)
        no_averages.append(no_avg)
        yes_stdevs.append(yes_std)
        no_stdevs.append(no_std)
    
    return pd.DataFrame({'Date':date_range, 'Approve':yes_averages, 'Disapprove':no_averages}), pd.DataFrame({'Date':date_range, 'Approve':yes_stdevs, 'Disapprove':no_stdevs}), avgs_pipeline(data, datetime.datetime.today())

# %%
approval_avg, approval_std, polls_df = approval_over_time(approval_polls)
approval_avg
# Out:
#           Date    Approve  Disapprove
# 0   2024-04-01  38.792522   52.514938
# 1   2024-04-02  38.007592   52.728352
# 2   2024-04-03  38.007592   52.728352
# 3   2024-04-04  38.007592   52.728352
# 4   2024-04-05  38.007592   52.728352
# ..         ...        ...         ...
# 379 2025-04-15  40.705668   45.442687
# 380 2025-04-16  40.705668   45.442687
# 381 2025-04-17  40.705668   45.442687
# 382 2025-04-18  40.705668   45.442687
# 383 2025-04-19  40.705668   45.442687
#
# [384 rows x 3 columns]

# %%
polls_df.shape
# Out:
# (93, 19)

# %%
display_df = polls_df[['pollster', 'sponsors', 'start_date', 'end_date', 'sample_size', 'population', 'approve', 'disapprove', 'net',
                      'total_weights', 'url']]
display_df['sponsors'] = '^Sponsor: ' + display_df['sponsors'] + '^'
display_df['sponsors'] = display_df['sponsors'].fillna('')
display_df = display_df.sort_values(['end_date'], ascending=False)
display_df = display_df.rename({'pollster':'Pollster', 'approve':'Approve', 'disapprove':'Disapprove', 'net':'Net', 'total_weights':'Weight', 'start_date':'Start Date', 'end_date':'End Date', 'url':'URL'}, axis='columns')
display_df['Sample'] = display_df['sample_size'].astype(int).astype(str) + ' ' + display_df['population'].map(lambda x: x.upper())
# display_df['end_date'] = display_df['end_date'].map(lambda x: datetime.datetime.strptime(datetime.datetime.fromtimestamp(x), '%m/%d/%Y').strftime('%Y-%m-%d'))
# display_df['Date'] = pd.to_datetime(display_df['startdate']).astype(str) + ' - ' + display_df['end_date'].astype(str)
display_df['Start Date'] = pd.to_datetime(display_df['Start Date']).astype(str)
display_df['End Date'] = display_df['End Date'].astype(str)
display_df = display_df.reset_index()
# display_df = display_df.drop(['sample_size', 'population'], axis='columns')
display_df['Pollster'] = '<a href="' + display_df['URL'] + '" style="color:black; text-decoration:underline;"><u>' + display_df['Pollster'] + '</u></a>' + display_df['sponsors']
# display_df['Pollster'] = '[' + display_df['Pollster'] + '](' + display_df['URL'] + ')'
display_df = display_df[['Pollster', 'Start Date', 'End Date', 'Sample', 'Weight', 'Approve', 'Disapprove', 'Net']]
# display_df = display_df.set_index(['Pollster'])
display_df
# Out:
#                                              Pollster  Start Date    End Date  \
# 0   <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2025-04-13  2025-04-15
# 1   <a href="https://napolitannews.org/posts/supre...  2025-04-09  2025-04-10
# 2   <a href="https://www.umass.edu/political-scien...  2025-04-04  2025-04-09
# 3   <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2025-04-05  2025-04-08
# 4   <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2025-03-30  2025-04-01
# ..                                                ...         ...         ...
# 88  <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2023-12-31  2024-01-02
# 89  <a href="https://twitter.com/RMG_Research/stat...  2023-12-20  2023-12-21
# 90  <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2023-12-16  2023-12-18
# 91  <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2023-12-09  2023-12-12
# 92  <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2023-12-02  2023-12-05
#
#      Sample        Weight  Approve  Disapprove   Net
# 0    1512 A  2.073008e-01     38.0        45.0  -7.0
# 1   1000 RV  8.471274e-02     50.0        42.0   8.0
# 2    1000 A  1.193507e-01     38.0        48.0 -10.0
# 3    1741 A  1.486704e-01     34.0        49.0 -15.0
# 4    1626 A  9.602521e-02     35.0        46.0 -11.0
# ..      ...           ...      ...         ...   ...
# 88   1521 A  3.916423e-13     38.0        47.0  -9.0
# 89  1000 RV  1.066470e-13     41.0        51.0 -10.0
# 90   1500 A  1.640101e-13     36.0        46.0 -10.0
# 91   1500 A  1.161103e-13     35.0        51.0 -16.0
# 92   1500 A  7.760159e-14     35.0        49.0 -14.0
#
# [93 rows x 8 columns]

# %%
display_df.to_csv('scotus_approval_polls_display_table.csv')

# %%
approval_avg['Net'] = approval_avg['Approve'] - approval_avg['Disapprove']
approval_avg
# Out:
#           Date    Approve  Disapprove        Net
# 0   2024-04-01  38.792522   52.514938 -13.722416
# 1   2024-04-02  38.007592   52.728352 -14.720760
# 2   2024-04-03  38.007592   52.728352 -14.720760
# 3   2024-04-04  38.007592   52.728352 -14.720760
# 4   2024-04-05  38.007592   52.728352 -14.720760
# ..         ...        ...         ...        ...
# 379 2025-04-15  40.705668   45.442687  -4.737020
# 380 2025-04-16  40.705668   45.442687  -4.737020
# 381 2025-04-17  40.705668   45.442687  -4.737020
# 382 2025-04-18  40.705668   45.442687  -4.737020
# 383 2025-04-19  40.705668   45.442687  -4.737020
#
# [384 rows x 4 columns]

# %%
approval_trendline = pd.merge(left=approval_avg, right=approval_std, left_on='Date', right_on='Date', how='inner')
approval_trendline['approve_CI_upper'] = approval_trendline['Approve_x'] + 1.96*approval_trendline['Approve_y']
approval_trendline['approve_CI_lower'] = approval_trendline['Approve_x'] - 1.96*approval_trendline['Approve_y']
approval_trendline['disapprove_CI_upper'] = approval_trendline['Disapprove_x'] + 1.96*approval_trendline['Disapprove_y']
approval_trendline['disapprove_CI_lower'] = approval_trendline['Disapprove_x'] - 1.96*approval_trendline['Disapprove_y']
approval_trendline = approval_trendline.rename({
    'Approve_x':'approve_mean',
    'Disapprove_x':'disapprove_mean',
}, axis='columns').drop(['Approve_y', 'Disapprove_y', 'Net'], axis='columns')
approval_trendline
# Out:
#           Date  approve_mean  disapprove_mean  approve_CI_upper  \
# 0   2024-04-01     38.792522        52.514938         50.440419
# 1   2024-04-02     38.007592        52.728352         49.123357
# 2   2024-04-03     38.007592        52.728352         49.123357
# 3   2024-04-04     38.007592        52.728352         49.123357
# 4   2024-04-05     38.007592        52.728352         49.123357
# ..         ...           ...              ...               ...
# 379 2025-04-15     40.705668        45.442687         53.635781
# 380 2025-04-16     40.705668        45.442687         53.635781
# 381 2025-04-17     40.705668        45.442687         53.635781
# 382 2025-04-18     40.705668        45.442687         53.635781
# 383 2025-04-19     40.705668        45.442687         53.635781
#
#      approve_CI_lower  disapprove_CI_upper  disapprove_CI_lower
# 0           27.144625            62.030077            42.999799
# 1           26.891826            61.430700            44.026003
# 2           26.891826            61.430700            44.026003
# 3           26.891826            61.430700            44.026003
# 4           26.891826            61.430700            44.026003
# ..                ...                  ...                  ...
# 379         27.775554            49.995827            40.889548
# 380         27.775554            49.995827            40.889548
# 381         27.775554            49.995827            40.889548
# 382         27.775554            49.995827            40.889548
# 383         27.775554            49.995827            40.889548
#
# [384 rows x 7 columns]

# %%
# Export approval ratings
approval_trendline.to_csv('scotus_approval_stats.csv')

# %%
line = px.line(approval_avg, x='Date', y=['Approve', 'Disapprove'])
# scatter = px.scatter(polls_df[polls_df['end_date'] >= pd.to_datetime('2025-01-24')], x='end_date', y=['approve', 'disapprove'])
line.update_traces(hovertemplate=None)
line.update_layout(hovermode='x unified')
# scatter.update_traces(hovertemplate=None, hoverinfo='skip')
fig_approve_CI = go.Figure([
    go.Scatter(
        name='Approve CI Upper Bound',
        x = approval_avg['Date'],
        y = approval_avg['Approve'] + 1.96*approval_std['Approve'],
        mode='lines',
        marker=dict(color='#8be8f2'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),
    go.Scatter(
        name='Approve CI Lower Bound',
        x = approval_avg['Date'],
        y = approval_avg['Approve'] - 1.96*approval_std['Approve'],
        mode='lines',
        marker=dict(color='#8be8f2'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),  
])
fig_disapprove_CI = go.Figure([
    go.Scatter(
        name='Disapprove CI Upper Bound',
        x = approval_avg['Date'],
        y = approval_avg['Disapprove'] + 1.96*approval_std['Disapprove'],
        mode='lines',
        marker=dict(color='#a3cbec'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),
    go.Scatter(
        name='Disapprove CI Lower Bound',
        x = approval_avg['Date'],
        y = approval_avg['Disapprove'] - 1.96*approval_std['Disapprove'],
        mode='lines',
        marker=dict(color='#a3cbec'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),  
])

fig = go.Figure(data=line.data + fig_approve_CI.data + fig_disapprove_CI.data)
fig.update_layout(
    title='SCOTUS Approval Rating',
    xaxis_title='Date',
    yaxis_title='%',
    legend_title='Legend',
    hovermode='x unified'
)
fig.show()
# Out:
# <div>                            <div id="882d5216-2e28-4d45-9ba5-24d2df08fa16" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("882d5216-2e28-4d45-9ba5-24d2df08fa16")) {                    Plotly.newPlot(                        "882d5216-2e28-4d45-9ba5-24d2df08fa16",                        [{"legendgroup":"Approve","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Approve","orientation":"v","showlegend":true,"x":["2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00","2024-08-06T00:00:00","2024-08-07T00:00:00","2024-08-08T00:00:00","2024-08-09T00:00:00","2024-08-10T00:00:00","2024-08-11T00:00:00","2024-08-12T00:00:00","2024-08-13T00:00:00","2024-08-14T00:00:00","2024-08-15T00:00:00","2024-08-16T00:00:00","2024-08-17T00:00:00","2024-08-18T00:00:00","2024-08-19T00:00:00","2024-08-20T00:00:00","2024-08-21T00:00:00","2024-08-22T00:00:00","2024-08-23T00:00:00","2024-08-24T00:00:00","2024-08-25T00:00:00","2024-08-26T00:00:00","2024-08-27T00:00:00","2024-08-28T00:00:00", ...

# %%
line = px.line(approval_avg, x='Date', y=['Net'])
scatter = px.scatter(polls_df[polls_df['end_date'] >= pd.to_datetime('2024-04-01')], x='end_date', y=['net'])
fig = go.Figure(data=line.data + scatter.data)
fig.add_hline(y=0, line_dash='dash')
fig.show()
# Out:
# <div>                            <div id="70dc8815-2ece-47f4-90fe-dfb8c3b819e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70dc8815-2ece-47f4-90fe-dfb8c3b819e7")) {                    Plotly.newPlot(                        "70dc8815-2ece-47f4-90fe-dfb8c3b819e7",                        [{"hovertemplate":"variable=Net\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Net","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Net","orientation":"v","showlegend":true,"x":["2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-06T00:00:00","2024-04-07T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-13T00:00:00","2024-04-14T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-20T00:00:00","2024-04-21T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-27T00:00:00","2024-04-28T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-04T00:00:00","2024-05-05T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-11T00:00:00","2024-05-12T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-18T00:00:00","2024-05-19T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-25T00:00:00","2024-05-26T00:00:00","2024-05-27T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-01T00:00:00","2024-06-02T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-08T00:00:00","2024-06-09T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-15T00:00:00","2024-06-16T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-19T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-22T00:00:00","2024-06-23T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-06-29T00:00:00","2024-06-30T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-04T00:00:00","2024-07-05T00:00:00","2024-07-06T00:00:00","2024-07-07T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-13T00:00:00","2024-07-14T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-20T00:00:00","2024-07-21T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-27T00:00:00","2024-07-28T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-03T00:00:00","2024-08-04T00:00:00","2024-08-05T00:00:00","2024-08-06T00:00:00","2024-08-07T00:00:00","2024-08-08T00:00:00","2024-08-09T00:00:00","2024-08-10T00:00:00","2024-08-11T00:00:00","2024-08-12T00:00:00","2024-08-13T00:00:00","2024-08-14T00:00:00","2024-08-15T00:00:00","2024-08-16T00:00:00","2024-08-17T00:00:00","2024-08-18T00:00:00","2024-08-19T00:00:00","2024-08-20T00:00:00","2024-08-21T00:00:00","2024-08-22T00:00:00","2024-08-23T00:00:00", ...
