# %%
import numpy as np
import pandas as pd
import scipy
from scipy.optimize import minimize
import plotly.express as px
import plotly.graph_objects as go
import datetime

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://docs.google.com/spreadsheets/d/1_y0_LJmSY6sNx8qd51T70n0oa_ugN50AVFKuJmXO1-s/export?format=csv&gid=2042605142'
approval = pd.read_csv(url)
approval
# Out:
#      poll_id  pollster_id          pollster sponsor_ids             sponsors  \
# 0      89437         1347            Cygnal         NaN                  NaN
# 1      89445          294        McLaughlin         NaN                  NaN
# 2      89491         1347            Cygnal         NaN                  NaN
# 3      89497         1554      RMG Research        2178  Napolitan Institute
# 4      89511         1895  Quantus Insights        2184     TrendingPolitics
# ..       ...          ...               ...         ...                  ...
# 122    90539          568            YouGov         352        The Economist
# 123    90542          568            YouGov        1213           Yahoo News
# 124    90617         1347            Cygnal         NaN                  NaN
# 125    90614          568            YouGov         352        The Economist
# 126    90614          568            YouGov         352        The Economist
#
#      sponsor_candidate_id  sponsor_candidate  sponsor_candidate_party  \
# 0                     NaN                NaN                      NaN
# 1                     NaN                NaN                      NaN
# 2                     NaN                NaN                      NaN
# 3                     NaN                NaN                      NaN
# 4                     NaN                NaN                      NaN
# ..                    ...                ...                      ...
# 122                   NaN                NaN                      NaN
# 123                   NaN                NaN                      NaN
# 124                   NaN                NaN                      NaN
# 125                   NaN                NaN                      NaN
# 126                   NaN                NaN                      NaN
#
#                 display_name                   mode  ...  \
# 0                     Cygnal                    NaN  ...
# 1    McLaughlin & Associates    Online Opt-In Panel  ...
# 2                     Cygnal                    NaN  ...
# 3               RMG Research    Online Opt-In Panel  ...
# 4           Quantus Insights    Online Opt-In Panel  ...
# ..                       ...                    ...  ...
# 122                   YouGov  Online Matched Sample  ...
# 123                   YouGov  Online Matched Sample  ...
# 124                   Cygnal                    NaN  ...
# 125                   YouGov  Online Matched Sample  ...
# 126                   YouGov  Online Matched Sample  ...
#
#                                            url_topline  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 122  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 123                                                NaN
# 124                                                NaN
# 125  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 126  https://d3nkl3psvxxpe9.cloudfront.net/document...
#
#                                           url_crosstab race_id  cycle  \
# 0    https://www.cygn.al/wp-content/uploads/2024/12...   16444   2026
# 1    https://mclaughlinonline.com/pols/wp-content/u...   16444   2026
# 2    https://www.cygn.al/wp-content/uploads/2025/01...   16444   2026
# 3                                                  NaN   16444   2026
# 4    https://drive.google.com/file/d/1d1e9IDGzoiE2S...   16444   2026
# ..                                                 ...     ...    ...
# 122  https://d3nkl3psvxxpe9.cloudfront.net/document...   16444   2026
# 123  https://www.scribd.com/document/911899946/Yaho...   16444   2026
# 124  https://www.cygn.al/wp-content/uploads/2025/09...   16444   2026
# 125  https://d3nkl3psvxxpe9.cloudfront.net/document...   16444   2026
# 126  https://d3nkl3psvxxpe9.cloudfront.net/document...   16444   2026
#
#     office_type       seat_name  election_date    stage   dem   rep
# 0    U.S. House  Generic Ballot     2026-11-03  general  44.6  48.4
# 1    U.S. House  Generic Ballot     2026-11-03  general  42.0  47.0
# 2    U.S. House  Generic Ballot     2026-11-03  general  44.6  46.8
# 3    U.S. House  Generic Ballot     2026-11-03  general  44.0  51.0
# 4    U.S. House  Generic Ballot     2026-11-03  general  45.0  48.0
# ..          ...             ...            ...      ...   ...   ...
# 122  U.S. House  Generic Ballot     2026-11-03  general  43.0  39.0
# 123  U.S. House  Generic Ballot     2026-11-03  general  44.0  40.0
# 124  U.S. House  Generic Ballot     2026-11-03  general  47.6  45.2
# 125  U.S. House  Generic Ballot     2026-11-03  general  39.0  36.0
# 126  U.S. House  Generic Ballot     2026-11-03  general  44.0  40.0
#
# [127 rows x 36 columns]

# %%
approval = approval[~approval['poll_id'].isna()]
approval
# Out:
#      poll_id  pollster_id          pollster sponsor_ids             sponsors  \
# 0      89437         1347            Cygnal         NaN                  NaN
# 1      89445          294        McLaughlin         NaN                  NaN
# 2      89491         1347            Cygnal         NaN                  NaN
# 3      89497         1554      RMG Research        2178  Napolitan Institute
# 4      89511         1895  Quantus Insights        2184     TrendingPolitics
# ..       ...          ...               ...         ...                  ...
# 122    90539          568            YouGov         352        The Economist
# 123    90542          568            YouGov        1213           Yahoo News
# 124    90617         1347            Cygnal         NaN                  NaN
# 125    90614          568            YouGov         352        The Economist
# 126    90614          568            YouGov         352        The Economist
#
#      sponsor_candidate_id  sponsor_candidate  sponsor_candidate_party  \
# 0                     NaN                NaN                      NaN
# 1                     NaN                NaN                      NaN
# 2                     NaN                NaN                      NaN
# 3                     NaN                NaN                      NaN
# 4                     NaN                NaN                      NaN
# ..                    ...                ...                      ...
# 122                   NaN                NaN                      NaN
# 123                   NaN                NaN                      NaN
# 124                   NaN                NaN                      NaN
# 125                   NaN                NaN                      NaN
# 126                   NaN                NaN                      NaN
#
#                 display_name                   mode  ...  \
# 0                     Cygnal                    NaN  ...
# 1    McLaughlin & Associates    Online Opt-In Panel  ...
# 2                     Cygnal                    NaN  ...
# 3               RMG Research    Online Opt-In Panel  ...
# 4           Quantus Insights    Online Opt-In Panel  ...
# ..                       ...                    ...  ...
# 122                   YouGov  Online Matched Sample  ...
# 123                   YouGov  Online Matched Sample  ...
# 124                   Cygnal                    NaN  ...
# 125                   YouGov  Online Matched Sample  ...
# 126                   YouGov  Online Matched Sample  ...
#
#                                            url_topline  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 122  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 123                                                NaN
# 124                                                NaN
# 125  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 126  https://d3nkl3psvxxpe9.cloudfront.net/document...
#
#                                           url_crosstab race_id  cycle  \
# 0    https://www.cygn.al/wp-content/uploads/2024/12...   16444   2026
# 1    https://mclaughlinonline.com/pols/wp-content/u...   16444   2026
# 2    https://www.cygn.al/wp-content/uploads/2025/01...   16444   2026
# 3                                                  NaN   16444   2026
# 4    https://drive.google.com/file/d/1d1e9IDGzoiE2S...   16444   2026
# ..                                                 ...     ...    ...
# 122  https://d3nkl3psvxxpe9.cloudfront.net/document...   16444   2026
# 123  https://www.scribd.com/document/911899946/Yaho...   16444   2026
# 124  https://www.cygn.al/wp-content/uploads/2025/09...   16444   2026
# 125  https://d3nkl3psvxxpe9.cloudfront.net/document...   16444   2026
# 126  https://d3nkl3psvxxpe9.cloudfront.net/document...   16444   2026
#
#     office_type       seat_name  election_date    stage   dem   rep
# 0    U.S. House  Generic Ballot     2026-11-03  general  44.6  48.4
# 1    U.S. House  Generic Ballot     2026-11-03  general  42.0  47.0
# 2    U.S. House  Generic Ballot     2026-11-03  general  44.6  46.8
# 3    U.S. House  Generic Ballot     2026-11-03  general  44.0  51.0
# 4    U.S. House  Generic Ballot     2026-11-03  general  45.0  48.0
# ..          ...             ...            ...      ...   ...   ...
# 122  U.S. House  Generic Ballot     2026-11-03  general  43.0  39.0
# 123  U.S. House  Generic Ballot     2026-11-03  general  44.0  40.0
# 124  U.S. House  Generic Ballot     2026-11-03  general  47.6  45.2
# 125  U.S. House  Generic Ballot     2026-11-03  general  39.0  36.0
# 126  U.S. House  Generic Ballot     2026-11-03  general  44.0  40.0
#
# [127 rows x 36 columns]

# %%
approval.columns.values
# Out:
# array(['poll_id', 'pollster_id', 'pollster', 'sponsor_ids', 'sponsors',
#        'sponsor_candidate_id', 'sponsor_candidate',
#        'sponsor_candidate_party', 'display_name', 'mode', 'state',
#        'start_date', 'end_date', 'internal', 'partisan', 'question_id',
#        'sample_size', 'population', 'subpopulation', 'population_full',
#        'tracking', 'created_at', 'updated_at', 'notes', 'url',
#        'url_article', 'url_topline', 'url_crosstab', 'race_id', 'cycle',
#        'office_type', 'seat_name', 'election_date', 'stage', 'dem', 'rep'],
#       dtype=object)

# %%
# morris_to_silver_dict = {
#     'HarrisX/Harris Poll':'Harris Insights & Analytics',
#     'Clarity': 'Clarity Campaign Labs',
#     'Beacon/Shaw': 'Beacon Research/Shaw & Co. Research',
#     'Monmouth': 'Monmouth University',
#     'HarrisX': 'Harris Insights & Analytics',
#     'UMass Amherst/YouGov': 'YouGov',
#     'Emerson': 'Emerson College',
#     'Marquette Law School': 'Marquette University Law School',
#     'NewsNation/Decision Desk HQ': 'NewsNation',
#     'CNN/SSRS': 'SSRS',
#     'Suffolk': 'Suffolk University',
#     'Harris Poll': 'Harris Insights & Analytics',
#     'Fabrizio/Impact': 'Fabrizio Lee & Associates/Impact Research',
#     'Winston': 'The Winston Group',
#     'Hart/POS': 'Hart Research Associates/Public Opinion Strategies',
#     'Quinnipiac': 'Quinnipiac University',
#     'Siena/NYT': 'The New York Times/Siena College',
#     'Noble Predictive Insights': 'OH Predictive Insights',
#     'McLaughlin': 'McLaughlin & Associates'
# }

# %%
pollsters_short = np.unique(approval['pollster'])
pollsters_long = np.unique(approval['display_name'])

# %%
pollsters_short, pollsters_long
# Out:
# (array(['American Pulse', 'AtlasIntel', 'Beacon/Shaw', 'Big Data Poll',
#         'Clarity', 'Cygnal', 'Echelon Insights', 'Emerson',
#         'Fabrizio Ward', 'Fabrizio/Impact', 'Hart/POS', 'Ipsos',
#         'J.L. Partners', 'McLaughlin', 'Morning Consult',
#         'NewsNation/Decision Desk HQ', 'Noble Predictive Insights',
#         'Normington, Petts & Associates', 'Public Opinion Strategies',
#         'Quantus Insights', 'RMG Research', 'RealClear Opinion Research',
#         'Siena/NYT', 'SoCal Strategies', 'Verasight',
#         'Verasight/The Argument', 'Winston', 'Yale Youth Poll', 'YouGov',
#         'co/efficient'], dtype=object),
#  array(['American Pulse Research & Polling', 'AtlasIntel',
#         'Beacon Research/Shaw & Co. Research', 'Big Data Poll',
#         'Clarity Campaign Labs', 'Cygnal', 'Echelon Insights',
#         'Emerson College', 'Fabrizio Ward',
#         'Fabrizio, Lee & Associates/Impact Research',
#         'Hart Research Associates/Public Opinion Strategies', 'Ipsos',
#         'J.L. Partners', 'McLaughlin & Associates', 'Morning Consult',
#         'NewsNation', 'Noble Predictive Insights',
#         'Normington, Petts & Associates', 'Public Opinion Strategies',
#         'Quantus Insights', 'RMG Research', 'RealClear Opinion Research',
#         'SoCal Strategies', 'The Argument/Verasight',
#         'The New York Times/Siena College', 'The Winston Group',
#         'Verasight',
#         'Yale University Institution for Social and Policy Studies',
#         'YouGov', 'co/efficient'], dtype=object))

# %%
pollsters_short.shape, pollsters_long.shape
# Out:
# ((30,), (30,))

# %%
morris_to_silver_dict = {short: long for short, long in zip(pollsters_short, pollsters_long)}
morris_to_silver_dict
# Out:
# {'American Pulse': 'American Pulse Research & Polling',
#  'AtlasIntel': 'AtlasIntel',
#  'Beacon/Shaw': 'Beacon Research/Shaw & Co. Research',
#  'Big Data Poll': 'Big Data Poll',
#  'Clarity': 'Clarity Campaign Labs',
#  'Cygnal': 'Cygnal',
#  'Echelon Insights': 'Echelon Insights',
#  'Emerson': 'Emerson College',
#  'Fabrizio Ward': 'Fabrizio Ward',
#  'Fabrizio/Impact': 'Fabrizio, Lee & Associates/Impact Research',
#  'Hart/POS': 'Hart Research Associates/Public Opinion Strategies',
#  'Ipsos': 'Ipsos',
#  'J.L. Partners': 'J.L. Partners',
#  'McLaughlin': 'McLaughlin & Associates',
#  'Morning Consult': 'Morning Consult',
#  'NewsNation/Decision Desk HQ': 'NewsNation',
#  'Noble Predictive Insights': 'Noble Predictive Insights',
#  'Normington, Petts & Associates': 'Normington, Petts & Associates',
#  'Public Opinion Strategies': 'Public Opinion Strategies',
#  'Quantus Insights': 'Quantus Insights',
#  'RMG Research': 'RMG Research',
#  'RealClear Opinion Research': 'RealClear Opinion Research',
#  'Siena/NYT': 'SoCal Strategies',
#  'SoCal Strategies': 'The Argument/Verasight',
#  'Verasight': 'The New York Times/Siena College',
#  'Verasight/The Argument': 'The Winston Group',
#  'Winston': 'Verasight',
#  'Yale Youth Poll': 'Yale University Institution for Social and Policy Studies',
#  'YouGov': 'YouGov',
#  'co/efficient': 'co/efficient'}

# %%
morris_to_silver_dict.update({
    'HarrisX/Harris Poll':'Harris Insights & Analytics',
    'Clarity': 'Clarity Campaign Labs',
    'Beacon/Shaw': 'Beacon Research/Shaw & Co. Research',
    'Monmouth': 'Monmouth University',
    'HarrisX': 'Harris Insights & Analytics',
    'UMass Amherst/YouGov': 'YouGov',
    'Emerson': 'Emerson College',
    'Marquette Law School': 'Marquette University Law School',
    'NewsNation/Decision Desk HQ': 'NewsNation',
    'CNN/SSRS': 'SSRS',
    'Suffolk': 'Suffolk University',
    'Harris Poll': 'Harris Insights & Analytics',
    'Fabrizio/Impact': 'Fabrizio Lee & Associates/Impact Research',
    'Winston': 'Verasight',
    'Verasight': 'Verasight',
    'Hart/POS': 'Hart Research Associates/Public Opinion Strategies',
    'Quinnipiac': 'Quinnipiac University',
    'Siena/NYT': 'The New York Times/Siena College',
    'Noble Predictive Insights': 'OH Predictive Insights',
    'McLaughlin': 'McLaughlin & Associates',
})

# %%
morris_to_silver_dict
# Out:
# {'American Pulse': 'American Pulse Research & Polling',
#  'AtlasIntel': 'AtlasIntel',
#  'Beacon/Shaw': 'Beacon Research/Shaw & Co. Research',
#  'Big Data Poll': 'Big Data Poll',
#  'Clarity': 'Clarity Campaign Labs',
#  'Cygnal': 'Cygnal',
#  'Echelon Insights': 'Echelon Insights',
#  'Emerson': 'Emerson College',
#  'Fabrizio Ward': 'Fabrizio Ward',
#  'Fabrizio/Impact': 'Fabrizio Lee & Associates/Impact Research',
#  'Hart/POS': 'Hart Research Associates/Public Opinion Strategies',
#  'Ipsos': 'Ipsos',
#  'J.L. Partners': 'J.L. Partners',
#  'McLaughlin': 'McLaughlin & Associates',
#  'Morning Consult': 'Morning Consult',
#  'NewsNation/Decision Desk HQ': 'NewsNation',
#  'Noble Predictive Insights': 'OH Predictive Insights',
#  'Normington, Petts & Associates': 'Normington, Petts & Associates',
#  'Public Opinion Strategies': 'Public Opinion Strategies',
#  'Quantus Insights': 'Quantus Insights',
#  'RMG Research': 'RMG Research',
#  'RealClear Opinion Research': 'RealClear Opinion Research',
#  'Siena/NYT': 'The New York Times/Siena College',
#  'SoCal Strategies': 'The Argument/Verasight',
#  'Verasight': 'Verasight',
#  'Verasight/The Argument': 'The Winston Group',
#  'Winston': 'Verasight',
#  'Yale Youth Poll': 'Yale University Institution for Social and Policy Studies',
#  'YouGov': 'YouGov',
#  'co/efficient': 'co/efficient',
#  'HarrisX/Harris Poll': 'Harris Insights & Analytics',
#  'Monmouth': 'Monmouth University',
#  'HarrisX': 'Harris Insights & Analytics',
#  'UMass Amherst/YouGov': 'YouGov',
#  'Marquette Law School': 'Marquette University Law School',
#  'CNN/SSRS': 'SSRS',
#  'Suffolk': 'Suffolk University',
#  'Harris Poll': 'Harris Insights & Analytics',
#  'Quinnipiac': 'Quinnipiac University'}

# %%
approval['pollster'] = approval['pollster'].replace(morris_to_silver_dict)
approval = approval.rename({'population':'population_empty'}, axis='columns')
approval = approval.rename({'population_full':'population'}, axis='columns')
approval.head(7)
# Out:
#    poll_id  pollster_id                                   pollster  \
# 0    89437         1347                                     Cygnal
# 1    89445          294                    McLaughlin & Associates
# 2    89491         1347                                     Cygnal
# 3    89497         1554                               RMG Research
# 4    89511         1895                           Quantus Insights
# 5    89530          294                    McLaughlin & Associates
# 6    89555         1699  Fabrizio Lee & Associates/Impact Research
#
#   sponsor_ids             sponsors  sponsor_candidate_id  sponsor_candidate  \
# 0         NaN                  NaN                   NaN                NaN
# 1         NaN                  NaN                   NaN                NaN
# 2         NaN                  NaN                   NaN                NaN
# 3        2178  Napolitan Institute                   NaN                NaN
# 4        2184     TrendingPolitics                   NaN                NaN
# 5         NaN                  NaN                   NaN                NaN
# 6          42                 AARP                   NaN                NaN
#
#    sponsor_candidate_party                                display_name  \
# 0                      NaN                                      Cygnal
# 1                      NaN                     McLaughlin & Associates
# 2                      NaN                                      Cygnal
# 3                      NaN                                RMG Research
# 4                      NaN                            Quantus Insights
# 5                      NaN                     McLaughlin & Associates
# 6                      NaN  Fabrizio, Lee & Associates/Impact Research
#
#                               mode  ...  url_topline  \
# 0                              NaN  ...          NaN
# 1              Online Opt-In Panel  ...          NaN
# 2                              NaN  ...          NaN
# 3              Online Opt-In Panel  ...          NaN
# 4              Online Opt-In Panel  ...          NaN
# 5              Online Opt-In Panel  ...          NaN
# 6  Online Opt-In Panel/Text-to-Web  ...          NaN
#
#                                         url_crosstab race_id  cycle  \
# 0  https://www.cygn.al/wp-content/uploads/2024/12...   16444   2026
# 1  https://mclaughlinonline.com/pols/wp-content/u...   16444   2026
# 2  https://www.cygn.al/wp-content/uploads/2025/01...   16444   2026
# 3                                                NaN   16444   2026
# 4  https://drive.google.com/file/d/1d1e9IDGzoiE2S...   16444   2026
# 5  https://mclaughlinonline.com/pols/wp-content/u...   16444   2026
# 6  https://www.aarp.org/content/dam/aarp/research...   16444   2026
#
#   office_type       seat_name  election_date    stage   dem   rep
# 0  U.S. House  Generic Ballot     2026-11-03  general  44.6  48.4
# 1  U.S. House  Generic Ballot     2026-11-03  general  42.0  47.0
# 2  U.S. House  Generic Ballot     2026-11-03  general  44.6  46.8
# 3  U.S. House  Generic Ballot     2026-11-03  general  44.0  51.0
# 4  U.S. House  Generic Ballot     2026-11-03  general  45.0  48.0
# 5  U.S. House  Generic Ballot     2026-11-03  general  40.0  48.0
# 6  U.S. House  Generic Ballot     2026-11-03  general  43.0  43.0
#
# [7 rows x 36 columns]

# %%
approval.shape
# Out:
# (127, 36)

# %%
approval = approval[approval['partisan'].isna()]# [pd.to_datetime(approval['end_date']) >= pd.to_datetime('2023-12-01')]
approval.shape
# Out:
# (105, 36)

# %%
ratings = pd.read_csv('pollster_ratings_silver.csv')
ratings
# Out:
#                              Pollster    Grade  Predictive Plus-Minus  \
# 0                          AtlasIntel    A+@@1              -0.957740
# 1     Marquette University Law School   A/B@@4              -0.920261
# 2                 The Washington Post    A+@@1              -0.902281
# 3             Research & Polling Inc.     A@@2              -0.871136
# 4    The New York Times/Siena College     A@@2              -0.763947
# ..                                ...      ...                    ...
# 530          Nielson Brothers Polling  C/D@@12               1.946864
# 531                     Ascend Action  C/D@@12               2.282717
# 532       Jayhawk Consulting Services  C/D@@12               2.353968
# 533        Fort Hays State University  C/D@@12               2.489170
# 534                The Dartmouth Poll  C/D@@12               3.988291
#
#       Mean-reverted bias  Number of polls cat
# 0     D+0.16@@0.16334188               91  D+
# 1     D+0.32@@0.31545374               17  D+
# 2     D+0.90@@0.89811021               98  D+
# 3    R+0.55@@-0.54944503               44  R+
# 4      D+1.41@@1.4121077              116  D+
# ..                   ...              ...  ..
# 530    D+3.05@@3.0515239               11  D+
# 531    D+3.35@@3.3485439                6  D+
# 532    D+2.27@@2.2674108                2  D+
# 533   R+1.10@@-1.0960908                6  R+
# 534    D+4.40@@4.4045453                4  D+
#
# [535 rows x 6 columns]

# %%
banned_pollsters = ratings[ratings['Grade'].str.contains('F')]['Pollster'].values
banned_pollsters
# Out:
# array(['Strategic Vision LLC', 'Pharos Research Group', 'Research 2000',
#        'Big Data Poll', 'Overtime Politics', 'Rethink Priorities',
#        'Blumenthal Research Daily', 'CSP Polling', 'KG Polling',
#        'OurProgress (The Progress Campaign)', 'TCJ Research'],
#       dtype=object)

# %%
approval = approval[~approval['pollster'].isin(banned_pollsters)]
approval.shape
# Out:
# (103, 36)

# %%
approval = pd.merge(left=approval, right=ratings[['Pollster', 'Predictive Plus-Minus']], left_on='pollster',
                   right_on='Pollster', how='left')
approval.shape
# Out:
# (103, 38)

# %%
approval = approval[(~approval['sample_size'].isna())]
approval.shape
# Out:
# (102, 38)

# %%
approval['pollster'].value_counts()
# Out:
# pollster
# YouGov                                                       29
# Cygnal                                                       11
# Echelon Insights                                              9
# RMG Research                                                  8
# McLaughlin & Associates                                       8
# Clarity Campaign Labs                                         5
# Verasight                                                     4
# Emerson College                                               4
# Quantus Insights                                              3
# Fabrizio Lee & Associates/Impact Research                     3
# Hart Research Associates/Public Opinion Strategies            2
# AtlasIntel                                                    2
# Ipsos                                                         1
# The Winston Group                                             1
# American Pulse Research & Polling                             1
# J.L. Partners                                                 1
# Fabrizio Ward                                                 1
# OH Predictive Insights                                        1
# NewsNation                                                    1
# The New York Times/Siena College                              1
# Beacon Research/Shaw & Co. Research                           1
# RealClear Opinion Research                                    1
# Yale University Institution for Social and Policy Studies     1
# Normington, Petts & Associates                                1
# Public Opinion Strategies                                     1
# Morning Consult                                               1
# Name: count, dtype: int64

# %%
auxiliary = pd.read_csv('auxiliary_pollster_rating_stats.csv')
auxiliary
# Out:
#                               Pollster  Correct calls       Outside MoE  \
# 0                           AtlasIntel       0.840659   8.8%@@91.208791
# 1                  The Washington Post       0.693878   6.1%@@93.877551
# 2              Research & Polling Inc.       0.886364  9.1%@@90.9090906
# 3     The New York Times/Siena College       0.737069  18.1%@@81.896552
# 4                               Cygnal       0.939655  13.8%@@86.206897
# ..                                 ...            ...               ...
# 93                    Digital Research       0.904762  38.1%@@61.904761
# 94  Mitchell Research & Communications       0.695122    39%@@60.975611
# 95                Merriman River Group       0.840000    60%@@39.999998
# 96             McLaughlin & Associates       0.689655  34.5%@@65.517241
# 97                        TCJ Research       0.590909  49.2%@@50.757575
#
#            House effect             ADPA  Herding penalty  herd_cat p_cat
# 0    R+2.00@@-1.9990723   3.7@@3.6687982         0.096047         2    R+
# 1     D+1.02@@1.0173736   3.6@@3.5756676         0.221841         3    D+
# 2    D+0.63@@0.63289553    4.6@@4.642076         0.286276         3    D+
# 3    D+0.79@@0.79133403   3.2@@3.2483816         0.280332         3    D+
# 4   R+0.60@@-0.59704119   3.5@@3.4644768         0.521310         4    R+
# ..                  ...              ...              ...       ...   ...
# 93   R+2.44@@-2.4431372  11.4@@11.413808         0.000000         1    R+
# 94  R+0.45@@-0.44617203   4.4@@4.4410443         0.229193         3    R+
# 95   R+3.23@@-3.2347174  10.3@@10.260222         0.000000         1    R+
# 96   R+4.94@@-4.9392128     6.2@@6.17804         0.000000         1    R+
# 97   R+3.42@@-3.4232018   4.4@@4.3859954         0.000000         1    R+
#
# [98 rows x 8 columns]

# %%
# house_eff = auxiliary['House effect'].str.extract(r'(\w)\+(\d\.\d\d)@@*.')
house_eff = auxiliary['House effect'].str.extract(r'(\w)\+\d.\d\d.*@@([\d\.\+\-]+)')
house_eff[1] = house_eff[1].astype(float)
house_eff
# Out:
#     0         1
# 0   R -1.999072
# 1   D  1.017374
# 2   D  0.632896
# 3   D  0.791334
# 4   R -0.597041
# .. ..       ...
# 93  R -2.443137
# 94  R -0.446172
# 95  R -3.234717
# 96  R -4.939213
# 97  R -3.423202
#
# [98 rows x 2 columns]

# %%
# R --> -1, D --> 1
house_eff[0] = house_eff[0].replace({'R':-1, 'D':1})
house_eff['house_effect'] = house_eff[1]
house_eff
# Out:
#     0         1  house_effect
# 0  -1 -1.999072     -1.999072
# 1   1  1.017374      1.017374
# 2   1  0.632896      0.632896
# 3   1  0.791334      0.791334
# 4  -1 -0.597041     -0.597041
# .. ..       ...           ...
# 93 -1 -2.443137     -2.443137
# 94 -1 -0.446172     -0.446172
# 95 -1 -3.234717     -3.234717
# 96 -1 -4.939213     -4.939213
# 97 -1 -3.423202     -3.423202
#
# [98 rows x 3 columns]

# %%
auxiliary['house_effect'] = house_eff['house_effect']
auxiliary = auxiliary.set_index(['Pollster'])
auxiliary
# Out:
#                                     Correct calls       Outside MoE  \
# Pollster
# AtlasIntel                               0.840659   8.8%@@91.208791
# The Washington Post                      0.693878   6.1%@@93.877551
# Research & Polling Inc.                  0.886364  9.1%@@90.9090906
# The New York Times/Siena College         0.737069  18.1%@@81.896552
# Cygnal                                   0.939655  13.8%@@86.206897
# ...                                           ...               ...
# Digital Research                         0.904762  38.1%@@61.904761
# Mitchell Research & Communications       0.695122    39%@@60.975611
# Merriman River Group                     0.840000    60%@@39.999998
# McLaughlin & Associates                  0.689655  34.5%@@65.517241
# TCJ Research                             0.590909  49.2%@@50.757575
#
#                                            House effect             ADPA  \
# Pollster
# AtlasIntel                           R+2.00@@-1.9990723   3.7@@3.6687982
# The Washington Post                   D+1.02@@1.0173736   3.6@@3.5756676
# Research & Polling Inc.              D+0.63@@0.63289553    4.6@@4.642076
# The New York Times/Siena College     D+0.79@@0.79133403   3.2@@3.2483816
# Cygnal                              R+0.60@@-0.59704119   3.5@@3.4644768
# ...                                                 ...              ...
# Digital Research                     R+2.44@@-2.4431372  11.4@@11.413808
# Mitchell Research & Communications  R+0.45@@-0.44617203   4.4@@4.4410443
# Merriman River Group                 R+3.23@@-3.2347174  10.3@@10.260222
# McLaughlin & Associates              R+4.94@@-4.9392128     6.2@@6.17804
# TCJ Research                         R+3.42@@-3.4232018   4.4@@4.3859954
#
#                                     Herding penalty  herd_cat p_cat  \
# Pollster
# AtlasIntel                                 0.096047         2    R+
# The Washington Post                        0.221841         3    D+
# Research & Polling Inc.                    0.286276         3    D+
# The New York Times/Siena College           0.280332         3    D+
# Cygnal                                     0.521310         4    R+
# ...                                             ...       ...   ...
# Digital Research                           0.000000         1    R+
# Mitchell Research & Communications         0.229193         3    R+
# Merriman River Group                       0.000000         1    R+
# McLaughlin & Associates                    0.000000         1    R+
# TCJ Research                               0.000000         1    R+
#
#                                     house_effect
# Pollster
# AtlasIntel                             -1.999072
# The Washington Post                     1.017374
# Research & Polling Inc.                 0.632896
# The New York Times/Siena College        0.791334
# Cygnal                                 -0.597041
# ...                                          ...
# Digital Research                       -2.443137
# Mitchell Research & Communications     -0.446172
# Merriman River Group                   -3.234717
# McLaughlin & Associates                -4.939213
# TCJ Research                           -3.423202
#
# [98 rows x 8 columns]

# %%
def apply_house_eff(data, pollster):
    df = data[data['pollster']==pollster]
    try:
        df['dem_adj'] = df['dem'] - (auxiliary.loc[pollster, 'house_effect'] / 2)
        df['rep_adj'] = df['rep'] + (auxiliary.loc[pollster, 'house_effect'] / 2)
    except KeyError:
        df['dem_adj'] = df['dem']
        df['rep_adj'] = df['rep']
    return df

# %%
pollsters = approval['pollster'].value_counts().index.values
df_adjs = []
for p in pollsters:
    df = apply_house_eff(approval, p)
    df_adjs.append(df)

approval_adj = pd.concat(df_adjs, axis=0)
approval_adj
# Out:
#     poll_id  pollster_id                                           pollster  \
# 10    89579          568                                             YouGov
# 11    89579          568                                             YouGov
# 23    89690          568                                             YouGov
# 24    89690          568                                             YouGov
# 38    89897          568                                             YouGov
# ..      ...          ...                                                ...
# 25    89712         1524                         RealClear Opinion Research
# 22    89744         1903  Yale University Institution for Social and Pol...
# 19    89821         1107                     Normington, Petts & Associates
# 13    89658          379                          Public Opinion Strategies
# 96    90535         1189                                    Morning Consult
#
#    sponsor_ids                  sponsors  sponsor_candidate_id  \
# 10         352             The Economist                   NaN
# 11         352             The Economist                   NaN
# 23         352             The Economist                   NaN
# 24         352             The Economist                   NaN
# 38         352             The Economist                   NaN
# ..         ...                       ...                   ...
# 25         NaN                       NaN                   NaN
# 22         NaN                       NaN                   NaN
# 19         543                 Third Way                   NaN
# 13        2255  Paragon Health Institute                   NaN
# 96         NaN                       NaN                   NaN
#
#     sponsor_candidate  sponsor_candidate_party  \
# 10                NaN                      NaN
# 11                NaN                      NaN
# 23                NaN                      NaN
# 24                NaN                      NaN
# 38                NaN                      NaN
# ..                ...                      ...
# 25                NaN                      NaN
# 22                NaN                      NaN
# 19                NaN                      NaN
# 13                NaN                      NaN
# 96                NaN                      NaN
#
#                                          display_name                   mode  \
# 10                                             YouGov  Online Matched Sample
# 11                                             YouGov  Online Matched Sample
# 23                                             YouGov  Online Matched Sample
# 24                                             YouGov  Online Matched Sample
# 38                                             YouGov  Online Matched Sample
# ..                                                ...                    ...
# 25                         RealClear Opinion Research                    NaN
# 22  Yale University Institution for Social and Pol...    Online Opt-In Panel
# 19                     Normington, Petts & Associates                    NaN
# 13                          Public Opinion Strategies             Live Phone
# 96                                    Morning Consult    Online Opt-In Panel
#
#     ...  office_type       seat_name election_date    stage   dem   rep  \
# 10  ...   U.S. House  Generic Ballot    2026-11-03  general  42.0  41.0
# 11  ...   U.S. House  Generic Ballot    2026-11-03  general  35.0  37.0
# 23  ...   U.S. House  Generic Ballot    2026-11-03  general  43.0  42.0
# 24  ...   U.S. House  Generic Ballot    2026-11-03  general  39.0  36.0
# 38  ...   U.S. House  Generic Ballot    2026-11-03  general  43.0  42.0
# ..  ...          ...             ...           ...      ...   ...   ...
# 25  ...   U.S. House  Generic Ballot    2026-11-03  general  39.8  39.2
# 22  ...   U.S. House  Generic Ballot    2026-11-03  general  43.3  41.7
# 19  ...   U.S. House  Generic Ballot    2026-11-03  general  50.0  50.0
# 13  ...   U.S. House  Generic Ballot    2026-11-03  general  44.0  46.0
# 96  ...   U.S. House  Generic Ballot    2026-11-03  general  45.0  41.0
#
#                           Pollster Predictive Plus-Minus    dem_adj    rep_adj
# 10                          YouGov              0.047635  41.750413  41.249587
# 11                          YouGov              0.047635  34.750413  37.249587
# 23                          YouGov              0.047635  42.750413  42.249587
# 24                          YouGov              0.047635  38.750413  36.249587
# 38                          YouGov              0.047635  42.750413  42.249587
# ..                             ...                   ...        ...        ...
# 25                             NaN                   NaN  39.800000  39.200000
# 22                             NaN                   NaN  43.300000  41.700000
# 19  Normington, Petts & Associates              0.837728  50.000000  50.000000
# 13       Public Opinion Strategies             -0.246974  46.071409  43.928591
# 96                 Morning Consult              0.584994  44.570341  41.429659
#
# [102 rows x 40 columns]

# %%
approval = approval_adj.copy()
approval.shape
# Out:
# (102, 40)

# %%
def pipeline(data: pd.DataFrame):
    dup = data[data.duplicated(subset='poll_id')]
    ndup = data[~data.duplicated(subset='poll_id')]
    #try:
    dup_a = dup[dup['population'].isin(['lv'])]
#     except ValueError:
#         print(dup['population'].isin(['a']))
    df = pd.concat([dup_a, ndup], axis=0)
    
    dup = df[df.duplicated(subset='poll_id')]
    ndup = df[~df.duplicated(subset='poll_id')]
    dup_lv = dup[dup['population'].isin(['rv'])]
    df = pd.concat([dup_lv, ndup], axis=0)
    
    df['start_date'] = pd.to_datetime(df['start_date'])
    df['end_date'] = pd.to_datetime(df['end_date'])
    
    return df

# %%
approval = approval.rename({'Predictive Plus-Minus':'pred_plus_minus'}, axis=1)

# %%
# banned_pollsters_aux = ['Rasmussen Reports', 'co/efficient', 'TIPP Insights', 'Civiqs', 'Trafalgar Group', 'OnMessage Inc.']
banned_pollsters_aux = pd.read_csv('banned_pollsters_aux.csv')['banned_pollsters'].values
banned_pollsters_aux
# Out:
# array(['Rasmussen Reports', 'TIPP Insights', 'Trafalgar Group',
#        'Trafalgar Group/Insider Advantage'], dtype=object)

# %%
approval = approval[~approval['pollster'].isin(banned_pollsters_aux)]
approval.head()
# Out:
#     poll_id  pollster_id pollster sponsor_ids       sponsors  \
# 10    89579          568   YouGov         352  The Economist
# 11    89579          568   YouGov         352  The Economist
# 23    89690          568   YouGov         352  The Economist
# 24    89690          568   YouGov         352  The Economist
# 38    89897          568   YouGov         352  The Economist
#
#     sponsor_candidate_id  sponsor_candidate  sponsor_candidate_party  \
# 10                   NaN                NaN                      NaN
# 11                   NaN                NaN                      NaN
# 23                   NaN                NaN                      NaN
# 24                   NaN                NaN                      NaN
# 38                   NaN                NaN                      NaN
#
#    display_name                   mode  ...  office_type       seat_name  \
# 10       YouGov  Online Matched Sample  ...   U.S. House  Generic Ballot
# 11       YouGov  Online Matched Sample  ...   U.S. House  Generic Ballot
# 23       YouGov  Online Matched Sample  ...   U.S. House  Generic Ballot
# 24       YouGov  Online Matched Sample  ...   U.S. House  Generic Ballot
# 38       YouGov  Online Matched Sample  ...   U.S. House  Generic Ballot
#
#    election_date    stage   dem   rep  Pollster pred_plus_minus    dem_adj  \
# 10    2026-11-03  general  42.0  41.0    YouGov        0.047635  41.750413
# 11    2026-11-03  general  35.0  37.0    YouGov        0.047635  34.750413
# 23    2026-11-03  general  43.0  42.0    YouGov        0.047635  42.750413
# 24    2026-11-03  general  39.0  36.0    YouGov        0.047635  38.750413
# 38    2026-11-03  general  43.0  42.0    YouGov        0.047635  42.750413
#
#       rep_adj
# 10  41.249587
# 11  37.249587
# 23  42.249587
# 24  36.249587
# 38  42.249587
#
# [5 rows x 40 columns]

# %%
approval.shape
# Out:
# (102, 40)

# %%
# net: negative --> dem advantage, positive --> rep advantage
approval['net'] = approval['rep'] - approval['dem']
approval.head(1)
# Out:
#     poll_id  pollster_id pollster sponsor_ids       sponsors  \
# 10    89579          568   YouGov         352  The Economist
#
#     sponsor_candidate_id  sponsor_candidate  sponsor_candidate_party  \
# 10                   NaN                NaN                      NaN
#
#    display_name                   mode  ...       seat_name election_date  \
# 10       YouGov  Online Matched Sample  ...  Generic Ballot    2026-11-03
#
#       stage   dem   rep  Pollster  pred_plus_minus    dem_adj    rep_adj  net
# 10  general  42.0  41.0    YouGov         0.047635  41.750413  41.249587 -1.0
#
# [1 rows x 41 columns]

# %%
approval['url'] = approval['url_crosstab'].fillna(approval['url_topline']).fillna(approval['url_article'].fillna(''))

# %%
approval_polls = approval[['pollster', 'start_date', 'end_date', 'sample_size', 'population', 'dem', 'rep', 'dem_adj', 'rep_adj', 'net', 'pred_plus_minus', 'poll_id', 'url', 'sponsors']]
approval_polls
# Out:
#                                              pollster  start_date    end_date  \
# 10                                             YouGov  2025-02-16  2025-02-18
# 11                                             YouGov  2025-02-16  2025-02-18
# 23                                             YouGov  2025-04-05  2025-04-08
# 24                                             YouGov  2025-04-05  2025-04-08
# 38                                             YouGov  2025-05-16  2025-05-19
# ..                                                ...         ...         ...
# 25                         RealClear Opinion Research  2025-04-10  2025-04-12
# 22  Yale University Institution for Social and Pol...  2025-04-01  2025-04-03
# 19                     Normington, Petts & Associates  2025-03-12  2025-03-19
# 13                          Public Opinion Strategies  2025-02-25  2025-03-02
# 96                                    Morning Consult  2025-08-29  2025-08-31
#
#     sample_size population   dem   rep    dem_adj    rep_adj  net  \
# 10       1451.0         rv  42.0  41.0  41.750413  41.249587 -1.0
# 11       1603.0          a  35.0  37.0  34.750413  37.249587  2.0
# 23       1558.0         rv  43.0  42.0  42.750413  42.249587 -1.0
# 24       1741.0          a  39.0  36.0  38.750413  36.249587 -3.0
# 38       1558.0         rv  43.0  42.0  42.750413  42.249587 -1.0
# ..          ...        ...   ...   ...        ...        ...  ...
# 25       1000.0         rv  39.8  39.2  39.800000  39.200000 -0.6
# 22       4100.0         rv  43.3  41.7  43.300000  41.700000 -1.6
# 19        800.0         lv  50.0  50.0  50.000000  50.000000  0.0
# 13       1000.0         rv  44.0  46.0  46.071409  43.928591  2.0
# 96       2202.0         rv  45.0  41.0  44.570341  41.429659 -4.0
#
#     pred_plus_minus  poll_id  \
# 10         0.047635    89579
# 11         0.047635    89579
# 23         0.047635    89690
# 24         0.047635    89690
# 38         0.047635    89897
# ..              ...      ...
# 25              NaN    89712
# 22              NaN    89744
# 19         0.837728    89821
# 13        -0.246974    89658
# 96         0.584994    90535
#
#                                                   url  \
# 10  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 11  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 23  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 24  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 38  https://today.yougov.com/topics/politics/track...
# ..                                                ...
# 25  https://www.realclearpolitics.com/docs/2025/RC...
# 22  https://docs.google.com/spreadsheets/d/1JhSWPV...
# 19  https://thirdway.imgix.net/downloads/democrats...
# 13  https://paragoninstitute.org/medicaid/paragon-...
# 96  https://links.morningconsult.com/s/vb/zpOJTp1f...
#
#                     sponsors
# 10             The Economist
# 11             The Economist
# 23             The Economist
# 24             The Economist
# 38             The Economist
# ..                       ...
# 25                       NaN
# 22                       NaN
# 19                 Third Way
# 13  Paragon Health Institute
# 96                       NaN
#
# [102 rows x 14 columns]

# %%
def avgs_pipeline(data: pd.DataFrame, date: datetime.date):
    state_pivot = pipeline(data)
    # state_pivot['end_date'] = pd.to_datetime(state_pivot['end_date'])
    # state_pivot['pred_plus_minus'] = state_pivot['pred_plus_minus'].map(lambda x: -x)
    state_pivot = state_pivot[state_pivot['end_date'] <= pd.to_datetime(date)]
    # state_pivot['population'] = state_pivot['population'].astype(str).map(lambda x: x.strip())
    
    total_num_polls = state_pivot.shape[0]

    # Sample size weights
    total_sample_size = np.sum(state_pivot['sample_size'])
    state_pivot['sample_size_weights'] = (state_pivot['sample_size'].map(lambda x: np.sqrt(min(x, 3000))) / np.sqrt(np.median(state_pivot['sample_size'].map(lambda x: min(x, 2000)))))
    # print(np.median(state_pivot['sample_size'].map(lambda x: min(x, 5000))))
    state_pivot['sample_size_weights'] /= np.sum(state_pivot['sample_size_weights'])
    
    # Time weights
    # Variation of the equation used here: https://polls.votehub.us/
    latest_date = pd.Timestamp(date)
    delta = state_pivot['end_date'].apply(lambda x: (latest_date - x).days)# (latest_date - state_pivot['end_date']).apply(lambda x: x.days)
    # linear_weights = (1 - delta/((latest_date - state_pivot['end_date'].min()).days + 1))
    linear_weights = delta.map(lambda x: (1 - x/60) if x < 60 else 0)
    exp_weights = 0.1**(delta/(45))
    state_pivot['time_weights'] =  0.1 * linear_weights + 0.9 * exp_weights
    # state_pivot['time_weights'] /= np.sum(state_pivot['time_weights'])
    
    # Quality weights
    rel_quality = state_pivot['pred_plus_minus']
    def quality_weight(rel_qual):
        if np.isnan(rel_qual):
            return 0.1
        if rel_qual > 0.5: # Utilizing predictive plus-minus from Silver Bulletin's ratings
            return 0.2
        # return np.sqrt(-rel_qual+1)+0.05
        return np.exp(-rel_qual/1.3)
    state_pivot['quality_weights'] = rel_quality.map(quality_weight)
    # state_pivot['quality_weights'] /= np.sum(state_pivot['quality_weights'])
    
    # Population weights
    def population_weight(population):
        if population == 'rv':
            return 0.8
        elif population == 'a':
            return 0.5
        return 1
    state_pivot['population_weights'] = state_pivot['population'].map(population_weight)
    # state_pivot['population_weights'] /= np.sum(state_pivot['population_weights'])

    # Gather the weights together
    state_pivot['total_weights'] = state_pivot['sample_size_weights'] * state_pivot['time_weights'] * state_pivot['quality_weights'] * state_pivot['population_weights']
    state_pivot['total_weights'] /= np.sum(state_pivot['total_weights']) # Normalization step
    
    return state_pivot

# %%
avgs_pipeline(approval_polls, datetime.datetime.today())
# Out:
#                                              pollster start_date   end_date  \
# 67                                   Echelon Insights 2025-07-10 2025-07-14
# 10                                             YouGov 2025-02-16 2025-02-18
# 23                                             YouGov 2025-04-05 2025-04-08
# 38                                             YouGov 2025-05-16 2025-05-19
# 42                                             YouGov 2025-05-23 2025-05-26
# ..                                                ...        ...        ...
# 25                         RealClear Opinion Research 2025-04-10 2025-04-12
# 22  Yale University Institution for Social and Pol... 2025-04-01 2025-04-03
# 19                     Normington, Petts & Associates 2025-03-12 2025-03-19
# 13                          Public Opinion Strategies 2025-02-25 2025-03-02
# 96                                    Morning Consult 2025-08-29 2025-08-31
#
#     sample_size population   dem   rep    dem_adj    rep_adj  net  \
# 67       1084.0         lv  45.0  41.0  45.000000  41.000000 -4.0
# 10       1451.0         rv  42.0  41.0  41.750413  41.249587 -1.0
# 23       1558.0         rv  43.0  42.0  42.750413  42.249587 -1.0
# 38       1558.0         rv  43.0  42.0  42.750413  42.249587 -1.0
# 42       1486.0         rv  43.0  41.0  42.750413  41.249587 -2.0
# ..          ...        ...   ...   ...        ...        ...  ...
# 25       1000.0         rv  39.8  39.2  39.800000  39.200000 -0.6
# 22       4100.0         rv  43.3  41.7  43.300000  41.700000 -1.6
# 19        800.0         lv  50.0  50.0  50.000000  50.000000  0.0
# 13       1000.0         rv  44.0  46.0  46.071409  43.928591  2.0
# 96       2202.0         rv  45.0  41.0  44.570341  41.429659 -4.0
#
#     pred_plus_minus  poll_id  \
# 67        -0.216672    90309
# 10         0.047635    89579
# 23         0.047635    89690
# 38         0.047635    89897
# 42         0.047635    90016
# ..              ...      ...
# 25              NaN    89712
# 22              NaN    89744
# 19         0.837728    89821
# 13        -0.246974    89658
# 96         0.584994    90535
#
#                                                   url  \
# 67  https://echelonin.wpenginepowered.com/wp-conte...
# 10  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 23  https://d3nkl3psvxxpe9.cloudfront.net/document...
# 38  https://today.yougov.com/topics/politics/track...
# 42  https://today.yougov.com/topics/politics/track...
# ..                                                ...
# 25  https://www.realclearpolitics.com/docs/2025/RC...
# 22  https://docs.google.com/spreadsheets/d/1JhSWPV...
# 19  https://thirdway.imgix.net/downloads/democrats...
# 13  https://paragoninstitute.org/medicaid/paragon-...
# 96  https://links.morningconsult.com/s/vb/zpOJTp1f...
#
#                     sponsors  sample_size_weights  time_weights  \
# 67                       NaN             0.009850      0.041774
# 10             The Economist             0.011396      0.000024
# 23             The Economist             0.011809      0.000292
# 38             The Economist             0.011809      0.002379
# 42             The Economist             0.011533      0.003404
# ..                       ...                  ...           ...
# 25                       NaN             0.009461      0.000358
# 22                       NaN             0.016387      0.000226
# 19                 Third Way             0.008462      0.000105
# 13  Paragon Health Institute             0.009461      0.000044
# 96                       NaN             0.014039      0.567053
#
#     quality_weights  population_weights  total_weights
# 67         1.181365                 1.0       0.007303
# 10         0.964021                 0.8       0.000003
# 23         0.964021                 0.8       0.000040
# 38         0.964021                 0.8       0.000326
# 42         0.964021                 0.8       0.000455
# ..              ...                 ...            ...
# 25         0.100000                 0.8       0.000004
# 22         0.100000                 0.8       0.000004
# 19         0.200000                 1.0       0.000003
# 13         1.209225                 0.8       0.000006
# 96         0.200000                 0.8       0.019134
#
# [93 rows x 19 columns]

# %%
approval_polls['end_date'].min()
# Out:
# '2024-12-11'

# %%
def approval_over_time(data: pd.DataFrame):
    date_range = pd.date_range(start=datetime.date(2025, 1, 20), end=datetime.datetime.today(), freq='d', inclusive='both')
    yes_averages = []
    no_averages = []
    yes_stdevs = []
    no_stdevs = []
    for date in date_range:
        pipelined_df = avgs_pipeline(data, date)
        yes_avg = np.sum(pipelined_df['rep_adj'] * pipelined_df['total_weights'])
        no_avg = np.sum(pipelined_df['dem_adj'] * pipelined_df['total_weights'])
        yes_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['rep_adj'] - yes_avg)**2))
        no_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['dem_adj'] - no_avg)**2))
        yes_averages.append(yes_avg)
        no_averages.append(no_avg)
        yes_stdevs.append(yes_std)
        no_stdevs.append(no_std)
    
    return pd.DataFrame({'Date':date_range, 'Republicans':yes_averages, 'Democrats':no_averages}), pd.DataFrame({'Date':date_range, 'Republicans':yes_stdevs, 'Democrats':no_stdevs}), avgs_pipeline(data, datetime.datetime.today())

# %%
approval_avg, approval_std, polls_df = approval_over_time(approval_polls)
approval_avg
# Out:
#           Date  Republicans  Democrats
# 0   2025-01-20    47.709367  44.675605
# 1   2025-01-21    47.709031  44.675533
# 2   2025-01-22    47.708688  44.675440
# 3   2025-01-23    47.708340  44.675325
# 4   2025-01-24    47.707986  44.675186
# ..         ...          ...        ...
# 231 2025-09-08    41.987601  44.803511
# 232 2025-09-09    41.987751  44.802144
# 233 2025-09-10    41.987844  44.800555
# 234 2025-09-11    41.987875  44.798725
# 235 2025-09-12    41.987838  44.796633
#
# [236 rows x 3 columns]

# %%
polls_df.shape
# Out:
# (93, 19)

# %%
display_df = polls_df[['pollster', 'start_date', 'end_date', 'sample_size', 'population', 'dem', 'rep', 'net',
                      'total_weights', 'url', 'sponsors']]
display_df['sponsors'] = '^Sponsor: ' + display_df['sponsors'] + '^'
display_df['sponsors'] = display_df['sponsors'].fillna('')
display_df = display_df.sort_values(['end_date'], ascending=False)
display_df = display_df.rename({'pollster':'Pollster', 'dem':'Democrats', 'rep':'Republicans', 'net':'Net', 'total_weights':'Weight', 'start_date':'Start Date', 'end_date':'End Date', 'url':'URL'}, axis='columns')
display_df['Sample'] = display_df['sample_size'].astype(int).astype(str) + ' ' + display_df['population'].map(lambda x: x.upper()).astype(str)
# display_df['end_date'] = display_df['end_date'].map(lambda x: datetime.datetime.strptime(datetime.datetime.fromtimestamp(x), '%m/%d/%Y').strftime('%Y-%m-%d'))
# display_df['Date'] = pd.to_datetime(display_df['startdate']).astype(str) + ' - ' + display_df['end_date'].astype(str)
display_df['Start Date'] = pd.to_datetime(display_df['Start Date']).astype(str)
display_df['End Date'] = display_df['End Date'].astype(str)
display_df = display_df.reset_index()
display_df['Pollster'] = '<a href="' + display_df['URL'] + '" style="color:black; text-decoration:underline;"><u>' + display_df['Pollster'] + '</u></a>' + display_df['sponsors']
# display_df = display_df.drop(['sample_size', 'population'], axis='columns')
display_df = display_df[['Pollster', 'Start Date', 'End Date', 'Sample', 'Weight', 'Democrats', 'Republicans', 'Net']]
# display_df = display_df.set_index(['Pollster'])
display_df
# Out:
#                                              Pollster  Start Date    End Date  \
# 0   <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2025-09-05  2025-09-08
# 1   <a href="https://www.cygn.al/wp-content/upload...  2025-09-02  2025-09-03
# 2   <a href="https://d3nkl3psvxxpe9.cloudfront.net...  2025-08-29  2025-09-02
# 3   <a href="https://www.scribd.com/document/91189...  2025-08-29  2025-09-02
# 4   <a href="https://links.morningconsult.com/s/vb...  2025-08-29  2025-08-31
# ..                                                ...         ...         ...
# 88  <a href="https://mclaughlinonline.com/pols/wp-...  2025-01-22  2025-01-27
# 89  <a href="https://napolitannews.org/posts/gener...  2025-01-15  2025-01-16
# 90  <a href="https://www.cygn.al/wp-content/upload...  2025-01-09  2025-01-12
# 91  <a href="https://mclaughlinonline.com/pols/wp-...  2024-12-11  2024-12-16
# 92  <a href="https://www.cygn.al/wp-content/upload...  2024-12-09  2024-12-11
#
#      Sample        Weight  Democrats  Republicans  Net
# 0    1644 A  7.261876e-02       39.0         36.0 -3.0
# 1   1500 LV  2.019283e-01       47.6         45.2 -2.4
# 2    1691 A  5.548682e-02       38.0         34.0 -4.0
# 3   1136 RV  7.276578e-02       44.0         40.0 -4.0
# 4   2202 RV  1.913448e-02       45.0         41.0 -4.0
# ..      ...           ...        ...          ...  ...
# 88  1000 LV  2.194172e-07       40.0         48.0  8.0
# 89  1000 RV  4.036513e-07       44.0         51.0  7.0
# 90  1500 LV  1.108201e-06       44.6         46.8  2.2
# 91  1000 LV  2.558216e-08       42.0         47.0  5.0
# 92  1500 LV  2.155299e-07       44.6         48.4  3.8
#
# [93 rows x 8 columns]

# %%
display_df.to_csv('generic_ballot_polls_display_table.csv')

# %%
approval_avg['Net'] = approval_avg['Republicans'] - approval_avg['Democrats']
approval_avg
# Out:
#           Date  Republicans  Democrats       Net
# 0   2025-01-20    47.709367  44.675605  3.033762
# 1   2025-01-21    47.709031  44.675533  3.033498
# 2   2025-01-22    47.708688  44.675440  3.033248
# 3   2025-01-23    47.708340  44.675325  3.033015
# 4   2025-01-24    47.707986  44.675186  3.032800
# ..         ...          ...        ...       ...
# 231 2025-09-08    41.987601  44.803511 -2.815909
# 232 2025-09-09    41.987751  44.802144 -2.814393
# 233 2025-09-10    41.987844  44.800555 -2.812711
# 234 2025-09-11    41.987875  44.798725 -2.810850
# 235 2025-09-12    41.987838  44.796633 -2.808795
#
# [236 rows x 4 columns]

# %%
approval_trendline = pd.merge(left=approval_avg, right=approval_std, left_on='Date', right_on='Date', how='inner')
approval_trendline['approve_CI_upper'] = approval_trendline['Republicans_x'] + 1.96*approval_trendline['Republicans_y']
approval_trendline['approve_CI_lower'] = approval_trendline['Republicans_x'] - 1.96*approval_trendline['Republicans_y']
approval_trendline['disapprove_CI_upper'] = approval_trendline['Democrats_x'] + 1.96*approval_trendline['Democrats_y']
approval_trendline['disapprove_CI_lower'] = approval_trendline['Democrats_x'] - 1.96*approval_trendline['Democrats_y']
approval_trendline = approval_trendline.rename({
    'Republicans_x':'approve_mean',
    'Democrats_x':'disapprove_mean',
}, axis='columns').drop(['Republicans_y', 'Democrats_y', 'Net'], axis='columns')
approval_trendline
# Out:
#           Date  approve_mean  disapprove_mean  approve_CI_upper  \
# 0   2025-01-20     47.709367        44.675605         51.436357
# 1   2025-01-21     47.709031        44.675533         51.436673
# 2   2025-01-22     47.708688        44.675440         51.437131
# 3   2025-01-23     47.708340        44.675325         51.437744
# 4   2025-01-24     47.707986        44.675186         51.438524
# ..         ...           ...              ...               ...
# 231 2025-09-08     41.987601        44.803511         50.550683
# 232 2025-09-09     41.987751        44.802144         50.554869
# 233 2025-09-10     41.987844        44.800555         50.559407
# 234 2025-09-11     41.987875        44.798725         50.564323
# 235 2025-09-12     41.987838        44.796633         50.569646
#
#      approve_CI_lower  disapprove_CI_upper  disapprove_CI_lower
# 0           43.982377            45.464155            43.887055
# 1           43.981388            45.464185            43.886881
# 2           43.980246            45.464223            43.886658
# 3           43.978937            45.464270            43.886381
# 4           43.977449            45.464327            43.886046
# ..                ...                  ...                  ...
# 231         33.424520            52.195938            37.411083
# 232         33.420632            52.195760            37.408528
# 233         33.416281            52.195530            37.405580
# 234         33.411427            52.195245            37.402205
# 235         33.406030            52.194898            37.398368
#
# [236 rows x 7 columns]

# %%
# remember: approve = Republicans, disapprove = Democrats - kept for DataWrapper setup simplicity
# Export generic ballot averages
approval_trendline.to_csv('generic_ballot_stats.csv')

# %%
# line = px.line(approval_avg, x='Date', y=['Approve', 'Disapprove'])
# # scatter = px.scatter(polls_df[polls_df['end_date'] >= pd.to_datetime('2025-01-24')], x='end_date', y=['approve', 'disapprove'])
# line.update_traces(hovertemplate=None)
# line.update_layout(hovermode='x unified')
# # scatter.update_traces(hovertemplate=None, hoverinfo='skip')
# fig_approve_CI = go.Figure([
#     go.Scatter(
#         name='Approve CI Upper Bound',
#         x = approval_avg['Date'],
#         y = approval_avg['Approve'] + 1.96*approval_std['Approve'],
#         mode='lines',
#         marker=dict(color='#8be8f2'),
#         line=dict(width=0),
#         showlegend=False,
#         hoverinfo='skip'
#     ),
#     go.Scatter(
#         name='Approve CI Lower Bound',
#         x = approval_avg['Date'],
#         y = approval_avg['Approve'] - 1.96*approval_std['Approve'],
#         mode='lines',
#         marker=dict(color='#8be8f2'),
#         line=dict(width=0),
#         showlegend=False,
#         hoverinfo='skip'
#     ),  
# ])
# fig_disapprove_CI = go.Figure([
#     go.Scatter(
#         name='Disapprove CI Upper Bound',
#         x = approval_avg['Date'],
#         y = approval_avg['Disapprove'] + 1.96*approval_std['Disapprove'],
#         mode='lines',
#         marker=dict(color='#a3cbec'),
#         line=dict(width=0),
#         showlegend=False,
#         hoverinfo='skip'
#     ),
#     go.Scatter(
#         name='Disapprove CI Lower Bound',
#         x = approval_avg['Date'],
#         y = approval_avg['Disapprove'] - 1.96*approval_std['Disapprove'],
#         mode='lines',
#         marker=dict(color='#a3cbec'),
#         line=dict(width=0),
#         showlegend=False,
#         hoverinfo='skip'
#     ),  
# ])

# fig = go.Figure(data=line.data + fig_approve_CI.data + fig_disapprove_CI.data)
# fig.update_layout(
#     title='Congressional Approval Rating',
#     xaxis_title='Date',
#     yaxis_title='%',
#     legend_title='Legend',
#     hovermode='x unified'
# )
# fig.show()

# %%
approval_polls.head()
# Out:
#    pollster  start_date    end_date  sample_size population   dem   rep  \
# 10   YouGov  2025-02-16  2025-02-18       1451.0         rv  42.0  41.0
# 11   YouGov  2025-02-16  2025-02-18       1603.0          a  35.0  37.0
# 23   YouGov  2025-04-05  2025-04-08       1558.0         rv  43.0  42.0
# 24   YouGov  2025-04-05  2025-04-08       1741.0          a  39.0  36.0
# 38   YouGov  2025-05-16  2025-05-19       1558.0         rv  43.0  42.0
#
#       dem_adj    rep_adj  net  pred_plus_minus  poll_id  \
# 10  41.750413  41.249587 -1.0         0.047635    89579
# 11  34.750413  37.249587  2.0         0.047635    89579
# 23  42.750413  42.249587 -1.0         0.047635    89690
# 24  38.750413  36.249587 -3.0         0.047635    89690
# 38  42.750413  42.249587 -1.0         0.047635    89897
#
#                                                   url       sponsors
# 10  https://d3nkl3psvxxpe9.cloudfront.net/document...  The Economist
# 11  https://d3nkl3psvxxpe9.cloudfront.net/document...  The Economist
# 23  https://d3nkl3psvxxpe9.cloudfront.net/document...  The Economist
# 24  https://d3nkl3psvxxpe9.cloudfront.net/document...  The Economist
# 38  https://today.yougov.com/topics/politics/track...  The Economist

# %%
def net_col(df: pd.DataFrame, min_date: datetime.date):
#     df_copy = df.set_index(['Date'])
#     return df_copy['approve_mean'] - df_copy['disapprove_mean']
    date_range = pd.date_range(start=min_date, end=datetime.datetime.today(), freq='d', inclusive='both')
    data = df.copy()
    data['net_adj'] = data['rep_adj'] - data['dem_adj']
    net_averages = []
    net_stdevs = []
    issue_cols = {'Date': date_range, 'net':[], 'net_std':[]}
    for date in date_range:
    #         try:
            pipelined_df = avgs_pipeline(data, date)
    #         except TypeError:
    #             print('TypeError')
    #             print(date)
            net_avg = np.sum(pipelined_df['net_adj'] * pipelined_df['total_weights'])
            net_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['net_adj'] - net_avg)**2))

            net_averages.append(net_avg)
            net_stdevs.append(net_std)

    issue_cols['net'].extend(net_averages)
    issue_cols[f'net_std'].extend(net_stdevs)
        
    net_averages, net_stdevs = [], []
        
    return pd.DataFrame(issue_cols)

# %%
net_approval = net_col(approval_polls, datetime.date(2025, 1, 20))
net_approval
# Out:
#           Date       net   net_std
# 0   2025-01-20  3.033762  2.276959
# 1   2025-01-21  3.033498  2.277409
# 2   2025-01-22  3.033248  2.277961
# 3   2025-01-23  3.033015  2.278625
# 4   2025-01-24  3.032800  2.279411
# ..         ...       ...       ...
# 231 2025-09-08 -2.815909  1.964984
# 232 2025-09-09 -2.814393  1.959990
# 233 2025-09-10 -2.812711  1.954427
# 234 2025-09-11 -2.810850  1.948246
# 235 2025-09-12 -2.808795  1.941389
#
# [236 rows x 3 columns]

# %%
net_approval['net_upper_CI'] = net_approval['net'] + 1.96*net_approval['net_std']
net_approval['net_lower_CI'] = net_approval['net'] - 1.96*net_approval['net_std']
net_approval
# Out:
#           Date       net   net_std  net_upper_CI  net_lower_CI
# 0   2025-01-20  3.033762  2.276959      7.496602     -1.429078
# 1   2025-01-21  3.033498  2.277409      7.497219     -1.430224
# 2   2025-01-22  3.033248  2.277961      7.498052     -1.431556
# 3   2025-01-23  3.033015  2.278625      7.499121     -1.433091
# 4   2025-01-24  3.032800  2.279411      7.500445     -1.434845
# ..         ...       ...       ...           ...           ...
# 231 2025-09-08 -2.815909  1.964984      1.035460     -6.667278
# 232 2025-09-09 -2.814393  1.959990      1.027187     -6.655973
# 233 2025-09-10 -2.812711  1.954427      1.017967     -6.643389
# 234 2025-09-11 -2.810850  1.948246      1.007712     -6.629412
# 235 2025-09-12 -2.808795  1.941389      0.996327     -6.613917
#
# [236 rows x 5 columns]

# %%
net_approval.to_csv('net_generic_ballot.csv')
