# %%
import numpy as np
import pandas as pd
import datetime
# Out:
# C:\Users\adhva\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Individual Pollsters

# %%
approval = pd.read_csv('trump_approval_polls.csv')
approval.head()
# Out:
#    Unnamed: 0                president   subgroup               pollster  \
# 0           4  Donald Trump (2nd term)  All polls  Quinnipiac University
# 1           8  Donald Trump (2nd term)  All polls        Morning Consult
# 2          12  Donald Trump (2nd term)  All polls          J.L. Partners
# 3          14  Donald Trump (2nd term)  All polls      Rasmussen Reports
# 4          22  Donald Trump (2nd term)  All polls                 YouGov
#
#      sponsors startdate    enddate  samplesize population    weight  ...  \
# 0         NaN  6/5/2025   6/9/2025      1265.0         RV  1.377684  ...
# 1         NaN  6/3/2025   6/9/2025     45000.0          A  1.157798  ...
# 2  Daily Mail  6/6/2025   6/6/2025      1006.0         RV  1.071648  ...
# 3         NaN  6/4/2025  6/10/2025      1500.0         LV  0.841767  ...
# 4   Economist  6/6/2025   6/9/2025      1533.0          A  0.707933  ...
#
#    tracking approve  disapprove        net  adjusted_approve  \
# ...

# %%
# Okay just see presidential-approval.ipynb for actual code for this graph
