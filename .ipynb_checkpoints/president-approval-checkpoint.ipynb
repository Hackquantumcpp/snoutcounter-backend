# %%
import numpy as np
import pandas as pd
import scipy
from scipy.optimize import minimize
import plotly.express as px
import plotly.graph_objects as go
import datetime

from sklearn import linear_model as lm
from sklearn.feature_selection import r_regression
from sklearn.metrics import r2_score
# Out:
# C:\Users\adhva\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
approval = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vS-FKWVTTFtJT6u56e0bqdfoMcXvDO1DUChsJ3jQAMB2lZk2SMqVfmg7dGjclTYkYWz-Pm5lfcLPjp4/pub?output=csv')
# approval = approval.reset_index()
# approval = approval.rename({'index':'poll_id'}, axis=1)
approval
# Out:
#                     president   subgroup  \
# 0     Donald Trump (2nd term)     Adults
# 1     Donald Trump (2nd term)     Adults
# 2     Donald Trump (2nd term)       Cost
# 3     Donald Trump (2nd term)       Cost
# 4     Donald Trump (2nd term)     Adults
# ...                       ...        ...
# 1769  Donald Trump (2nd term)       Weak
# 1770  Donald Trump (2nd term)     Strong
# 1771  Donald Trump (2nd term)    Economy
# 1772  Donald Trump (2nd term)     Voters
# 1773  Donald Trump (2nd term)  All polls
#
#                                              pollster           sponsors  \
# 0                                       TIPP Insights  Issues & Insights
# 1                                      Marist College     NPR | PBS News
# 2                                              YouGov          Economist
# 3     Global Strategy Group/GBAO (Navigator Research)                NaN
# 4                                     The Tyson Group                NaN
# ...                                               ...                ...
# 1769                                            Ipsos            Reuters
# 1770                                            Ipsos            Reuters
# 1771                                            Ipsos            Reuters
# 1772                                 InsiderAdvantage                NaN
# 1773                                 InsiderAdvantage                NaN
#
#       startdate    enddate  samplesize population    weight  influence  \
# 0     6/26/2025  6/28/2025      1421.0          A  1.550951   1.374013
# 1     6/23/2025  6/25/2025      1381.0          A  1.481290   1.059650
# 2     6/27/2025  6/30/2025      1648.0          A  0.959537   0.959537
# 3     6/26/2025  6/30/2025      1000.0         RV  0.896889   0.845830
# 4     6/25/2025  6/26/2025      1027.0          A  0.975024   0.808503
# ...         ...        ...         ...        ...       ...        ...
# 1769  1/20/2025  1/21/2025      1077.0          A  0.749248   0.000000
# 1770  1/20/2025  1/21/2025      1077.0          A  0.749248   0.000000
# 1771  1/20/2025  1/21/2025      1077.0          A  0.749248   0.000000
# 1772  1/20/2025  1/20/2025       800.0         RV  1.093180   0.000000
# 1773  1/20/2025  1/20/2025       800.0         RV  1.093180   0.000000
#
#      tracking  approve  disapprove   net  adjusted_approve  \
# 0         NaN     44.0        45.0  -1.0          44.42427
# 1         NaN     43.0        52.0  -9.0          43.33692
# 2         NaN     35.0        59.0 -24.0          34.39935
# 3         NaN     35.0        58.0 -23.0          35.14219
# 4         NaN     45.0        51.0  -6.0          44.42818
# ...       ...      ...         ...   ...               ...
# 1769      NaN     15.0         8.0   7.0          12.97008
# 1770      NaN     29.0        29.0   0.0          33.38937
# 1771      NaN     42.0        36.0   6.0          44.60607
# 1772      NaN     56.0        39.0  17.0          53.46296
# 1773      NaN     56.0        39.0  17.0          53.02651
#
#       adjusted_disapprove  adjusted_net  \
# 0               48.051880     -3.627609
# 1               52.281610     -8.944687
# 2               60.398650    -25.999300
# 3               58.284840    -23.142650
# 4               51.363850     -6.935669
# ...                   ...           ...
# 1769             7.313927      5.656153
# 1770            29.040990      4.348379
# 1771            36.352830      8.253242
# 1772            41.055830     12.407130
# 1773            41.478550     11.547960
#
#                                                     url createddate  \
# 0     https://issuesinsights.com/2025/06/30/trump-cl...   6/28/2025
# 1     https://maristpoll.marist.edu/wp-content/uploa...   6/25/2025
# 2     https://d3nkl3psvxxpe9.cloudfront.net/document...   6/30/2025
# 3     https://navigatorresearch.org/wp-content/uploa...   6/30/2025
# 4     https://tysongroup.co/wp-content/uploads/2025/...   6/26/2025
# ...                                                 ...         ...
# 1769  https://www.ipsos.com/en-us/reuters-ipsos-trum...   1/21/2025
# 1770  https://www.ipsos.com/en-us/reuters-ipsos-trum...   1/21/2025
# 1771  https://www.ipsos.com/en-us/reuters-ipsos-trum...   1/21/2025
# 1772  https://insideradvantage.com/first-insideradva...   1/20/2025
# 1773  https://insideradvantage.com/first-insideradva...   1/20/2025
#
#                  timestamp
# 0     23:00:44  7 Jul 2025
# 1     23:00:44  7 Jul 2025
# 2     23:00:57  7 Jul 2025
# 3     23:00:57  7 Jul 2025
# 4     23:00:44  7 Jul 2025
# ...                    ...
# 1769  23:00:51  7 Jul 2025
# 1770  23:00:47  7 Jul 2025
# 1771  23:00:53  7 Jul 2025
# 1772  23:00:41  7 Jul 2025
# 1773  23:00:36  7 Jul 2025
#
# [1774 rows x 20 columns]

# %%
# approval[approval['pollster']=='YouGov'][approval['subgroup']=='All polls']

# %%
approval = approval[~approval['subgroup'].isin(['Weak', 'Strong', 'Economy', 'Cost', 'Immigration', 'Trade', 'Adults', 'Voters'])]

# %%
approval.to_csv('trump_approval_polls.csv')

# %%
approval.columns.values
# Out:
# array(['president', 'subgroup', 'pollster', 'sponsors', 'startdate',
#        'enddate', 'samplesize', 'population', 'weight', 'influence',
#        'tracking', 'approve', 'disapprove', 'net', 'adjusted_approve',
#        'adjusted_disapprove', 'adjusted_net', 'url', 'createddate',
#        'timestamp'], dtype=object)

# %%
approval.shape
# Out:
# (384, 20)

# %%
# dates = approval['Dates'].str.extract(r'(\d{1,2}\/\d{1,2}) \- (\d{1,2}\/\d{1,2}), (\d{4})')
# dates

# %%
# dates['end_date'] = dates[1] + '/' + dates[2]
# dates['end_date'] = pd.to_datetime(dates['end_date'])
# dates

# %%
# approval['Dates'] = dates['end_date']
# approval.head()

# %%
# samples = approval['Sample'].str.extract(r'[0-9,]{3,5} (\w{1,2})@@(\d{3,4})')
# samples

# %%
# approval['population'] = samples[0]
# approval['sample_size'] = samples[1].astype(int)
# approval.head()

# %%
ratings = pd.read_csv('pollster_ratings_silver.csv')
ratings
# Out:
#                              Pollster    Grade  Predictive Plus-Minus  \
# 0                          AtlasIntel    A+@@1              -0.957740
# 1     Marquette University Law School   A/B@@4              -0.920261
# 2                 The Washington Post    A+@@1              -0.902281
# 3             Research & Polling Inc.     A@@2              -0.871136
# 4    The New York Times/Siena College     A@@2              -0.763947
# ..                                ...      ...                    ...
# 530          Nielson Brothers Polling  C/D@@12               1.946864
# 531                     Ascend Action  C/D@@12               2.282717
# 532       Jayhawk Consulting Services  C/D@@12               2.353968
# 533        Fort Hays State University  C/D@@12               2.489170
# 534                The Dartmouth Poll  C/D@@12               3.988291
#
#       Mean-reverted bias  Number of polls cat
# 0     D+0.16@@0.16334188               91  D+
# 1     D+0.32@@0.31545374               17  D+
# 2     D+0.90@@0.89811021               98  D+
# 3    R+0.55@@-0.54944503               44  R+
# 4      D+1.41@@1.4121077              116  D+
# ..                   ...              ...  ..
# 530    D+3.05@@3.0515239               11  D+
# 531    D+3.35@@3.3485439                6  D+
# 532    D+2.27@@2.2674108                2  D+
# 533   R+1.10@@-1.0960908                6  R+
# 534    D+4.40@@4.4045453                4  D+
#
# [535 rows x 6 columns]

# %%
ratings['Pollster'].values
# Out:
# array(['AtlasIntel', 'Marquette University Law School',
#        'The Washington Post', 'Research & Polling Inc.',
#        'The New York Times/Siena College', 'Cygnal', 'SurveyUSA',
#        'Siena College', 'Beacon Research/Shaw & Co. Research',
#        'Alaska Survey Research', 'OnMessage Inc.', 'TIPP Insights',
#        'Emerson College', 'Landmark Communications',
#        'Monmouth University', 'Data Orbital',
#        'University of North Florida', 'MassINC Polling Group',
#        'Marist College', 'Public Policy Institute of California',
#        'Public Policy Polling', 'University of California Berkeley',
#        'CBS News/The New York Times', 'Christopher Newport University',
#        'Mason-Dixon Polling & Strategy', 'Strategic Vision LLC',
#        'Suffolk University', 'Stockton University',
#        'Field Research Corp. (Field Poll)', 'Quinnipiac University',
#        'Los Angeles Times',
#        'Hart Research Associates/Public Opinion Strategies',
#        'Public Opinion Strategies', 'Susquehanna Polling & Research Inc.',
#        'Grove Insight', 'OH Predictive Insights', 'Echelon Insights',
#        'University of Massachusetts Lowell', 'Trafalgar Group',
#        'Saint Anselm College', 'co/efficient',
#        'Greenberg Quinlan Rosner/American Viewpoint',
#        'RKM Research and Communications Inc.', 'National Research',
#        'Tarrance Group', 'Dittman Research', 'RRH Elections', 'Selzer',
#        'Fairleigh Dickinson University', 'The Winston Group',
#        'Opinion Dynamics', 'University of Connecticut', 'Elway Research',
#        'Angus Reid Global', 'Muhlenberg College', 'Gallup',
#        'Fabrizio, Lee & Associates', 'Elon University',
#        'Pharos Research Group', 'Florida Atlantic University',
#        'Garin-Hart-Yang Research Group', 'Abt Associates',
#        'National Journal', 'Temple University',
#        'Princeton Survey Research Associates International',
#        'Landmark Communications/Rosetta Stone Communications',
#        'Michigan State University', 'Vox Populi Polling', 'KAConsulting',
#        'KRC Research', 'Western New England University',
#        'InsiderAdvantage', 'Lake Research Partners',
#        'Lake Research Partners/The Tarrance Group',
#        'East Carolina University', 'North Star Opinion Research',
#        'YouGov', 'Fleming & Associates',
#        'University of Cincinnati (Ohio Poll)', 'University of Arkansas',
#        'GfK Group', 'Rasmussen Reports',
#        'New England College Polling Center', 'Greenberg Quinlan Rosner',
#        'WPA Intelligence', 'SEA Polling & Strategic Design',
#        'Public Religion Research Institute', 'Optimus Analytics',
#        'Public Opinion Strategies/Hamilton Campaigns (Texas Credit Union League)',
#        'Glengariff Group', 'RAND (American Life Panel)',
#        'Magellan Strategies', 'Concord Public Opinion Partners',
#        'EPIC-MRA', 'Pew Research Center', 'Indiana University',
#        'Wirthlin Worldwide', 'Clemson University', 'St. Pete Polls',
#        'Knowledge Networks', 'Harper Polling', 'Belden Russonello',
#        'Louis Harris & Associates', 'Wick', 'Civiqs',
#        'Gravis Marketing/Kaplan Strategies',
#        'Harris Insights & Analytics', 'Blum & Weprin Associates',
#        'Pasquines', 'University of Florida', 'Gordon S. Black Corp.',
#        'University of Georgia', 'Ohio State University', 'J.L. Partners',
#        'Harstad Strategic Research', 'RT Strategies',
#        'Polling Company/Global Strategy Group',
#        'GQR Research/Public Opinion Strategies', 'Clarity Campaign Labs',
#        'Harvard University', 'Spry Strategies', 'Victory Research',
#        'Data for Progress', 'RMG Research', 'Praecones Analytica',
#        'Starboard Communications', 'Franklin & Marshall College',
#        'Ward Research', 'Mellman Group', 'Ciruli Associates',
#        'Strategic National', 'Patriot Polling', 'Dan Jones & Associates',
#        'Middle Tennessee State University', 'Remington Research Group',
#        'Leger', 'Keating Research', 'Ragnar Research Partners',
#        'Blueprint Polling', 'Yankelovich Partners Inc.',
#        'St. Norbert College', 'Pan Atlantic Research', 'Strategies 360',
#        'Redfield & Wilton Strategies', 'Market Shares Corp.',
#        'Columbus Dispatch', 'CVOTER', 'DCCC', 'ROI Rocket',
#        'Cardinal Point Analytics (CardinalGPS)', 'Lucid',
#        'Lee Business School (University of Nevada Las Vegas)',
#        'Edgewater Research/My People Vote', 'GBAO', 'Research 2000',
#        'University of South Alabama', 'OpinionWorks', 'Axis Research',
#        'Fabrizio, Lee & Associates/GBAO', 'High Point University',
#        'David Binder Research', 'Big Village', 'Impact Research',
#        'We Ask America', 'Market Research Institute Inc.',
#        'University of New Hampshire', 'RBI Strategies & Research',
#        'Ogden & Fry', 'Louisville Courier-Journal', 'DFM Research',
#        'Ipsos', 'Frederick Polls', 'Kiley & Company',
#        'BSP Research/Shaw & Company Research', 'Focaldata',
#        'Riley Research Associates', 'Schoen Cooperman Research',
#        'BK Strategies', 'Iowa State University',
#        'Benenson Strategy Group', 'McKeon & Associates',
#        'Alabama State University', "Maine People's Resource Center",
#        'El Nuevo Día/The Research Office', 'University of Washington',
#        'Latino Decisions', 'University of New Orleans',
#        'Meeting Street Insights', 'Orion Strategies', 'Big Data Poll',
#        'Richard Day Research', 'GS Strategy Group', 'Tulchin Research',
#        'IVR Polls', 'Google Consumer Surveys', 'John Zogby Strategies',
#        'Potomac Incorporated',
#        'Keating Research/OnSight Public Affairs/Melanson',
#        'MWR Strategies', 'University of Massachusetts (Amherst)',
#        'MSR Group', 'OnPoint', 'Change Research', 'JMC Analytics',
#        'Master Image', 'Douglas Fulmer & Associates', 'Basswood Research',
#        'Winthrop University', 'Northern Arizona University',
#        'Castleton University', 'Zogby Analytics', 'Tufts University',
#        'Torchlight Strategies', 'Gotham Polling & Analytics',
#        'M3 Strategies', 'CJ&N', 'Missouri State University',
#        'Financial Dynamics', 'Marshall Marketing', 'APC Research',
#        'Dixie Strategies', 'The Tyson Group', 'American Viewpoint',
#        'Overtime Politics', 'Morning Consult', 'Slingshot Strategies',
#        'CWS Research', 'Fabrizio Lee & Associates/Impact Research',
#        'Washington College', 'MFour Mobile Research',
#        'Wiese Research Associates', 'Merrill Poll', 'Braun Research',
#        'University of Southern California', 'Rethink Priorities',
#        'Park Street Strategies', 'Data Targeting',
#        'Southern Media & Opinion Research',
#        'University of Texas at Tyler', 'NewsNation',
#        'Minneapolis Star Tribune', 'The Citadel',
#        'Blumenthal Research Daily', 'Cherry Communications',
#        'PSB Research', 'Mason Strategies', '1892 Polling', 'DHM Research',
#        'Ethridge & Associates LLC', 'Baruch College Survey Research',
#        'Montgomery Research', 'Research Co.', 'Voter/Consumer Research',
#        'Bendixen & Amandi International',
#        'The Polling Company Inc./National Research Inc.',
#        'Valley Research', 'Personal Marketing Research',
#        'Franklin Pierce University',
#        'Behavior Research Center (Rocky Mountain Poll)',
#        'Market Solutions Group', 'Market Decisions Research',
#        'Scripps Howard', 'Forward Strategies', 'Targeted Persuasion',
#        'University of Houston', 'Singularis Group', 'CSP Polling',
#        'University of Wisconsin-Milwaukee',
#        'Reconnect Research/Probolsky Research', 'Beacon Research',
#        'JMC Analytics/Bold Blue Campaigns', 'National Public Affairs',
#        'Strategic Research Associates', 'Mercyhurst University', 'Odney',
#        'Diamond State Consulting Group', 'IMGE Insights', 'KG Polling',
#        'University of Tennessee', 'Jim Meader (KELOLAND-TV)',
#        'Virginia Commonwealth University', 'AYTM',
#        'Richmond Times-Dispatch',
#        'Global Strategy Group/National Research (Philadelphia Inquirer)',
#        'Manhattanville College', 'Garin-Hart-Yang/Global Strategy Group',
#        'War Room Logistics', 'The Polling Company Inc.',
#        'GreatBlue Research', 'Big Ten',
#        'African American Research Collaborative', 'Crantford Research',
#        'Jorge Benítez', 'Lincoln Institute', 'Seven Letter Insight',
#        'Quest Research Group', 'Strategy Research',
#        'Aspen Media & Market Research', 'Purple Strategies',
#        'Rivercity Polling', 'Probolsky Research',
#        'Florida International University/Univision',
#        'New Mexico State University', 'Drake Research & Strategy, Inc.',
#        'Myers Research & Strategic Services', 'Clarus Research Group',
#        'Morningside College', 'Thirty-Ninth Street Strategies',
#        'Frank N. Magid Associates Inc.',
#        'OurProgress (The Progress Campaign)', 'West Chester University',
#        'Canisius College', 'Central Surveys Inc.', 'ASA Marketing Group',
#        'Triumph Campaigns', 'Neighborhood Research and Media',
#        'BIGresearch', 'Moore Information Group', 'Cooper & Secrest',
#        'Escalent', 'Stetson University', 'Analytical Group', 'Penta',
#        'Dynamics Marketing', 'Vox Populi Communications',
#        'Diversified Research Inc', 'Centre College',
#        'Lauer, Lalley, Victoria', 'Market Trends Pacific', 'Cromer Group',
#        'Dynata', 'Dartmouth College', 'Global Strategy Group',
#        'Pacific Market Research', 'Liberty Opinion Research',
#        'NRECA Market Research', 'Wood Communications Group',
#        'Southeastern Louisiana University',
#        'University of Nevada Las Vegas', 'CallFire', 'Deltapoll',
#        'Zimmerman & Associates/Marketing Intelligence', 'TargetSmart',
#        'University of Wisconsin (Madison)', 'Rossman Group',
#        'Wick Communications', 'Capital Survey Research Center',
#        'Public Strategies Inc.', 'Targoz Market Research',
#        'Victoria Research & Consulting', 'Becker Institute',
#        'Iona University', 'QEV Analytics',
#        'West Virginia Research Center',
#        'Florida Atlantic University/Mainstreet Research', 'MarblePort',
#        'The Florida Poll', 'Rice University',
#        'Independent Market Research', 'CrossTarget', 'Alloy Analytics',
#        'Old Dominion University', 'TMR Research',
#        'Marketing Research Institute', 'Premise', 'A&A Research',
#        'Paradigm', 'Constituent Dynamics',
#        'SmithJohnson Opinion Research', 'Illinois Wesleyan University',
#        'Multi-Quest International', 'Decision Forecasting',
#        'Minnesota State University', 'Tulsa Surveys',
#        'TeleResearch Corporation', 'Feldman Group',
#        'Southern Research Group', 'Y2 Analytics',
#        'Harper Polling/Clarity Campaign Labs', 'Clout Research',
#        'Great Lakes Strategies Group',
#        'Montana State University Billings',
#        'California State University, Bakersfield',
#        'Howey Politics/DePauw University', 'Sky Research',
#        'Kimball Political Consulting', 'Detroit Free Press',
#        'University of Illinois at Chicago', 'Southern Opinion Research',
#        'Zata3', '20/20 Insight', 'Opinion Consultants',
#        'University of North Carolina', 'GaPundit.com',
#        'New Frontier Strategy', 'Baselice & Associates',
#        'Arthur J. Finkelstein & Associates',
#        'Bannon Communications Research', 'MarketAide Services Inc.',
#        'Patinkin Research Strategies', 'Forman Center',
#        'Baydoun Consulting', 'Auburn University', 'Abacus Associates',
#        'American Pulse Research & Polling',
#        'SMS Research & Marketing Services',
#        'Global Strategy Group/GBAO (Navigator Research)',
#        'Ed Renwick/Loyola University New Orleans', 'Hays Research Group',
#        'Zia Poll', 'SocialSphere', 'Lester & Associates',
#        'Datamar Analytics', 'ccAdvertising', 'EMC Research', 'PSI',
#        'American Research Group', 'Gazette Communications', 'LIT Data',
#        'Jeffrey Stonecash', 'Consumer Logic', 'Hoffman Research Group',
#        'Cometrends', 'Glover Park Group', 'Open Model Project',
#        'Univision/Latino Decisions/North Star Opinion Research',
#        'Neighbor', 'Normington, Petts & Associates',
#        'Lycoming College Polling Institute', 'Rainmaker Media Group',
#        'VCreek/AMG', 'The Kitchens Group', 'Lauer Johnson Research',
#        'University of Colorado (Boulder)', 'Saguaro Strategies',
#        'University of Alabama at Birmingham', 'Bold Decision',
#        'Phillips Academy', 'Ohio University', 'Hill Research Consultants',
#        'Hellenthal & Associates', 'Hendrix College',
#        'brilliant corners Research & Strategies', 'RMS Research',
#        'Data West Polling', 'Hunt Research',
#        'Gonzales Research & Marketing Strategies Inc.', 'WCIA-TV',
#        'HighGround Inc.', 'Nelson Research', 'Arizona State University',
#        'Hickman Analytics', 'The Justice Collaborative Institute',
#        'Cole Hargrave Snodgrass & Associates', 'Colby College',
#        'Thomas Partners Strategies/Optimus', 'Opinium',
#        'GCR & Associates', 'East Tennessee State University',
#        'Brandwatch Qriously',
#        'Consultoría Académica e Investigación Social LLC',
#        'Global Marketing Research Services', 'Market Research Insight',
#        'Victory Enterprises', 'Loras College', 'Victory Insights',
#        'Western Kentucky University', 'Bainbridge Media Group',
#        'Schapiro Group', 'SSRS', 'Miami Univerity',
#        'Marketing Resource Group (MRG)', 'SoonerPoll.com',
#        'Millersville University', 'Hampton University', 'Survation',
#        'Massie & Associates', 'Greg Smith & Associates', 'Citizen Data',
#        'BWD Global', 'University of Iowa', 'Roanoke College',
#        'Kiaer Research', 'DeSales University', 'SurveyMonkey', 'Swayable',
#        'Digital Research', 'IZQ Strategies', 'Repass',
#        'Bluegrass Community and Technical College', 'Marketing Workshop',
#        'Craciun Research Group', 'Momentum Analysis', 'TargetPoint',
#        'St. Cloud State University', 'Meredith College',
#        'Mitchell Research & Communications', 'Baldwin Wallace University',
#        'Merriman River Group', 'Truedot', 'Glascock Group', 'Elucd',
#        'Tomahawk Strategies', 'Carroll Strategies', 'Dane & Associates',
#        'GOP Calls', 'Amber Integrated', 'CPEC', 'Riggs Research Services',
#        'University of Minnesota', 'Thomas Partners Strategies',
#        'Target Insyght', 'Point Blank Political', 'Center Street PAC',
#        'Saint Leo University Polling Institute',
#        'Island Analytics & Marketing, LLC', 'University of Wyoming',
#        'FM3 Research', 'Rutgers University', 'Capen Analytics',
#        'McLaughlin & Associates',
#        'The Political Matrix/The Listener Group',
#        'Triton Polling & Research', 'RABA Research',
#        'Opinion Research Associates', 'Brigham Young University',
#        'Brown University', 'TCJ Research',
#        'Indiana University-Purdue University Fort Wayne (Downs Center)',
#        'Long Island University', 'Nielson Brothers Polling',
#        'Ascend Action', 'Jayhawk Consulting Services',
#        'Fort Hays State University', 'The Dartmouth Poll'], dtype=object)

# %%
ratings[ratings['Pollster'].str.contains('North Star')]#.sum()
# Out:
#                                               Pollster   Grade  \
# 75                         North Star Opinion Research  B/C@@8
# 425  Univision/Latino Decisions/North Star Opinion ...  B/C@@8
#
#      Predictive Plus-Minus   Mean-reverted bias  Number of polls cat
# 75                0.043339  R+0.63@@-0.62697512               13  R+
# 425               0.830409    D+1.06@@1.0564657                7  D+

# %%
banned_pollsters = ratings[ratings['Grade'].str.contains('F')]['Pollster'].values
banned_pollsters
# Out:
# array(['Strategic Vision LLC', 'Pharos Research Group', 'Research 2000',
#        'Big Data Poll', 'Overtime Politics', 'Rethink Priorities',
#        'Blumenthal Research Daily', 'CSP Polling', 'KG Polling',
#        'OurProgress (The Progress Campaign)', 'TCJ Research'],
#       dtype=object)

# %%
approval = approval[~approval['pollster'].isin(banned_pollsters)]
approval.shape
# Out:
# (384, 20)

# %%
approval = pd.merge(left=approval, right=ratings[['Pollster', 'Predictive Plus-Minus']], left_on='pollster',
                   right_on='Pollster', how='left')
approval
# Out:
#                    president   subgroup           pollster  \
# 0    Donald Trump (2nd term)  All polls      TIPP Insights
# 1    Donald Trump (2nd term)  All polls    Morning Consult
# 2    Donald Trump (2nd term)  All polls    Emerson College
# 3    Donald Trump (2nd term)  All polls  Rasmussen Reports
# 4    Donald Trump (2nd term)  All polls     Marist College
# ..                       ...        ...                ...
# 379  Donald Trump (2nd term)  All polls   Echelon Insights
# 380  Donald Trump (2nd term)  All polls         AtlasIntel
# 381  Donald Trump (2nd term)  All polls       RMG Research
# 382  Donald Trump (2nd term)  All polls              Ipsos
# 383  Donald Trump (2nd term)  All polls   InsiderAdvantage
#
#                    sponsors  startdate    enddate  samplesize population  \
# 0         Issues & Insights  6/26/2025  6/28/2025      1421.0          A
# 1                       NaN   7/3/2025   7/6/2025      2203.0         RV
# 2                       NaN  6/24/2025  6/25/2025      1000.0         RV
# 3                       NaN  6/27/2025   7/3/2025      1500.0         LV
# 4            NPR | PBS News  6/23/2025  6/25/2025      1381.0          A
# ..                      ...        ...        ...         ...        ...
# 379                     NaN  1/22/2025  1/24/2025      1024.0         LV
# 380                     NaN  1/21/2025  1/23/2025      1882.0          A
# 381  Napolitan News Service  1/20/2025  1/23/2025      3000.0         RV
# 382                 Reuters  1/20/2025  1/21/2025      1077.0          A
# 383                     NaN  1/20/2025  1/20/2025       800.0         RV
#
#        weight  influence  ... disapprove        net  adjusted_approve  \
# 0    1.482545   0.795084  ...       45.0  -1.000000          45.31171
# 1    0.758325   0.758325  ...       52.0  -7.000000          43.91041
# 2    1.392550   0.599789  ...       46.3  -1.399998          44.89963
# 3    0.842307   0.587045  ...       48.0   2.000000          46.98711
# 4    1.481290   0.553682  ...       52.0  -9.000000          43.99912
# ..        ...        ...  ...        ...        ...               ...
# 379  1.211361   0.000000  ...       43.0   8.000000          50.35032
# 380  1.910964   0.000000  ...       49.7   0.399998          49.92295
# 381  0.927446   0.000000  ...       39.0  18.000000          53.69668
# 382  0.749248   0.000000  ...       41.0   6.000000          49.13866
# 383  1.093180   0.000000  ...       39.0  17.000000          53.02651
#
#      adjusted_disapprove  adjusted_net  \
# 0               47.17788     -1.866169
# 1               53.26694     -9.356529
# 2               48.90335     -4.003719
# 3               49.70502     -2.717911
# 4               51.77161     -7.772491
# ..                   ...           ...
# 379             43.10314      7.247177
# 380             48.33114      1.591812
# 381             41.42194     12.274740
# 382             39.83569      9.302971
# 383             41.47855     11.547960
#
#                                                    url  createddate  \
# 0    https://issuesinsights.com/2025/06/30/trump-cl...    6/28/2025
# 1    https://pro.morningconsult.com/trackers/donald...     7/6/2025
# 2    https://emersoncollegepolling.com/june-nationa...    6/25/2025
# 3    https://www.rasmussenreports.com/public_conten...     7/3/2025
# 4    https://maristpoll.marist.edu/wp-content/uploa...    6/25/2025
# ..                                                 ...          ...
# 379  https://echeloninsights.com/in-the-news/dec-20...    1/24/2025
# 380  https://cdn.atlasintel.org/ed3f5238-e823-495e-...    1/23/2025
# 381  https://x.com/ScottWRasmussen/status/188280455...    1/23/2025
# 382  https://www.ipsos.com/en-us/reuters-ipsos-trum...    1/21/2025
# 383  https://insideradvantage.com/first-insideradva...    1/20/2025
#
#                 timestamp           Pollster Predictive Plus-Minus
# 0    23:00:36  7 Jul 2025      TIPP Insights             -0.571372
# 1    23:00:36  7 Jul 2025    Morning Consult              0.584994
# 2    23:00:36  7 Jul 2025    Emerson College             -0.569153
# 3    23:00:36  7 Jul 2025  Rasmussen Reports              0.087015
# 4    23:00:36  7 Jul 2025     Marist College             -0.436610
# ..                    ...                ...                   ...
# 379  23:00:36  7 Jul 2025   Echelon Insights             -0.216672
# 380  23:00:36  7 Jul 2025         AtlasIntel             -0.957740
# 381  23:00:36  7 Jul 2025       RMG Research              0.278023
# 382  23:00:36  7 Jul 2025              Ipsos              0.442898
# 383  23:00:36  7 Jul 2025   InsiderAdvantage              0.034562
#
# [384 rows x 22 columns]

# %%
approval.shape
# Out:
# (384, 22)

# %%
approval['Pollster'].value_counts()
# Out:
# Pollster
# Rasmussen Reports                                     116
# YouGov                                                 43
# Morning Consult                                        29
# RMG Research                                           23
# Ipsos                                                  17
# J.L. Partners                                          11
# TIPP Insights                                           9
# Global Strategy Group/GBAO (Navigator Research)         8
# Echelon Insights                                        8
# Harris Insights & Analytics                             7
# Quinnipiac University                                   6
# Gallup                                                  6
# Emerson College                                         6
# AtlasIntel                                              5
# John Zogby Strategies                                   5
# McLaughlin & Associates                                 5
# American Research Group                                 5
# SSRS                                                    4
# Clarity Campaign Labs                                   4
# InsiderAdvantage                                        3
# co/efficient                                            3
# Beacon Research/Shaw & Co. Research                     3
# Cygnal                                                  3
# Marquette University Law School                         3
# Civiqs                                                  3
# Marist College                                          3
# Pew Research Center                                     3
# SurveyMonkey                                            2
# Trafalgar Group                                         2
# Blueprint Polling                                       2
# Fabrizio Lee & Associates/Impact Research               2
# Hart Research Associates/Public Opinion Strategies      2
# Targoz Market Research                                  2
# NewsNation                                              1
# American Pulse Research & Polling                       1
# The New York Times/Siena College                        1
# OH Predictive Insights                                  1
# The Tyson Group                                         1
# University of Massachusetts (Amherst)                   1
# GBAO                                                    1
# Public Religion Research Institute                      1
# Public Opinion Strategies                               1
# Remington Research Group                                1
# North Star Opinion Research                             1
# OnMessage Inc.                                          1
# SurveyUSA                                               1
# Research Co.                                            1
# Name: count, dtype: int64

# %%
# approval[~approval['tracking'].isna()]

# %%
approval['tracking'].value_counts()
# Out:
# tracking
# True    120
# Name: count, dtype: int64

# %%
# full_approval = approval.copy()

# %%
approval = approval[(~approval['samplesize'].isna())]
approval
# Out:
#                    president   subgroup           pollster  \
# 0    Donald Trump (2nd term)  All polls      TIPP Insights
# 1    Donald Trump (2nd term)  All polls    Morning Consult
# 2    Donald Trump (2nd term)  All polls    Emerson College
# 3    Donald Trump (2nd term)  All polls  Rasmussen Reports
# 4    Donald Trump (2nd term)  All polls     Marist College
# ..                       ...        ...                ...
# 379  Donald Trump (2nd term)  All polls   Echelon Insights
# 380  Donald Trump (2nd term)  All polls         AtlasIntel
# 381  Donald Trump (2nd term)  All polls       RMG Research
# 382  Donald Trump (2nd term)  All polls              Ipsos
# 383  Donald Trump (2nd term)  All polls   InsiderAdvantage
#
#                    sponsors  startdate    enddate  samplesize population  \
# 0         Issues & Insights  6/26/2025  6/28/2025      1421.0          A
# 1                       NaN   7/3/2025   7/6/2025      2203.0         RV
# 2                       NaN  6/24/2025  6/25/2025      1000.0         RV
# 3                       NaN  6/27/2025   7/3/2025      1500.0         LV
# 4            NPR | PBS News  6/23/2025  6/25/2025      1381.0          A
# ..                      ...        ...        ...         ...        ...
# 379                     NaN  1/22/2025  1/24/2025      1024.0         LV
# 380                     NaN  1/21/2025  1/23/2025      1882.0          A
# 381  Napolitan News Service  1/20/2025  1/23/2025      3000.0         RV
# 382                 Reuters  1/20/2025  1/21/2025      1077.0          A
# 383                     NaN  1/20/2025  1/20/2025       800.0         RV
#
#        weight  influence  ... disapprove        net  adjusted_approve  \
# 0    1.482545   0.795084  ...       45.0  -1.000000          45.31171
# 1    0.758325   0.758325  ...       52.0  -7.000000          43.91041
# 2    1.392550   0.599789  ...       46.3  -1.399998          44.89963
# 3    0.842307   0.587045  ...       48.0   2.000000          46.98711
# 4    1.481290   0.553682  ...       52.0  -9.000000          43.99912
# ..        ...        ...  ...        ...        ...               ...
# 379  1.211361   0.000000  ...       43.0   8.000000          50.35032
# 380  1.910964   0.000000  ...       49.7   0.399998          49.92295
# 381  0.927446   0.000000  ...       39.0  18.000000          53.69668
# 382  0.749248   0.000000  ...       41.0   6.000000          49.13866
# 383  1.093180   0.000000  ...       39.0  17.000000          53.02651
#
#      adjusted_disapprove  adjusted_net  \
# 0               47.17788     -1.866169
# 1               53.26694     -9.356529
# 2               48.90335     -4.003719
# 3               49.70502     -2.717911
# 4               51.77161     -7.772491
# ..                   ...           ...
# 379             43.10314      7.247177
# 380             48.33114      1.591812
# 381             41.42194     12.274740
# 382             39.83569      9.302971
# 383             41.47855     11.547960
#
#                                                    url  createddate  \
# 0    https://issuesinsights.com/2025/06/30/trump-cl...    6/28/2025
# 1    https://pro.morningconsult.com/trackers/donald...     7/6/2025
# 2    https://emersoncollegepolling.com/june-nationa...    6/25/2025
# 3    https://www.rasmussenreports.com/public_conten...     7/3/2025
# 4    https://maristpoll.marist.edu/wp-content/uploa...    6/25/2025
# ..                                                 ...          ...
# 379  https://echeloninsights.com/in-the-news/dec-20...    1/24/2025
# 380  https://cdn.atlasintel.org/ed3f5238-e823-495e-...    1/23/2025
# 381  https://x.com/ScottWRasmussen/status/188280455...    1/23/2025
# 382  https://www.ipsos.com/en-us/reuters-ipsos-trum...    1/21/2025
# 383  https://insideradvantage.com/first-insideradva...    1/20/2025
#
#                 timestamp           Pollster Predictive Plus-Minus
# 0    23:00:36  7 Jul 2025      TIPP Insights             -0.571372
# 1    23:00:36  7 Jul 2025    Morning Consult              0.584994
# 2    23:00:36  7 Jul 2025    Emerson College             -0.569153
# 3    23:00:36  7 Jul 2025  Rasmussen Reports              0.087015
# 4    23:00:36  7 Jul 2025     Marist College             -0.436610
# ..                    ...                ...                   ...
# 379  23:00:36  7 Jul 2025   Echelon Insights             -0.216672
# 380  23:00:36  7 Jul 2025         AtlasIntel             -0.957740
# 381  23:00:36  7 Jul 2025       RMG Research              0.278023
# 382  23:00:36  7 Jul 2025              Ipsos              0.442898
# 383  23:00:36  7 Jul 2025   InsiderAdvantage              0.034562
#
# [384 rows x 22 columns]

# %%
auxiliary = pd.read_csv('auxiliary_pollster_rating_stats.csv')
auxiliary
# Out:
#                               Pollster  Correct calls       Outside MoE  \
# 0                           AtlasIntel       0.840659   8.8%@@91.208791
# 1                  The Washington Post       0.693878   6.1%@@93.877551
# 2              Research & Polling Inc.       0.886364  9.1%@@90.9090906
# 3     The New York Times/Siena College       0.737069  18.1%@@81.896552
# 4                               Cygnal       0.939655  13.8%@@86.206897
# ..                                 ...            ...               ...
# 93                    Digital Research       0.904762  38.1%@@61.904761
# 94  Mitchell Research & Communications       0.695122    39%@@60.975611
# 95                Merriman River Group       0.840000    60%@@39.999998
# 96             McLaughlin & Associates       0.689655  34.5%@@65.517241
# 97                        TCJ Research       0.590909  49.2%@@50.757575
#
#            House effect             ADPA  Herding penalty  herd_cat p_cat
# 0    R+2.00@@-1.9990723   3.7@@3.6687982         0.096047         2    R+
# 1     D+1.02@@1.0173736   3.6@@3.5756676         0.221841         3    D+
# 2    D+0.63@@0.63289553    4.6@@4.642076         0.286276         3    D+
# 3    D+0.79@@0.79133403   3.2@@3.2483816         0.280332         3    D+
# 4   R+0.60@@-0.59704119   3.5@@3.4644768         0.521310         4    R+
# ..                  ...              ...              ...       ...   ...
# 93   R+2.44@@-2.4431372  11.4@@11.413808         0.000000         1    R+
# 94  R+0.45@@-0.44617203   4.4@@4.4410443         0.229193         3    R+
# 95   R+3.23@@-3.2347174  10.3@@10.260222         0.000000         1    R+
# 96   R+4.94@@-4.9392128     6.2@@6.17804         0.000000         1    R+
# 97   R+3.42@@-3.4232018   4.4@@4.3859954         0.000000         1    R+
#
# [98 rows x 8 columns]

# %%
house_eff = auxiliary['House effect'].str.extract(r'(\w)\+(\d\.\d\d)@@*.')
house_eff[1] = house_eff[1].astype(float)
house_eff
# Out:
#     0     1
# 0   R  2.00
# 1   D  1.02
# 2   D  0.63
# 3   D  0.79
# 4   R  0.60
# .. ..   ...
# 93  R  2.44
# 94  R  0.45
# 95  R  3.23
# 96  R  4.94
# 97  R  3.42
#
# [98 rows x 2 columns]

# %%
# R --> -1, D --> 1
house_eff[0] = house_eff[0].replace({'R':-1, 'D':1})
house_eff['house_effect'] = house_eff[0] * house_eff[1]
house_eff
# Out:
#     0     1  house_effect
# 0  -1  2.00         -2.00
# 1   1  1.02          1.02
# 2   1  0.63          0.63
# 3   1  0.79          0.79
# 4  -1  0.60         -0.60
# .. ..   ...           ...
# 93 -1  2.44         -2.44
# 94 -1  0.45         -0.45
# 95 -1  3.23         -3.23
# 96 -1  4.94         -4.94
# 97 -1  3.42         -3.42
#
# [98 rows x 3 columns]

# %%
auxiliary['house_effect'] = house_eff['house_effect']
auxiliary = auxiliary.set_index(['Pollster'])
auxiliary
# Out:
#                                     Correct calls       Outside MoE  \
# Pollster
# AtlasIntel                               0.840659   8.8%@@91.208791
# The Washington Post                      0.693878   6.1%@@93.877551
# Research & Polling Inc.                  0.886364  9.1%@@90.9090906
# The New York Times/Siena College         0.737069  18.1%@@81.896552
# Cygnal                                   0.939655  13.8%@@86.206897
# ...                                           ...               ...
# Digital Research                         0.904762  38.1%@@61.904761
# Mitchell Research & Communications       0.695122    39%@@60.975611
# Merriman River Group                     0.840000    60%@@39.999998
# McLaughlin & Associates                  0.689655  34.5%@@65.517241
# TCJ Research                             0.590909  49.2%@@50.757575
#
#                                            House effect             ADPA  \
# Pollster
# AtlasIntel                           R+2.00@@-1.9990723   3.7@@3.6687982
# The Washington Post                   D+1.02@@1.0173736   3.6@@3.5756676
# Research & Polling Inc.              D+0.63@@0.63289553    4.6@@4.642076
# The New York Times/Siena College     D+0.79@@0.79133403   3.2@@3.2483816
# Cygnal                              R+0.60@@-0.59704119   3.5@@3.4644768
# ...                                                 ...              ...
# Digital Research                     R+2.44@@-2.4431372  11.4@@11.413808
# Mitchell Research & Communications  R+0.45@@-0.44617203   4.4@@4.4410443
# Merriman River Group                 R+3.23@@-3.2347174  10.3@@10.260222
# McLaughlin & Associates              R+4.94@@-4.9392128     6.2@@6.17804
# TCJ Research                         R+3.42@@-3.4232018   4.4@@4.3859954
#
#                                     Herding penalty  herd_cat p_cat  \
# Pollster
# AtlasIntel                                 0.096047         2    R+
# The Washington Post                        0.221841         3    D+
# Research & Polling Inc.                    0.286276         3    D+
# The New York Times/Siena College           0.280332         3    D+
# Cygnal                                     0.521310         4    R+
# ...                                             ...       ...   ...
# Digital Research                           0.000000         1    R+
# Mitchell Research & Communications         0.229193         3    R+
# Merriman River Group                       0.000000         1    R+
# McLaughlin & Associates                    0.000000         1    R+
# TCJ Research                               0.000000         1    R+
#
#                                     house_effect
# Pollster
# AtlasIntel                                 -2.00
# The Washington Post                         1.02
# Research & Polling Inc.                     0.63
# The New York Times/Siena College            0.79
# Cygnal                                     -0.60
# ...                                          ...
# Digital Research                           -2.44
# Mitchell Research & Communications         -0.45
# Merriman River Group                       -3.23
# McLaughlin & Associates                    -4.94
# TCJ Research                               -3.42
#
# [98 rows x 8 columns]

# %%
def apply_house_eff(data, pollster):
    df = data[data['pollster']==pollster]
    try:
        df['approve_adj'] = df['approve'] + (auxiliary.loc[pollster, 'house_effect'] / 2)
        df['disapprove_adj'] = df['disapprove'] - (auxiliary.loc[pollster, 'house_effect'] / 2)
    except KeyError:
        df['approve_adj'] = df['approve']
        df['disapprove_adj'] = df['disapprove']
    return df

# %%
pollsters = approval['pollster'].value_counts().index.values
df_adjs = []
for p in pollsters:
    df = apply_house_eff(approval, p)
    df_adjs.append(df)

approval_adj = pd.concat(df_adjs, axis=0)
approval_adj
# Out:
#                    president   subgroup  \
# 3    Donald Trump (2nd term)  All polls
# 28   Donald Trump (2nd term)  All polls
# 34   Donald Trump (2nd term)  All polls
# 36   Donald Trump (2nd term)  All polls
# 39   Donald Trump (2nd term)  All polls
# ..                       ...        ...
# 150  Donald Trump (2nd term)  All polls
# 139  Donald Trump (2nd term)  All polls
# 13   Donald Trump (2nd term)  All polls
# 114  Donald Trump (2nd term)  All polls
# 377  Donald Trump (2nd term)  All polls
#
#                                   pollster                   sponsors  \
# 3                        Rasmussen Reports                        NaN
# 28                       Rasmussen Reports                        NaN
# 34                       Rasmussen Reports                        NaN
# 36                       Rasmussen Reports                        NaN
# 39                       Rasmussen Reports                        NaN
# ..                                     ...                        ...
# 150                    Lord Ashcroft Polls                        NaN
# 139  University of Massachusetts (Amherst)                    WCVB-TV
# 13       American Pulse Research & Polling                        NaN
# 114                          Fabrizio Ward  Pinpoint Policy Institute
# 377                           Research Co.                        NaN
#
#      startdate    enddate  samplesize population    weight  influence  ...  \
# 3    6/27/2025   7/3/2025      1500.0         LV  0.842307   0.587045  ...
# 28   6/20/2025  6/26/2025      1500.0         LV  0.324773   0.096808  ...
# 34   6/26/2025   7/2/2025      1500.0         LV  0.117946   0.074957  ...
# 36   6/25/2025   7/1/2025      1500.0         LV  0.115884   0.066495  ...
# 39   6/23/2025  6/27/2025      1500.0         LV  0.155384   0.060040  ...
# ..         ...        ...         ...        ...       ...        ...  ...
# 150   4/9/2025  4/30/2025     10000.0          A  1.346009   0.000000  ...
# 139   4/4/2025   4/9/2025      1000.0          A  0.983206   0.000000  ...
# 13   6/23/2025  6/25/2025       633.0         RV  0.813438   0.304050  ...
# 114  5/15/2025  5/19/2025       800.0         RV  1.129986   0.000000  ...
# 377  1/22/2025  1/24/2025      1001.0          A  0.951747   0.000000  ...
#
#     adjusted_approve  adjusted_disapprove  adjusted_net  \
# 3           46.98711             49.70502     -2.717911
# 28          47.98711             49.70502     -1.717911
# 34          45.98711             49.70502     -3.717911
# 36          46.98711             48.70502     -1.717911
# 39          47.98711             49.70502     -1.717911
# ..               ...                  ...           ...
# 150         44.70750             52.92816     -8.220661
# 139         44.33548             51.03156     -6.696079
# 13          48.41513             49.66492     -1.249790
# 114         45.98891             49.50351     -3.514599
# 377         50.08488             45.40564      4.679241
#
#                                                    url  createddate  \
# 3    https://www.rasmussenreports.com/public_conten...     7/3/2025
# 28   https://www.rasmussenreports.com/public_conten...    6/26/2025
# 34   https://www.rasmussenreports.com/public_conten...     7/2/2025
# 36   https://www.rasmussenreports.com/public_conten...     7/1/2025
# 39   https://www.rasmussenreports.com/public_conten...    6/27/2025
# ..                                                 ...          ...
# 150  https://lordashcroftpolls.com/2025/05/trump-am...    4/30/2025
# 139  https://www.umass.edu/political-science/about/...     4/9/2025
# 13   https://s3.amazonaws.com/kajabi-storefronts-pr...    6/25/2025
# 114  https://pinpointpolicyinstitute.org/wp-content...    5/19/2025
# 377  https://researchco.ca/2025/01/27/immigration-usa/    1/24/2025
#
#                 timestamp                               Pollster  \
# 3    23:00:36  7 Jul 2025                      Rasmussen Reports
# 28   23:00:36  7 Jul 2025                      Rasmussen Reports
# 34   23:00:36  7 Jul 2025                      Rasmussen Reports
# 36   23:00:36  7 Jul 2025                      Rasmussen Reports
# 39   23:00:36  7 Jul 2025                      Rasmussen Reports
# ..                    ...                                    ...
# 150  23:00:36  7 Jul 2025                                    NaN
# 139  23:00:36  7 Jul 2025  University of Massachusetts (Amherst)
# 13   23:00:36  7 Jul 2025      American Pulse Research & Polling
# 114  23:00:36  7 Jul 2025                                    NaN
# 377  23:00:36  7 Jul 2025                           Research Co.
#
#     Predictive Plus-Minus approve_adj disapprove_adj
# 3                0.087015      49.360         48.640
# 28               0.087015      50.360         48.640
# 34               0.087015      48.360         48.640
# 36               0.087015      49.360         47.640
# 39               0.087015      50.360         48.640
# ..                    ...         ...            ...
# 150                   NaN      45.000         53.000
# 139              0.536200      44.000         51.000
# 13               0.800463      49.700         48.900
# 114                   NaN      46.000         49.000
# 377              0.632258      50.295         45.705
#
# [384 rows x 24 columns]

# %%
approval.shape
# Out:
# (384, 22)

# %%
approval = approval_adj.copy()
approval.shape
# Out:
# (384, 24)

# %%
approval['poll_id'] = pd.factorize(approval['pollster'] + approval['enddate'] + approval['sponsors'].fillna('none'))[0]
approval.head(7)
# Out:
#                   president   subgroup           pollster sponsors  startdate  \
# 3   Donald Trump (2nd term)  All polls  Rasmussen Reports      NaN  6/27/2025
# 28  Donald Trump (2nd term)  All polls  Rasmussen Reports      NaN  6/20/2025
# 34  Donald Trump (2nd term)  All polls  Rasmussen Reports      NaN  6/26/2025
# 36  Donald Trump (2nd term)  All polls  Rasmussen Reports      NaN  6/25/2025
# 39  Donald Trump (2nd term)  All polls  Rasmussen Reports      NaN  6/23/2025
# 40  Donald Trump (2nd term)  All polls  Rasmussen Reports      NaN  6/24/2025
# 42  Donald Trump (2nd term)  All polls  Rasmussen Reports      NaN  6/13/2025
#
#       enddate  samplesize population    weight  influence  ...  \
# 3    7/3/2025      1500.0         LV  0.842307   0.587045  ...
# 28  6/26/2025      1500.0         LV  0.324773   0.096808  ...
# 34   7/2/2025      1500.0         LV  0.117946   0.074957  ...
# 36   7/1/2025      1500.0         LV  0.115884   0.066495  ...
# 39  6/27/2025      1500.0         LV  0.155384   0.060040  ...
# 40  6/30/2025      1500.0         LV  0.114323   0.058442  ...
# 42  6/19/2025      1500.0         LV  0.319266   0.039821  ...
#
#    adjusted_disapprove  adjusted_net  \
# 3             49.70502     -2.717911
# 28            49.70502     -1.717911
# 34            49.70502     -3.717911
# 36            48.70502     -1.717911
# 39            49.70502     -1.717911
# 40            48.70502     -0.717911
# 42            48.70502      0.282089
#
#                                                   url  createddate  \
# 3   https://www.rasmussenreports.com/public_conten...     7/3/2025
# 28  https://www.rasmussenreports.com/public_conten...    6/26/2025
# 34  https://www.rasmussenreports.com/public_conten...     7/2/2025
# 36  https://www.rasmussenreports.com/public_conten...     7/1/2025
# 39  https://www.rasmussenreports.com/public_conten...    6/27/2025
# 40  https://www.rasmussenreports.com/public_conten...    6/30/2025
# 42  https://www.rasmussenreports.com/public_conten...    6/19/2025
#
#                timestamp           Pollster  Predictive Plus-Minus  \
# 3   23:00:36  7 Jul 2025  Rasmussen Reports               0.087015
# 28  23:00:36  7 Jul 2025  Rasmussen Reports               0.087015
# 34  23:00:36  7 Jul 2025  Rasmussen Reports               0.087015
# 36  23:00:36  7 Jul 2025  Rasmussen Reports               0.087015
# 39  23:00:36  7 Jul 2025  Rasmussen Reports               0.087015
# 40  23:00:36  7 Jul 2025  Rasmussen Reports               0.087015
# 42  23:00:36  7 Jul 2025  Rasmussen Reports               0.087015
#
#    approve_adj disapprove_adj poll_id
# 3        49.36          48.64       0
# 28       50.36          48.64       1
# 34       48.36          48.64       2
# 36       49.36          47.64       3
# 39       50.36          48.64       4
# 40       50.36          47.64       5
# 42       51.36          47.64       6
#
# [7 rows x 25 columns]

# %%
approval['population'] = approval['population'].str.strip(' ')

# %%
def pipeline(data: pd.DataFrame):
    dup = data[data.duplicated(subset='poll_id', keep=False)]
    ndup = data[~data.duplicated(subset='poll_id', keep=False)]
    # print('dup', dup, '\n ndup', ndup)
    dup_a = dup[dup['population'].isin(['A'])]
    # print('dup_a', dup_a)
    df = pd.concat([dup_a, ndup], axis=0)
    
    dup = df[df.duplicated(subset='poll_id', keep=False)]
    ndup = df[~df.duplicated(subset='poll_id', keep=False)]
    dup_lv = dup[dup['population'].isin(['RV'])]
    # print('dup_rv', dup_lv, 'ndup', ndup)
    df = pd.concat([dup_lv, ndup], axis=0)
    
    df['end_date'] = pd.to_datetime(df['end_date'])
    
    return df

# %%
approval = approval.rename({'enddate':'end_date', 'samplesize':'sample_size', 'Predictive Plus-Minus':'pred_plus_minus'}, axis=1)

# %%
approval['population'].value_counts().index.values
# Out:
# array(['LV', 'RV', 'A', 'V'], dtype=object)

# %%
approval.shape, pipeline(approval).shape
# Out:
# ((384, 25), (372, 25))

# %%
pipeline(approval)
# Out:
#                    president   subgroup  \
# 3    Donald Trump (2nd term)  All polls
# 28   Donald Trump (2nd term)  All polls
# 34   Donald Trump (2nd term)  All polls
# 36   Donald Trump (2nd term)  All polls
# 39   Donald Trump (2nd term)  All polls
# ..                       ...        ...
# 150  Donald Trump (2nd term)  All polls
# 139  Donald Trump (2nd term)  All polls
# 13   Donald Trump (2nd term)  All polls
# 114  Donald Trump (2nd term)  All polls
# 377  Donald Trump (2nd term)  All polls
#
#                                   pollster                   sponsors  \
# 3                        Rasmussen Reports                        NaN
# 28                       Rasmussen Reports                        NaN
# 34                       Rasmussen Reports                        NaN
# 36                       Rasmussen Reports                        NaN
# 39                       Rasmussen Reports                        NaN
# ..                                     ...                        ...
# 150                    Lord Ashcroft Polls                        NaN
# 139  University of Massachusetts (Amherst)                    WCVB-TV
# 13       American Pulse Research & Polling                        NaN
# 114                          Fabrizio Ward  Pinpoint Policy Institute
# 377                           Research Co.                        NaN
#
#      startdate   end_date  sample_size population    weight  influence  ...  \
# 3    6/27/2025 2025-07-03       1500.0         LV  0.842307   0.587045  ...
# 28   6/20/2025 2025-06-26       1500.0         LV  0.324773   0.096808  ...
# 34   6/26/2025 2025-07-02       1500.0         LV  0.117946   0.074957  ...
# 36   6/25/2025 2025-07-01       1500.0         LV  0.115884   0.066495  ...
# 39   6/23/2025 2025-06-27       1500.0         LV  0.155384   0.060040  ...
# ..         ...        ...          ...        ...       ...        ...  ...
# 150   4/9/2025 2025-04-30      10000.0          A  1.346009   0.000000  ...
# 139   4/4/2025 2025-04-09       1000.0          A  0.983206   0.000000  ...
# 13   6/23/2025 2025-06-25        633.0         RV  0.813438   0.304050  ...
# 114  5/15/2025 2025-05-19        800.0         RV  1.129986   0.000000  ...
# 377  1/22/2025 2025-01-24       1001.0          A  0.951747   0.000000  ...
#
#     adjusted_disapprove  adjusted_net  \
# 3              49.70502     -2.717911
# 28             49.70502     -1.717911
# 34             49.70502     -3.717911
# 36             48.70502     -1.717911
# 39             49.70502     -1.717911
# ..                  ...           ...
# 150            52.92816     -8.220661
# 139            51.03156     -6.696079
# 13             49.66492     -1.249790
# 114            49.50351     -3.514599
# 377            45.40564      4.679241
#
#                                                    url  createddate  \
# 3    https://www.rasmussenreports.com/public_conten...     7/3/2025
# 28   https://www.rasmussenreports.com/public_conten...    6/26/2025
# 34   https://www.rasmussenreports.com/public_conten...     7/2/2025
# 36   https://www.rasmussenreports.com/public_conten...     7/1/2025
# 39   https://www.rasmussenreports.com/public_conten...    6/27/2025
# ..                                                 ...          ...
# 150  https://lordashcroftpolls.com/2025/05/trump-am...    4/30/2025
# 139  https://www.umass.edu/political-science/about/...     4/9/2025
# 13   https://s3.amazonaws.com/kajabi-storefronts-pr...    6/25/2025
# 114  https://pinpointpolicyinstitute.org/wp-content...    5/19/2025
# 377  https://researchco.ca/2025/01/27/immigration-usa/    1/24/2025
#
#                 timestamp                               Pollster  \
# 3    23:00:36  7 Jul 2025                      Rasmussen Reports
# 28   23:00:36  7 Jul 2025                      Rasmussen Reports
# 34   23:00:36  7 Jul 2025                      Rasmussen Reports
# 36   23:00:36  7 Jul 2025                      Rasmussen Reports
# 39   23:00:36  7 Jul 2025                      Rasmussen Reports
# ..                    ...                                    ...
# 150  23:00:36  7 Jul 2025                                    NaN
# 139  23:00:36  7 Jul 2025  University of Massachusetts (Amherst)
# 13   23:00:36  7 Jul 2025      American Pulse Research & Polling
# 114  23:00:36  7 Jul 2025                                    NaN
# 377  23:00:36  7 Jul 2025                           Research Co.
#
#      pred_plus_minus approve_adj disapprove_adj poll_id
# 3           0.087015      49.360         48.640       0
# 28          0.087015      50.360         48.640       1
# 34          0.087015      48.360         48.640       2
# 36          0.087015      49.360         47.640       3
# 39          0.087015      50.360         48.640       4
# ..               ...         ...            ...     ...
# 150              NaN      45.000         53.000     373
# 139         0.536200      44.000         51.000     374
# 13          0.800463      49.700         48.900     375
# 114              NaN      46.000         49.000     376
# 377         0.632258      50.295         45.705     377
#
# [372 rows x 25 columns]

# %%
# approval[approval['pollster']=='Harris Insights & Analytics']

# %%
full_approval = approval.copy()

# %%
approval = approval[approval['tracking'].isna()]

# %%
# banned_pollsters_aux = ['Rasmussen Reports', 'co/efficient', 'TIPP Insights', 'Civiqs', 'Trafalgar Group', 'OnMessage Inc.']
banned_pollsters_aux = pd.read_csv('banned_pollsters_aux.csv')['banned_pollsters'].values
banned_pollsters_aux
# Out:
# array(['Rasmussen Reports', 'TIPP Insights', 'Trafalgar Group',
#        'Trafalgar Group/Insider Advantage'], dtype=object)

# %%
approval = approval[~approval['pollster'].isin(banned_pollsters_aux)]
approval.head()
# Out:
#                   president   subgroup pollster   sponsors  startdate  \
# 12  Donald Trump (2nd term)  All polls   YouGov  Economist  6/13/2025
# 27  Donald Trump (2nd term)  All polls   YouGov  Economist   6/6/2025
# 29  Donald Trump (2nd term)  All polls   YouGov   CBS News   6/4/2025
# 36  Donald Trump (2nd term)  All polls   YouGov  Economist  5/30/2025
# 48  Donald Trump (2nd term)  All polls   YouGov  Economist  5/23/2025
#
#      end_date  sample_size population    weight  influence  ...  \
# 12  6/16/2025       1512.0          A  0.839664   0.629156  ...
# 27   6/9/2025       1533.0          A  0.636911   0.202253  ...
# 29   6/6/2025       2428.0          A  0.727909   0.175116  ...
# 36   6/2/2025       1610.0          A  0.583608   0.086208  ...
# 48  5/26/2025       1660.0          A  0.565511   0.025114  ...
#
#    adjusted_disapprove  adjusted_net  \
# 12            54.41121    -12.544790
# 27            52.41121     -8.544788
# 29            55.41121     -9.544788
# 36            49.41121     -3.544788
# 48            52.41121     -7.544788
#
#                                                   url  createddate  \
# 12  https://d3nkl3psvxxpe9.cloudfront.net/document...    6/16/2025
# 27  https://d3nkl3psvxxpe9.cloudfront.net/document...     6/9/2025
# 29  https://www.cbsnews.com/news/deportation-immig...     6/6/2025
# 36  https://d3nkl3psvxxpe9.cloudfront.net/document...     6/2/2025
# 48  https://d3nkl3psvxxpe9.cloudfront.net/document...    5/26/2025
#
#                timestamp  Pollster  pred_plus_minus approve_adj  \
# 12  19:00:26 23 Jun 2025    YouGov         0.047635       41.25
# 27  19:00:26 23 Jun 2025    YouGov         0.047635       43.25
# 29  19:00:26 23 Jun 2025    YouGov         0.047635       45.25
# 36  19:00:26 23 Jun 2025    YouGov         0.047635       45.25
# 48  19:00:26 23 Jun 2025    YouGov         0.047635       44.25
#
#    disapprove_adj poll_id
# 12          53.75     106
# 27          51.75     107
# 29          54.75     108
# 36          48.75     109
# 48          51.75     110
#
# [5 rows x 25 columns]

# %%
approval[approval['pollster']=='Civiqs']# [['approve', 'disapprove', 'approve_adj', 'disapprove_adj']]
# Out:
#                    president   subgroup pollster   sponsors  startdate  \
# 78   Donald Trump (2nd term)  All polls   Civiqs  Daily Kos  5/17/2025
# 168  Donald Trump (2nd term)  All polls   Civiqs  Daily Kos  4/12/2025
# 207  Donald Trump (2nd term)  All polls   Civiqs  Daily Kos  2/28/2025
#
#       end_date  sample_size population    weight  influence  ...  \
# 78   5/20/2025       1018.0         RV  1.120966        0.0  ...
# 168  4/15/2025       1124.0         RV  1.149724        0.0  ...
# 207   3/3/2025       1031.0         RV  1.124632        0.0  ...
#
#     adjusted_disapprove  adjusted_net  \
# 78             51.25166     -4.620358
# 168            52.25166     -6.620358
# 207            51.25166     -3.620358
#
#                                                    url  createddate  \
# 78   https://civiqs.com/documents/Civiqs_DailyKos_b...    5/20/2025
# 168  https://civiqs.com/reports/2025/04/17/report-a...    4/15/2025
# 207  https://civiqs.com/reports/2025/03/04/report-a...     3/3/2025
#
#                 timestamp  Pollster  pred_plus_minus approve_adj  \
# 78   19:00:26 23 Jun 2025    Civiqs         0.158562       47.86
# 168  19:00:26 23 Jun 2025    Civiqs         0.158562       46.86
# 207  19:00:26 23 Jun 2025    Civiqs         0.158562       48.86
#
#     disapprove_adj poll_id
# 78           51.14     294
# 168          52.14     295
# 207          51.14     296
#
# [3 rows x 25 columns]

# %%
approval.columns.values
# Out:
# array(['president', 'subgroup', 'pollster', 'sponsors', 'startdate',
#        'end_date', 'sample_size', 'population', 'weight', 'influence',
#        'tracking', 'approve', 'disapprove', 'net', 'adjusted_approve',
#        'adjusted_disapprove', 'adjusted_net', 'url', 'createddate',
#        'timestamp', 'Pollster', 'pred_plus_minus', 'approve_adj',
#        'disapprove_adj', 'poll_id'], dtype=object)

# %%
approval_polls = approval[['pollster', 'sponsors', 'startdate', 'end_date', 'sample_size', 'population', 'approve', 'disapprove', 'approve_adj', 'disapprove_adj', 'net', 'url', 'pred_plus_minus', 'poll_id']]
approval_polls
# Out:
#                                   pollster                   sponsors  \
# 12                                  YouGov                  Economist
# 27                                  YouGov                  Economist
# 29                                  YouGov                   CBS News
# 36                                  YouGov                  Economist
# 48                                  YouGov                  Economist
# ..                                     ...                        ...
# 85                           Fabrizio Ward  Pinpoint Policy Institute
# 161                 OH Predictive Insights              Center Square
# 110  University of Massachusetts (Amherst)                    WCVB-TV
# 143       The New York Times/Siena College                        NaN
# 348                           Research Co.                        NaN
#
#      startdate   end_date  sample_size population  approve  disapprove  \
# 12   6/13/2025  6/16/2025       1512.0          A     41.0        54.0
# 27    6/6/2025   6/9/2025       1533.0          A     43.0        52.0
# 29    6/4/2025   6/6/2025       2428.0          A     45.0        55.0
# 36   5/30/2025   6/2/2025       1610.0          A     45.0        49.0
# 48   5/23/2025  5/26/2025       1660.0          A     44.0        52.0
# ..         ...        ...          ...        ...      ...         ...
# 85   5/15/2025  5/19/2025        800.0         RV     46.0        49.0
# 161  4/15/2025  4/18/2025       2527.0         RV     44.0        53.0
# 110   4/4/2025   4/9/2025       1000.0          A     44.0        51.0
# 143  4/21/2025  4/24/2025        913.0         RV     42.0        54.0
# 348  1/22/2025  1/24/2025       1001.0          A     50.0        46.0
#
#      approve_adj  disapprove_adj   net  \
# 12        41.250          53.750 -13.0
# 27        43.250          51.750  -9.0
# 29        45.250          54.750 -10.0
# 36        45.250          48.750  -4.0
# 48        44.250          51.750  -8.0
# ..           ...             ...   ...
# 85        46.000          49.000  -3.0
# 161       45.065          51.935  -9.0
# 110       44.000          51.000  -7.0
# 143       42.395          53.605 -12.0
# 348       50.295          45.705   4.0
#
#                                                    url  pred_plus_minus  \
# 12   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 27   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 29   https://www.cbsnews.com/news/deportation-immig...         0.047635
# 36   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 48   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# ..                                                 ...              ...
# 85   https://pinpointpolicyinstitute.org/wp-content...              NaN
# 161  https://bloximages.newyork1.vip.townnews.com/t...        -0.225885
# 110  https://www.umass.edu/political-science/about/...         0.536200
# 143  https://www.nytimes.com/interactive/2025/04/25...        -0.763947
# 348  https://researchco.ca/2025/01/27/immigration-usa/         0.632258
#
#      poll_id
# 12       106
# 27       107
# 29       108
# 36       109
# 48       110
# ..       ...
# 85       344
# 161      345
# 110      346
# 143      347
# 348      348
#
# [229 rows x 14 columns]

# %%
approval_polls.shape
# Out:
# (229, 14)

# %%
def avgs_pipeline(data: pd.DataFrame, date: datetime.date):
    state_pivot = pipeline(data)
    # state_pivot['end_date'] = pd.to_datetime(state_pivot['end_date'])
    # state_pivot['pred_plus_minus'] = state_pivot['pred_plus_minus'].map(lambda x: -x)
    state_pivot = state_pivot[state_pivot['end_date'] <= pd.to_datetime(date)]
    state_pivot['population'] = state_pivot['population'].astype(str).map(lambda x: x.strip())
    
    total_num_polls = state_pivot.shape[0]

    # Sample size weights
    total_sample_size = np.sum(state_pivot['sample_size'])
    state_pivot['sample_size_weights'] = (state_pivot['sample_size'].map(lambda x: np.sqrt(min(x, 3000))) / np.sqrt(np.median(state_pivot['sample_size'].map(lambda x: min(x, 2000)))))
    # print(np.median(state_pivot['sample_size'].map(lambda x: min(x, 5000))))
    state_pivot['sample_size_weights'] /= np.sum(state_pivot['sample_size_weights'])
    
    # Time weights
    # Variation of the equation used here: https://polls.votehub.us/
    latest_date = pd.Timestamp(date)
    delta = state_pivot['end_date'].apply(lambda x: (latest_date - x).days)# (latest_date - state_pivot['end_date']).apply(lambda x: x.days)
    linear_weights = (1 - delta/((latest_date - state_pivot['end_date'].min()).days + 1))
    exp_weights = 0.1**(delta/(30))
    state_pivot['time_weights'] =  0 * linear_weights + 1 * exp_weights
    # state_pivot['time_weights'] /= np.sum(state_pivot['time_weights'])
    
    # Quality weights
    rel_quality = state_pivot['pred_plus_minus']
    def quality_weight(rel_qual):
        if np.isnan(rel_qual): # For pollsters without a quality rating from the Silver Bulletin
            return 0.1
        if rel_qual > 0.5: # Utilizing predictive plus-minus from Silver Bulletin's ratings
            return 0.2
        # return np.sqrt(-rel_qual+1)+0.05
        return np.exp(-rel_qual/1.3)
    state_pivot['quality_weights'] = rel_quality.map(quality_weight)
    # state_pivot['quality_weights'] /= np.sum(state_pivot['quality_weights'])
    
    # Population weights
    def population_weight(population):
        if population == 'RV':
            return 0.8
        elif population == 'LV':
            return 0.6
        return 1
    state_pivot['population_weights'] = state_pivot['population'].map(population_weight)
    # state_pivot['population_weights'] /= np.sum(state_pivot['population_weights'])

    # Gather the weights together
    state_pivot['total_weights'] = state_pivot['sample_size_weights'] * state_pivot['time_weights'] * state_pivot['quality_weights'] * state_pivot['population_weights']
    state_pivot['total_weights'] /= np.sum(state_pivot['total_weights']) # Normalization step
    
    return state_pivot

# %%
approval_polls['sample_size'].isna().any()
# Out:
# False

# %%
avgs_pipeline(approval_polls, datetime.datetime.today())
# Out:
#                                   pollster                   sponsors  \
# 12                                  YouGov                  Economist
# 27                                  YouGov                  Economist
# 29                                  YouGov                   CBS News
# 36                                  YouGov                  Economist
# 48                                  YouGov                  Economist
# ..                                     ...                        ...
# 85                           Fabrizio Ward  Pinpoint Policy Institute
# 161                 OH Predictive Insights              Center Square
# 110  University of Massachusetts (Amherst)                    WCVB-TV
# 143       The New York Times/Siena College                        NaN
# 348                           Research Co.                        NaN
#
#      startdate   end_date  sample_size population  approve  disapprove  \
# 12   6/13/2025 2025-06-16       1512.0          A     41.0        54.0
# 27    6/6/2025 2025-06-09       1533.0          A     43.0        52.0
# 29    6/4/2025 2025-06-06       2428.0          A     45.0        55.0
# 36   5/30/2025 2025-06-02       1610.0          A     45.0        49.0
# 48   5/23/2025 2025-05-26       1660.0          A     44.0        52.0
# ..         ...        ...          ...        ...      ...         ...
# 85   5/15/2025 2025-05-19        800.0         RV     46.0        49.0
# 161  4/15/2025 2025-04-18       2527.0         RV     44.0        53.0
# 110   4/4/2025 2025-04-09       1000.0          A     44.0        51.0
# 143  4/21/2025 2025-04-24        913.0         RV     42.0        54.0
# 348  1/22/2025 2025-01-24       1001.0          A     50.0        46.0
#
#      approve_adj  disapprove_adj   net  \
# 12        41.250          53.750 -13.0
# 27        43.250          51.750  -9.0
# 29        45.250          54.750 -10.0
# 36        45.250          48.750  -4.0
# 48        44.250          51.750  -8.0
# ..           ...             ...   ...
# 85        46.000          49.000  -3.0
# 161       45.065          51.935  -9.0
# 110       44.000          51.000  -7.0
# 143       42.395          53.605 -12.0
# 348       50.295          45.705   4.0
#
#                                                    url  pred_plus_minus  \
# 12   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 27   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 29   https://www.cbsnews.com/news/deportation-immig...         0.047635
# 36   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 48   https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# ..                                                 ...              ...
# 85   https://pinpointpolicyinstitute.org/wp-content...              NaN
# 161  https://bloximages.newyork1.vip.townnews.com/t...        -0.225885
# 110  https://www.umass.edu/political-science/about/...         0.536200
# 143  https://www.nytimes.com/interactive/2025/04/25...        -0.763947
# 348  https://researchco.ca/2025/01/27/immigration-usa/         0.632258
#
#      poll_id  sample_size_weights  time_weights  quality_weights  \
# 12       106             0.004385      0.584341         0.964021
# 27       107             0.004416      0.341455         0.964021
# 29       108             0.005557      0.271227         0.964021
# 36       109             0.004525      0.199526         0.964021
# 48       110             0.004595      0.116591         0.964021
# ..       ...                  ...           ...              ...
# 85       344             0.003190      0.068129         0.100000
# 161      345             0.005669      0.006310         1.189767
# 110      346             0.003566      0.003162         0.200000
# 143      347             0.003408      0.010000         1.799757
# 348      348             0.003568      0.000010         0.200000
#
#      population_weights  total_weights
# 12                  1.0   5.870688e-02
# 27                  1.0   3.454227e-02
# 29                  1.0   3.453060e-02
# 36                  1.0   2.068518e-02
# 48                  1.0   1.227346e-02
# ..                  ...            ...
# 85                  0.8   4.131696e-04
# 161                 0.8   8.091230e-04
# 110                 1.0   5.360311e-05
# 143                 0.8   1.166002e-03
# 348                 1.0   1.695927e-07
#
# [221 rows x 19 columns]

# %%
avgs_pipeline(approval_polls, datetime.datetime.today()).shape
# Out:
# (221, 19)

# %%
def approval_over_time(data: pd.DataFrame):
    date_range = pd.date_range(start=datetime.date(2025, 1, 23), end=datetime.datetime.today(), freq='d', inclusive='both')
    yes_averages = []
    no_averages = []
    yes_stdevs = []
    no_stdevs = []
    for date in date_range:
        pipelined_df = avgs_pipeline(data, date)
        yes_avg = np.sum(pipelined_df['approve_adj'] * pipelined_df['total_weights'])
        no_avg = np.sum(pipelined_df['disapprove_adj'] * pipelined_df['total_weights'])
        yes_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['approve_adj'] - yes_avg)**2))
        no_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['disapprove_adj'] - no_avg)**2))
        yes_averages.append(yes_avg)
        no_averages.append(no_avg)
        yes_stdevs.append(yes_std)
        no_stdevs.append(no_std)
    
    return pd.DataFrame({'Date':date_range, 'Approve':yes_averages, 'Disapprove':no_averages}), pd.DataFrame({'Date':date_range, 'Approve':yes_stdevs, 'Disapprove':no_stdevs}), avgs_pipeline(data, datetime.datetime.today())

# %%
approval_avg, approval_std, polls_df = approval_over_time(approval_polls)
approval_avg
# Out:
#           Date    Approve  Disapprove
# 0   2025-01-23  51.302546   45.716945
# 1   2025-01-24  51.229190   45.375031
# 2   2025-01-25  51.229190   45.375031
# 3   2025-01-26  50.557686   45.329878
# 4   2025-01-27  49.352305   45.485129
# ..         ...        ...         ...
# 147 2025-06-19  45.673143   51.303111
# 148 2025-06-20  45.556665   51.419924
# 149 2025-06-21  45.556665   51.419924
# 150 2025-06-22  45.556665   51.419924
# 151 2025-06-23  45.556665   51.419924
#
# [152 rows x 3 columns]

# %%
polls_df.shape
# Out:
# (221, 19)

# %%
polls_df.head(3)
# Out:
#    pollster   sponsors  startdate   end_date  sample_size population  approve  \
# 12   YouGov  Economist  6/13/2025 2025-06-16       1512.0          A     41.0
# 27   YouGov  Economist   6/6/2025 2025-06-09       1533.0          A     43.0
# 29   YouGov   CBS News   6/4/2025 2025-06-06       2428.0          A     45.0
#
#     disapprove  approve_adj  disapprove_adj   net  \
# 12        54.0        41.25           53.75 -13.0
# 27        52.0        43.25           51.75  -9.0
# 29        55.0        45.25           54.75 -10.0
#
#                                                   url  pred_plus_minus  \
# 12  https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 27  https://d3nkl3psvxxpe9.cloudfront.net/document...         0.047635
# 29  https://www.cbsnews.com/news/deportation-immig...         0.047635
#
#     poll_id  sample_size_weights  time_weights  quality_weights  \
# 12      106             0.004385      0.584341         0.964021
# 27      107             0.004416      0.341455         0.964021
# 29      108             0.005557      0.271227         0.964021
#
#     population_weights  total_weights
# 12                 1.0       0.058707
# 27                 1.0       0.034542
# 29                 1.0       0.034531

# %%
polls_df['net_adj'] = polls_df['approve_adj'] - polls_df['disapprove_adj']

# %%
display_df = polls_df[['pollster', 'sponsors', 'startdate', 'end_date', 'sample_size', 'population', 'approve', 'disapprove', 'net',
                      'total_weights', 'url']]
display_df['sponsors'] = '^Sponsor: ' + display_df['sponsors'] + '^'
display_df['sponsors'] = display_df['sponsors'].fillna('')
display_df = display_df.sort_values(['end_date'], ascending=False)
display_df = display_df.rename({'pollster':'Pollster', 'approve':'Approve', 'disapprove':'Disapprove', 'net':'Net', 'total_weights':'Weight', 'startdate':'Start Date', 'end_date':'End Date', 'url':'URL'}, axis='columns')
display_df['Sample'] = display_df['sample_size'].astype(int).astype(str) + ' ' + display_df['population']
# display_df['end_date'] = display_df['end_date'].map(lambda x: datetime.datetime.strptime(datetime.datetime.fromtimestamp(x), '%m/%d/%Y').strftime('%Y-%m-%d'))
# display_df['Date'] = pd.to_datetime(display_df['startdate']).astype(str) + ' - ' + display_df['end_date'].astype(str)
display_df['Start Date'] = pd.to_datetime(display_df['Start Date']).astype(str)
display_df['End Date'] = display_df['End Date'].astype(str)
display_df = display_df.reset_index()
# display_df = display_df.drop(['sample_size', 'population'], axis='columns')
display_df['Pollster'] = '<a href="' + display_df['URL'] + '" style="color:black; text-decoration:underline;"><u>' + display_df['Pollster'] + '</u></a>' + display_df['sponsors']
# display_df['Pollster'] = '[' + display_df['Pollster'] + '](' + display_df['URL'] + ')'
display_df = display_df[['Pollster', 'Start Date', 'End Date', 'Sample', 'Weight', 'Approve', 'Disapprove', 'Net']]
# display_df = display_df.set_index(['Pollster'])
display_df
# Out:
#                                               Pollster  Start Date  \
# 0    <a href="https://americanresearchgroup.com/eco...  2025-06-17
# 1    <a href="https://napolitannews.org/jobapproval...  2025-06-11
# 2    <a href="https://echelonin.wpenginepowered.com...  2025-06-17
# 3    <a href="https://jlpartners.com/israeliran" st...  2025-06-16
# 4    <a href="https://echelonin.wpenginepowered.com...  2025-06-12
# ..                                                 ...         ...
# 216  <a href="https://researchco.ca/2025/01/27/immi...  2025-01-22
# 217  <a href="https://cdn.atlasintel.org/ed3f5238-e...  2025-01-21
# 218  <a href="https://x.com/ScottWRasmussen/status/...  2025-01-20
# 219  <a href="https://www.ipsos.com/en-us/reuters-i...  2025-01-20
# 220  <a href="https://insideradvantage.com/first-in...  2025-01-20
#
#        End Date   Sample        Weight  Approve  Disapprove        Net
# 0    2025-06-20   1100 A  1.412168e-02     38.0        59.0 -21.000000
# 1    2025-06-19  3000 RV  6.975855e-02     53.0        46.0   7.000000
# 2    2025-06-18  1002 LV  4.096968e-02     48.0        52.0  -4.000000
# 3    2025-06-17  1039 RV  3.744908e-02     46.0        51.0  -5.000000
# 4    2025-06-17   982 LV  3.756221e-02     45.0        53.0  -8.000000
# ..          ...      ...           ...      ...         ...        ...
# 216  2025-01-24   1001 A  1.695927e-07     50.0        46.0   4.000000
# 217  2025-01-23   1882 A  2.249528e-06     50.1        49.7   0.399998
# 218  2025-01-23  3000 RV  8.782081e-07     57.0        39.0  18.000000
# 219  2025-01-21   1077 A  4.969445e-07     47.0        41.0   6.000000
# 220  2025-01-20   800 RV  4.344256e-07     56.0        39.0  17.000000
#
# [221 rows x 8 columns]

# %%
display_df.to_csv('polls_display_table.csv')

# %%
approval_std
# Out:
#           Date   Approve  Disapprove
# 0   2025-01-23  3.697758    5.575750
# 1   2025-01-24  3.393680    5.186733
# 2   2025-01-25  3.393680    5.186733
# 3   2025-01-26  3.666409    4.754769
# 4   2025-01-27  3.645936    4.322278
# ..         ...       ...         ...
# 147 2025-06-19  3.974545    3.490581
# 148 2025-06-20  4.064614    3.600655
# 149 2025-06-21  4.064614    3.600655
# 150 2025-06-22  4.064614    3.600655
# 151 2025-06-23  4.064614    3.600655
#
# [152 rows x 3 columns]

# %%
approval_avg['Net'] = approval_avg['Approve'] - approval_avg['Disapprove']
approval_avg
# Out:
#           Date    Approve  Disapprove       Net
# 0   2025-01-23  51.302546   45.716945  5.585601
# 1   2025-01-24  51.229190   45.375031  5.854159
# 2   2025-01-25  51.229190   45.375031  5.854159
# 3   2025-01-26  50.557686   45.329878  5.227807
# 4   2025-01-27  49.352305   45.485129  3.867175
# ..         ...        ...         ...       ...
# 147 2025-06-19  45.673143   51.303111 -5.629968
# 148 2025-06-20  45.556665   51.419924 -5.863259
# 149 2025-06-21  45.556665   51.419924 -5.863259
# 150 2025-06-22  45.556665   51.419924 -5.863259
# 151 2025-06-23  45.556665   51.419924 -5.863259
#
# [152 rows x 4 columns]

# %%
approval_trendline = pd.merge(left=approval_avg, right=approval_std, left_on='Date', right_on='Date', how='inner')
approval_trendline['approve_CI_upper'] = approval_trendline['Approve_x'] + 1.96*approval_trendline['Approve_y']
approval_trendline['approve_CI_lower'] = approval_trendline['Approve_x'] - 1.96*approval_trendline['Approve_y']
approval_trendline['disapprove_CI_upper'] = approval_trendline['Disapprove_x'] + 1.96*approval_trendline['Disapprove_y']
approval_trendline['disapprove_CI_lower'] = approval_trendline['Disapprove_x'] - 1.96*approval_trendline['Disapprove_y']
approval_trendline = approval_trendline.rename({
    'Approve_x':'approve_mean',
    'Disapprove_x':'disapprove_mean',
}, axis='columns').drop(['Approve_y', 'Disapprove_y', 'Net'], axis='columns')
approval_trendline
# Out:
#           Date  approve_mean  disapprove_mean  approve_CI_upper  \
# 0   2025-01-23     51.302546        45.716945         58.550152
# 1   2025-01-24     51.229190        45.375031         57.880803
# 2   2025-01-25     51.229190        45.375031         57.880803
# 3   2025-01-26     50.557686        45.329878         57.743848
# 4   2025-01-27     49.352305        45.485129         56.498339
# ..         ...           ...              ...               ...
# 147 2025-06-19     45.673143        51.303111         53.463251
# 148 2025-06-20     45.556665        51.419924         53.523308
# 149 2025-06-21     45.556665        51.419924         53.523308
# 150 2025-06-22     45.556665        51.419924         53.523308
# 151 2025-06-23     45.556665        51.419924         53.523308
#
#      approve_CI_lower  disapprove_CI_upper  disapprove_CI_lower
# 0           44.054940            56.645416            34.788474
# 1           44.577578            55.541028            35.209034
# 2           44.577578            55.541028            35.209034
# 3           43.371524            54.649225            36.010531
# 4           42.206270            53.956795            37.013464
# ..                ...                  ...                  ...
# 147         37.883035            58.144651            44.461571
# 148         37.590023            58.477208            44.362640
# 149         37.590023            58.477208            44.362640
# 150         37.590023            58.477208            44.362640
# 151         37.590023            58.477208            44.362640
#
# [152 rows x 7 columns]

# %%
# Export approval ratings
approval_trendline.to_csv('approval_stats.csv')

# %%
polls_df.shape
# Out:
# (221, 20)

# %%
line = px.line(approval_avg, x='Date', y=['Approve', 'Disapprove'])
# scatter = px.scatter(polls_df[polls_df['end_date'] >= pd.to_datetime('2025-01-24')], x='end_date', y=['approve', 'disapprove'])
line.update_traces(hovertemplate=None)
line.update_layout(hovermode='x unified')
# scatter.update_traces(hovertemplate=None, hoverinfo='skip')
fig_approve_CI = go.Figure([
    go.Scatter(
        name='Approve CI Upper Bound',
        x = approval_avg['Date'],
        y = approval_avg['Approve'] + 1.96*approval_std['Approve'],
        mode='lines',
        marker=dict(color='#8be8f2'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),
    go.Scatter(
        name='Approve CI Lower Bound',
        x = approval_avg['Date'],
        y = approval_avg['Approve'] - 1.96*approval_std['Approve'],
        mode='lines',
        marker=dict(color='#8be8f2'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),  
])
fig_disapprove_CI = go.Figure([
    go.Scatter(
        name='Disapprove CI Upper Bound',
        x = approval_avg['Date'],
        y = approval_avg['Disapprove'] + 1.96*approval_std['Disapprove'],
        mode='lines',
        marker=dict(color='#a3cbec'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),
    go.Scatter(
        name='Disapprove CI Lower Bound',
        x = approval_avg['Date'],
        y = approval_avg['Disapprove'] - 1.96*approval_std['Disapprove'],
        mode='lines',
        marker=dict(color='#a3cbec'),
        line=dict(width=0),
        showlegend=False,
        hoverinfo='skip'
    ),  
])

fig = go.Figure(data=line.data + fig_approve_CI.data + fig_disapprove_CI.data)
fig.update_layout(
    title='President Trump Approval Rating',
    xaxis_title='Date',
    yaxis_title='%',
    legend_title='Legend',
    hovermode='x unified'
)
fig.show()
# Out:
# <div>                            <div id="8f9df8ee-7a88-47f3-b3fd-85ee2d9e067a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f9df8ee-7a88-47f3-b3fd-85ee2d9e067a")) {                    Plotly.newPlot(                        "8f9df8ee-7a88-47f3-b3fd-85ee2d9e067a",                        [{"legendgroup":"Approve","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Approve","orientation":"v","showlegend":true,"x":["2025-01-23T00:00:00","2025-01-24T00:00:00","2025-01-25T00:00:00","2025-01-26T00:00:00","2025-01-27T00:00:00","2025-01-28T00:00:00","2025-01-29T00:00:00","2025-01-30T00:00:00","2025-01-31T00:00:00","2025-02-01T00:00:00","2025-02-02T00:00:00","2025-02-03T00:00:00","2025-02-04T00:00:00","2025-02-05T00:00:00","2025-02-06T00:00:00","2025-02-07T00:00:00","2025-02-08T00:00:00","2025-02-09T00:00:00","2025-02-10T00:00:00","2025-02-11T00:00:00","2025-02-12T00:00:00","2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00","2025-05-14T00:00:00","2025-05-15T00:00:00","2025-05-16T00:00:00","2025-05-17T00:00:00","2025-05-18T00:00:00","2025-05-19T00:00:00","2025-05-20T00:00:00","2025-05-21T00:00:00","2025-05-22T00:00:00","2025-05-23T00:00:00","2025-05-24T00:00:00","2025-05-25T00:00:00","2025-05-26T00:00:00","2025-05-27T00:00:00","2025-05-28T00:00:00","2025-05-29T00:00:00","2025-05-30T00:00:00","2025-05-31T00:00:00","2025-06-01T00:00:00","2025-06-02T00:00:00","2025-06-03T00:00:00","2025-06-04T00:00:00","2025-06-05T00:00:00","2025-06-06T00:00:00","2025-06-07T00:00:00","2025-06-08T00:00:00","2025-06-09T00:00:00","2025-06-10T00:00:00","2025-06-11T00:00:00","2025-06-12T00:00:00","2025-06-13T00:00:00","2025-06-14T00:00:00","2025-06-15T00:00:00","2025-06-16T00:00:00","2025-06-17T00:00:00","2025-06-18T00:00:00","2025-06-19T00:00:00","2025-06-20T00:00:00","2025-06-21T00:00:00", ...

# %%
line = px.line(approval_avg, x='Date', y=['Net'])
scatter = px.scatter(polls_df[polls_df['end_date'] >= pd.to_datetime('2025-01-24')], x='end_date', y=['net'])
                     #trendline='lowess', trendline_options=dict(frac=0.2))
fig = go.Figure(data=line.data + scatter.data)
fig.add_hline(y=0, line_dash='dash')
fig.show()
# Out:
# <div>                            <div id="92755bd8-8b52-468d-afb1-0ca41ce5ebcd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92755bd8-8b52-468d-afb1-0ca41ce5ebcd")) {                    Plotly.newPlot(                        "92755bd8-8b52-468d-afb1-0ca41ce5ebcd",                        [{"hovertemplate":"variable=Net\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Net","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Net","orientation":"v","showlegend":true,"x":["2025-01-23T00:00:00","2025-01-24T00:00:00","2025-01-25T00:00:00","2025-01-26T00:00:00","2025-01-27T00:00:00","2025-01-28T00:00:00","2025-01-29T00:00:00","2025-01-30T00:00:00","2025-01-31T00:00:00","2025-02-01T00:00:00","2025-02-02T00:00:00","2025-02-03T00:00:00","2025-02-04T00:00:00","2025-02-05T00:00:00","2025-02-06T00:00:00","2025-02-07T00:00:00","2025-02-08T00:00:00","2025-02-09T00:00:00","2025-02-10T00:00:00","2025-02-11T00:00:00","2025-02-12T00:00:00","2025-02-13T00:00:00","2025-02-14T00:00:00","2025-02-15T00:00:00","2025-02-16T00:00:00","2025-02-17T00:00:00","2025-02-18T00:00:00","2025-02-19T00:00:00","2025-02-20T00:00:00","2025-02-21T00:00:00","2025-02-22T00:00:00","2025-02-23T00:00:00","2025-02-24T00:00:00","2025-02-25T00:00:00","2025-02-26T00:00:00","2025-02-27T00:00:00","2025-02-28T00:00:00","2025-03-01T00:00:00","2025-03-02T00:00:00","2025-03-03T00:00:00","2025-03-04T00:00:00","2025-03-05T00:00:00","2025-03-06T00:00:00","2025-03-07T00:00:00","2025-03-08T00:00:00","2025-03-09T00:00:00","2025-03-10T00:00:00","2025-03-11T00:00:00","2025-03-12T00:00:00","2025-03-13T00:00:00","2025-03-14T00:00:00","2025-03-15T00:00:00","2025-03-16T00:00:00","2025-03-17T00:00:00","2025-03-18T00:00:00","2025-03-19T00:00:00","2025-03-20T00:00:00","2025-03-21T00:00:00","2025-03-22T00:00:00","2025-03-23T00:00:00","2025-03-24T00:00:00","2025-03-25T00:00:00","2025-03-26T00:00:00","2025-03-27T00:00:00","2025-03-28T00:00:00","2025-03-29T00:00:00","2025-03-30T00:00:00","2025-03-31T00:00:00","2025-04-01T00:00:00","2025-04-02T00:00:00","2025-04-03T00:00:00","2025-04-04T00:00:00","2025-04-05T00:00:00","2025-04-06T00:00:00","2025-04-07T00:00:00","2025-04-08T00:00:00","2025-04-09T00:00:00","2025-04-10T00:00:00","2025-04-11T00:00:00","2025-04-12T00:00:00","2025-04-13T00:00:00","2025-04-14T00:00:00","2025-04-15T00:00:00","2025-04-16T00:00:00","2025-04-17T00:00:00","2025-04-18T00:00:00","2025-04-19T00:00:00","2025-04-20T00:00:00","2025-04-21T00:00:00","2025-04-22T00:00:00","2025-04-23T00:00:00","2025-04-24T00:00:00","2025-04-25T00:00:00","2025-04-26T00:00:00","2025-04-27T00:00:00","2025-04-28T00:00:00","2025-04-29T00:00:00","2025-04-30T00:00:00","2025-05-01T00:00:00","2025-05-02T00:00:00","2025-05-03T00:00:00","2025-05-04T00:00:00","2025-05-05T00:00:00","2025-05-06T00:00:00","2025-05-07T00:00:00","2025-05-08T00:00:00","2025-05-09T00:00:00","2025-05-10T00:00:00","2025-05-11T00:00:00","2025-05-12T00:00:00","2025-05-13T00:00:00","2025-05-14T00:00:00","2025-05-15T00:00:00","2025-05-16T00:00:00","2025-05-17T00:00:00","2025-05-18T00:00:00","2025-05-19T00:00:00","2025-05-20T00:00:00","2025-05-21T00:00:00","2025-05-22T00:00:00","2025-05-23T00:00:00","2025-05-24T00:00:00","2025-05-25T00:00:00","2025-05-26T00:00:00","2025-05-27T00:00:00","2025-05-28T00:00:00","2025-05-29T00:00:00","2025-05-30T00:00:00","2025-05-31T00:00:00","2025-06-01T00:00:00","2025-06-02T00:00:00","2025-06-03T00:00:00","2025-06-04T00:00:00","2025-06-05T00:00:00","2025-06-06T00:00:00","2025-06-07T00:00:00","2025-06-08T00:00:00","2025-06-09T00:00:00","2025-06-10T00:00:00","2025-06-11T00:00:00","2025-06-12T00:00:00","2025-06-13T00:00:00","2025-06-14T00:00:00","2025-06-15T00:00:00","2025-06-16T00:00:00", ...

# %%
# scatter = px.scatter(polls_df[polls_df['end_date'] >= pd.to_datetime('2025-01-24')], x='end_date', y=['net', 'net_adj'])
# fig = go.Figure(data=scatter.data)
# fig.add_hline(y=0, line_dash='dash')
# fig.show()

# %%
def net_col(df: pd.DataFrame, min_date: datetime.date):
#     df_copy = df.set_index(['Date'])
#     return df_copy['approve_mean'] - df_copy['disapprove_mean']
    date_range = pd.date_range(start=min_date, end=datetime.datetime.today(), freq='d', inclusive='both')
    data = df.copy()
    data['net_adj'] = data['approve_adj'] - data['disapprove_adj']
    net_averages = []
    net_stdevs = []
    issue_cols = {'Date': date_range, 'net':[], 'net_std':[]}
    for date in date_range:
    #         try:
            pipelined_df = avgs_pipeline(data, date)
    #         except TypeError:
    #             print('TypeError')
    #             print(date)
            net_avg = np.sum(pipelined_df['net_adj'] * pipelined_df['total_weights'])
            net_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['net_adj'] - net_avg)**2))

            net_averages.append(net_avg)
            net_stdevs.append(net_std)

    issue_cols['net'].extend(net_averages)
    issue_cols[f'net_std'].extend(net_stdevs)
        
    net_averages, net_stdevs = [], []
        
    return pd.DataFrame(issue_cols)

# %%
net_approval = net_col(approval, datetime.date(2025, 1, 23))
net_approval
# Out:
#           Date       net   net_std
# 0   2025-01-23  5.585601  8.638245
# 1   2025-01-24  5.854159  7.957334
# 2   2025-01-25  5.854159  7.957334
# 3   2025-01-26  5.227807  7.578410
# 4   2025-01-27  3.867175  6.944637
# ..         ...       ...       ...
# 147 2025-06-19 -5.629968  6.942157
# 148 2025-06-20 -5.863259  7.163275
# 149 2025-06-21 -5.863259  7.163275
# 150 2025-06-22 -5.863259  7.163275
# 151 2025-06-23 -5.863259  7.163275
#
# [152 rows x 3 columns]

# %%
net_approval['net_upper_CI'] = net_approval['net'] + 1.96*net_approval['net_std']
net_approval['net_lower_CI'] = net_approval['net'] - 1.96*net_approval['net_std']
net_approval
# Out:
#           Date       net   net_std  net_upper_CI  net_lower_CI
# 0   2025-01-23  5.585601  8.638245     22.516561    -11.345359
# 1   2025-01-24  5.854159  7.957334     21.450534     -9.742216
# 2   2025-01-25  5.854159  7.957334     21.450534     -9.742216
# 3   2025-01-26  5.227807  7.578410     20.081490     -9.625875
# 4   2025-01-27  3.867175  6.944637     17.478664     -9.744313
# ..         ...       ...       ...           ...           ...
# 147 2025-06-19 -5.629968  6.942157      7.976659    -19.236595
# 148 2025-06-20 -5.863259  7.163275      8.176760    -19.903278
# 149 2025-06-21 -5.863259  7.163275      8.176760    -19.903278
# 150 2025-06-22 -5.863259  7.163275      8.176760    -19.903278
# 151 2025-06-23 -5.863259  7.163275      8.176760    -19.903278
#
# [152 rows x 5 columns]

# %%
net_approval.to_csv('net_approval.csv')

# %% [markdown]
# ### Auxiliary Graph: Individual Pollsters

# %%
approval_polls.columns.values
# Out:
# array(['pollster', 'sponsors', 'startdate', 'end_date', 'sample_size',
#        'population', 'approve', 'disapprove', 'approve_adj',
#        'disapprove_adj', 'net', 'url', 'pred_plus_minus', 'poll_id'],
#       dtype=object)

# %%
appr = full_approval.copy()
appr['net_adj'] = appr['approve'] - appr['disapprove']
appr = appr[~appr['pred_plus_minus'].isna()]
pollsters = appr['pollster'].value_counts().index.values
pollsters
# Out:
# array(['Rasmussen Reports', 'YouGov', 'Morning Consult', 'RMG Research',
#        'Ipsos', 'J.L. Partners', 'Echelon Insights', 'TIPP Insights',
#        'Global Strategy Group/GBAO (Navigator Research)',
#        'Harris Insights & Analytics', 'Emerson College',
#        'American Research Group', 'McLaughlin & Associates', 'Gallup',
#        'AtlasIntel', 'Quinnipiac University', 'Clarity Campaign Labs',
#        'SSRS', 'InsiderAdvantage', 'Pew Research Center',
#        'John Zogby Strategies', 'co/efficient', 'Cygnal',
#        'Marquette University Law School', 'Civiqs',
#        'Beacon Research/Shaw & Co. Research',
#        'Hart Research Associates/Public Opinion Strategies',
#        'Fabrizio Lee & Associates/Impact Research', 'Marist College',
#        'Blueprint Polling', 'Trafalgar Group', 'SurveyMonkey',
#        'Public Opinion Strategies', 'The New York Times/Siena College',
#        'University of Massachusetts (Amherst)', 'OH Predictive Insights',
#        'Targoz Market Research', 'GBAO',
#        'Public Religion Research Institute', 'Remington Research Group',
#        'North Star Opinion Research', 'OnMessage Inc.', 'SurveyUSA',
#        'NewsNation', 'Research Co.'], dtype=object)

# %%
def approval_today(data: pd.DataFrame):
    # date_range = pd.date_range(start=datetime.date(2025, 1, 23), end=datetime.datetime.today(), freq='d', inclusive='both')
#     yes_averages = []
#     no_averages = []
#     yes_stdevs = []
#     no_stdevs = []
    pipelined_df = avgs_pipeline(data, datetime.datetime.today())
    yes_avg = np.sum(pipelined_df['approve'] * pipelined_df['total_weights'])
    no_avg = np.sum(pipelined_df['disapprove'] * pipelined_df['total_weights'])
    yes_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['approve'] - yes_avg)**2))
    no_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['disapprove'] - no_avg)**2))
    net_avg = np.sum(pipelined_df['net'] * pipelined_df['total_weights'])
    net_std = np.sqrt(np.sum(pipelined_df['total_weights'] * (pipelined_df['net'] - net_avg)**2))
    
    #return pd.DataFrame({'Date':date_range, 'Approve':yes_averages, 'Disapprove':no_averages}), pd.DataFrame({'Date':date_range, 'Approve':yes_stdevs, 'Disapprove':no_stdevs}), avgs_pipeline(data, datetime.datetime.today())
    return yes_avg, no_avg, yes_std, no_std, net_avg, net_std

# %%
def indiv_pollster_avg(pollster: str):
    df = appr[appr['pollster'] == pollster]
    yes_avg, no_avg, yes_std, no_std, net_avg, net_std = approval_today(df)
    return yes_avg, no_avg, yes_std, no_std, net_avg, net_std

# %%
def get_ppm(pollster: str):
    df = ratings[ratings['Pollster'] == pollster]
    ppm = df['Predictive Plus-Minus'].values[0]
    
    return ppm

# %%
appr.shape
# Out:
# (338, 26)

# %%
def get_num_polls(pollster: str):
    df = appr[appr['pollster'] == pollster]
    num_polls = df.shape[0]
    return num_polls

# %%
get_ppm('YouGov')
# Out:
# 0.047635015

# %%
indiv_pollster_avg('YouGov')
# Out:
# (42.900474191057825,
#  52.76860451019765,
#  1.669632413956023,
#  1.9805638285980822,
#  -9.86813031913983,
#  2.9506225667562154)

# %%
indiv_pollster_avg('RMG Research')
# Out:
# (51.745629571313614,
#  46.683409356778746,
#  1.533554624310377,
#  1.4319488836630792,
#  5.062220214534895,
#  2.866232675147639)

# %%
nets = []
net_stdevs = []
ppms = []
nums = []

for p in pollsters:
    _, _, _, _, net, net_std = indiv_pollster_avg(p)
    ppm = get_ppm(p)
    num_polls = get_num_polls(p)
    
    nets.append(net)
    net_stdevs.append(net_std)
    ppms.append(ppm)
    nums.append(num_polls)

# %%
# nets

# %%
indiv_avgs = pd.DataFrame({'Pollster': pollsters, 'Net Approval': nets, 'Net Stdev': net_stdevs, 'Predictive Plus-Minus': ppms, 'Number of Approval Polls Conducted': nums})
indiv_avgs = indiv_avgs.sort_values(['Net Approval'], ascending=True)
indiv_avgs
# Out:
#                                              Pollster  Net Approval  \
# 11                            American Research Group    -20.306946
# 17                                               SSRS    -17.494832
# 19                                Pew Research Center    -17.026012
# 15                              Quinnipiac University    -15.959728
# 8     Global Strategy Group/GBAO (Navigator Research)    -12.410504
# 33                   The New York Times/Siena College    -12.000000
# 43                                         NewsNation    -12.000000
# 4                                               Ipsos    -11.743412
# 38                 Public Religion Research Institute    -11.000000
# 28                                     Marist College    -10.898258
# 31                                       SurveyMonkey    -10.000000
# 13                                             Gallup     -9.926876
# 1                                              YouGov     -9.868130
# 14                                         AtlasIntel     -9.762984
# 35                             OH Predictive Insights     -9.000000
# 25                Beacon Research/Shaw & Co. Research     -8.036696
# 23                    Marquette University Law School     -7.997985
# 34              University of Massachusetts (Amherst)     -7.000000
# 26  Hart Research Associates/Public Opinion Strate...     -6.820752
# 12                            McLaughlin & Associates     -6.770699
# 6                                    Echelon Insights     -5.906316
# 7                                       TIPP Insights     -5.388207
# 29                                  Blueprint Polling     -5.185800
# 24                                             Civiqs     -5.130944
# 40                        North Star Opinion Research     -5.000000
# 36                             Targoz Market Research     -5.000000
# 27          Fabrizio Lee & Associates/Impact Research     -4.909756
# 5                                       J.L. Partners     -4.688474
# 22                                             Cygnal     -4.040251
# 9                         Harris Insights & Analytics     -3.627568
# 16                              Clarity Campaign Labs     -2.995428
# 37                                               GBAO     -2.000000
# 21                                       co/efficient     -1.992164
# 2                                     Morning Consult     -1.990688
# 20                              John Zogby Strategies     -0.891306
# 10                                    Emerson College     -0.430618
# 41                                     OnMessage Inc.      1.000000
# 39                           Remington Research Group      2.000000
# 32                          Public Opinion Strategies      2.000000
# 44                                       Research Co.      4.000000
# 0                                   Rasmussen Reports      4.612950
# 3                                        RMG Research      5.062220
# 42                                          SurveyUSA      6.000000
# 30                                    Trafalgar Group      9.558649
# 18                                   InsiderAdvantage     10.289648
#
#     Net Stdev  Predictive Plus-Minus  Number of Approval Polls Conducted
# 11   2.200216               0.818141                                   5
# 17   2.384042               0.966835                                   4
# 19   0.251962               0.132230                                   3
# 15   0.434969              -0.290484                                   5
# 8    1.263552               0.804988                                   7
# 33   0.000000              -0.763947                                   1
# 43   0.000000               0.614459                                   1
# 4    1.023970               0.442898                                  15
# 38   0.000000               0.103864                                   1
# 28   0.837759              -0.436610                                   2
# 31   0.000000               1.047575                                   2
# 13   0.302161              -0.096810                                   5
# 1    2.950623               0.047635                                  40
# 14   0.752949              -0.957740                                   5
# 35   0.000000              -0.225885                                   1
# 25   0.397218              -0.635562                                   3
# 23   0.089744              -0.920261                                   3
# 34   0.000000               0.536200                                   1
# 26   0.711066              -0.250934                                   2
# 12   0.295844               1.412199                                   5
# 6    1.973388              -0.216672                                   8
# 7    2.297245              -0.571372                                   8
# 29   1.846098               0.328796                                   2
# 24   0.501798               0.158562                                   3
# 40   0.000000               0.043339                                   1
# 36   0.000000               0.731655                                   1
# 27   0.730287               0.588291                                   2
# 5    1.263982               0.197911                                  11
# 22   0.726085              -0.747339                                   3
# 9    1.100126               0.162447                                   7
# 16   0.180099               0.228707                                   4
# 37   0.000000               0.384788                                   1
# 21   0.176519              -0.209003                                   3
# 2    4.818472               0.584994                                  26
# 20   0.323850               0.533178                                   3
# 10   0.878473              -0.569153                                   5
# 41   0.000000              -0.600249                                   1
# 39   0.000000               0.322523                                   1
# 32   0.000000              -0.246974                                   1
# 44   0.000000               0.632258                                   1
# 0    2.067184               0.087015                                 107
# 3    2.866233               0.278023                                  22
# 42   0.000000              -0.732433                                   1
# 30   0.705630              -0.215439                                   2
# 18   0.039250               0.034562                                   3

# %%
indiv_avgs.to_csv('indiv_pollster_avgs.csv')

# %%
reg = lm.LinearRegression()
reg.fit(indiv_avgs[['Predictive Plus-Minus']], indiv_avgs['Net Approval'])
reg.coef_, reg.intercept_
# Out:
# (array([-1.99911052]), -5.19125786067504)

# %%
r = r_regression(indiv_avgs[['Predictive Plus-Minus']], indiv_avgs['Net Approval'])
r
# Out:
# array([-0.1624162])
